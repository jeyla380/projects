# %% [markdown]
# <img src="netflix_icon.png" style="width: 600px;" />
# <br>
#
# # Netflix Movies and TV Shows
#
# **About this Dataset:** [Netflix](https://en.wikipedia.org/wiki/Netflix) is one of the most popular media and video streaming platforms. They have over 8000 movies or tv shows available on their platform, as of mid-2021, they have over 200M Subscribers globally. This tabular dataset consists of listings of all the movies and tv shows available on Netflix, along with details such as - cast, directors, ratings, release year, duration, etc [<sup id="fn1-back">1</sup>](#fn1).
#
# Other than the dataset and description (above) given, the tasks, descriptions under the tasks, and summaries are all written and created by me.

# %% [markdown]
# <hr>
#
# ### Tasks:
#
# 1. Give an updated list removing all the blank spaces in the cast and director(s) column.
# 2. How many movies came out in 2021 vs. 2020, and vs. 2019?
# 3. How many TV shows between those same years?
# 4. How has Netflix been impacted by COVID-19?
# 5. What is the rating distribution like?
# 6. What month is the most movies and TV shows released in 2017, 2019, and 2021?
# 7. What TV shows on Netflix only lasted one season?
# 8. What type of genre is the most popular in both movies and TV shows?
# 9. How many TV shows were created outside the United States, and what countries are they?
#
# <hr>

# %% [markdown]
# The `netflix_titles.csv` contains the following headers:
#
# <table>
#     <tr>
#         <th>show_id</th>
#         <th>type</th>
#         <th>title</th>
#         <th>director</th>
#         <th>cast</th>
#         <th>country</th>
#         <th>date_added</th>
#         <th>release_year</th>
#         <th>rating</th>
#         <th>duration</th>
#         <th>listed_in</th>
#         <th>description</th>
#     </tr>
# </table>

# %%
import csv

netflix_type = []
netflix_title = []
netflix_director = []
netflix_cast = []
netflix_country = []
netflix_date_added = []
netflix_release_year = []
netflix_rating = []
netflix_duration = []
netflix_listed_in = []
netflix_description = []

with open('netflix_titles.csv', encoding="utf8") as netflix_titles:
    netflix_reader = csv.DictReader(netflix_titles)
    for row in netflix_reader:
        #print(row['title'])
        netflix_type.append(row['type'])
        netflix_title.append(row['title'])
        netflix_director.append(row['director'])
        netflix_cast.append(row['cast'])
        netflix_country.append(row['country'])
        netflix_date_added.append(row['date_added'])
        netflix_release_year.append(row['release_year'])
        netflix_rating.append(row['rating'])
        netflix_duration.append(row['duration'])
        netflix_listed_in.append(row['listed_in'])
        netflix_description.append(row['description'])

        
netflix_show_id = []
for number in range(0, len(netflix_title)):
    #print(number)
    netflix_show_id.append(number)

#print(netflix_director)   


#The 'netflix_titles.csv' is now imported into the notebook as 'netflix_reader' with UTF-8 encoded.

# %% [markdown]
# Here we are printing out all the movie titles from the `netflix_titles.csv` document as an example to ensure each column was added into a list (type, title, director, cast, country, etc.).
#
# Now the movie titles are in the `netflix_title` list.

# %%
#This is to check to make sure it's printing out correctly.
for title in netflix_title:
    print(title)
# Out:
# Dick Johnson Is Dead
# Blood & Water
# Ganglands
# Jailbirds New Orleans
# Kota Factory
# Midnight Mass
# My Little Pony: A New Generation
# Sankofa
# The Great British Baking Show
# The Starling
# Vendetta: Truth, Lies and The Mafia
# Bangkok Breaking
# Je Suis Karl
# Confessions of an Invisible Girl
# Crime Stories: India Detectives
# Dear White People
# Europe's Most Dangerous Man: Otto Skorzeny in Spain
# Falsa identidad
# Intrusion
# Jaguar
# Monsters Inside: The 24 Faces of Billy Milligan
# Resurrection: Ertugrul
# Avvai Shanmughi
# Go! Go! Cory Carson: Chrissy Takes the Wheel
# Jeans
# Love on the Spectrum
# Minsara Kanavu
# Grown Ups
# Dark Skies
# Paranoia
# Ankahi Kahaniya
# Chicago Party Aunt
# Sex Education
# Squid Game
# Tayo and Little Wizards
# The Father Who Moves Mountains
# The Stronghold
# Angry Birds
# Birth of the Dragon
# Chhota Bheem
# He-Man and the Masters of the Universe
# Jaws
# Jaws 2
# Jaws 3
# Jaws: The Revenge
# My Heroes Were Cowboys
# Safe House
# The Smart Money Woman
# Training Day
# Castle and Castle
# Dharmakshetra
# InuYasha the Movie 2: The Castle Beyond the Looking Glass
# InuYasha the Movie 3: Swords of an Honorable Ruler
# InuYasha the Movie 4: Fire on the Mystic Island
# InuYasha the Movie: Affections Touching Across Time
# Nailed It
# Naruto Shippuden the Movie: Blood Prison
# Naruto Shippûden the Movie: Bonds
# Naruto Shippûden the Movie: The Will of Fire
# Naruto Shippuden: The Movie
# Naruto Shippuden: The Movie: The Lost Tower
# Naruto the Movie 2: Legend of the Stone of Gelel
# Naruto the Movie 3: Guardians of the Crescent Moon Kingdom
# Naruto the Movie: Ninja Clash in the Land of Snow
# Nightbooks
# Numberblocks
# Raja Rasoi Aur Anya Kahaniyan
# Saved by the Bell
# Schumacher
# Stories by Rabindranath Tagore
# Too Hot To Handle: Latino
# A StoryBots Space Adventure
# Jack Whitehall: Travels with My Father
# King of Boys
# The World's Most Amazing Vacation Rentals
# You vs. Wild: Out Cold
# Yowamushi Pedal
# Little Singham - Black Shadow
# Tughlaq Durbar
# Tughlaq Durbar (Telugu)
# Firedrake the Silver Dragon
# Kate
# Lucifer
# Metal Shop Masters
# Omo Ghetto: the Saga
# Pokémon Master Journeys: The Series
# Prey
# Titipo Titipo
# Blood Brothers: Malcolm X & Muhammad Ali
# Mighty Raju
# Paradise Hills
# The Women and the Murderer
# Into the Night
# JJ+E
# Show Dogs
# The Circle
# If I Leave Here Tomorrow: A Film About Lynyrd Skynyrd
# Kid Cosmic
# Octonauts: Above & Beyond
# On the Verge
# Tobot Galaxy Detectives
# Untold: Breaking Point
# Countdown: Inspiration4 Mission to Space
# Shadow Parties
# Tayo the Little Bus
# Angamaly Diaries
# Bunk'd
# A Champion Heart
# Dive Club
# La casa de papel
# Money Heist: From Tokyo to Berlin
# Sharkdog
# Worth
# Afterlife of the Party
# Anjaam
# Bright Star
# Dhanak
# Final Account
# Gurgaon
# Here and There
# Heroes of Goo Jit Zu
# Hotel Del Luna
# In the Cut
# Luv Kushh
# Pororo - The Little Penguin
# Q-Force
# Shikara
# A Cinderella Story
# Agatha Christie's Crooked House
# An Unfinished Life
# Barbie Big City Big Dreams
# Blade Runner: The Final Cut
# Brave Animated Series
# Chappie
# Clear and Present Danger
# Cliffhanger
# Cold Mountain
# Crocodile Dundee in Los Angeles
# Dear John
# Do the Right Thing
# El patrón, radiografía de un crimen
# Extraction
# Freedom Writers
# Green Lantern
# House Party
# House Party 2
# House Party 3
# How to Be a Cowboy
# HQ Barbers
# I Got the Hook Up
# In Too Deep
# Initial D
# Janoskians: Untold and Untrue
# Kid-E-Cats
# Kuroko's Basketball
# Labyrinth
# Letters to Juliet
# Level 16
# Love Don't Cost a Thing
# Love in a Puff
# Major Dad
# Mars Attacks!
# Marshall
# My Boss's Daughter
# Mystery Men
# Oldsters
# Once Upon a Time in America
# Open Season 2
# Osmosis Jones
# Poseidon
# Rhyme & Reason
# Same Kind of Different as Me
# School of Rock
# Snervous Tyler Oakley
# Tears of the Sun
# The Blue Lagoon
# The Golden Child
# The Guns of Navarone
# The Interview
# The Nutty Professor
# The Nutty Professor II: The Klumps
# Turning Point: 9/11 and the War on Terror
# Welcome Home Roscoe Jenkins
# In the Line of Fire
# Sparking Joy
# Untold: Crime & Penalties
# Hometown Cha-Cha-Cha
# The Ingenuity of the Househusband
# 2 Alone in Paris
# Bread Barbershop
# Thimmarusu
# Wind River
# C Kkompany
# D.P.
# Deadly Sins
# EMI: Liya Hai To Chukana Padega
# He's All That
# I Heart Arlo
# King of Boys: The Return of the King
# Koi Aap Sa
# Krishna Cottage
# Kucch To Hai
# Kyaa Kool Hai Hum
# Kyaa Kool Hain Hum 3
# Kyaa Super Kool Hain Hum
# Kyo Kii... Main Jhuth Nahin Bolta
# LSD: Love, Sex Aur Dhokha
# Mission Istaanbul: Darr Ke Aagey Jeet Hai
# Once Upon a Time in Mumbaai
# Once Upon a Time in Mumbai Dobaara!
# Ragini MMS
# Ragini MMS 2
# Rebellion
# RIDE ON TIME
# SAS: Rise of the Black Swan
# Shootout at Lokhandwala
# Shor In the City
# The Dirty Picture
# Titletown High
# EDENS ZERO
# Family Reunion
# Bob Ross: Happy Accidents, Betrayal & Greed
# Clickbait
# John of God: The Crimes of a Spiritual Healer
# Motel Makeover
# Open Your Eyes
# Post Mortem: No One Dies in Skarnes
# Really Love
# The November Man
# The Old Ways
# The River Runner
# The Water Man
# Wheel of Fortune
# Count Me In
# Oggy Oggy
# Untold: Caitlyn Jenner
# Boomika
# Boomika (Hindi)
# Boomika (Malayalam)
# Boomika (Telugu)
# The Witcher: Nightmare of the Wolf
# Manifest
# Comedy Premium League
# Everything Will Be Fine
# Gunshot
# Korean Cold Noodle Rhapsody
# Man in Love
# Sweet Girl
# The Chair
# The Loud House Movie
# A Faraway Land
# Like Crazy
# Black Island
# Bombay
# Go! Go! Cory Carson
# Memories of a Murderer: The Nilsen Tapes
# Nneka The Pretty Serpent
# O Kadhal Kanmani
# Out of my league
# Pahuna
# The Defeated
# The Secret Diary of an Exchange Student
# Untold: Deal With the Devil
# Mother Goose Club
# Walk of Shame
# Rascal Does Not Dream of Bunny Girl Senpai
# The Creative Indians
# The Piano
# Unroyal
# Winx Club
# Beckett
# Brand New Cherry Flavor
# Fast & Furious Spy Racers
# Gone for Good
# Grace and Frankie
# The Kingdom
# Valeria
# AlRawabi School for Girls
# Lokillo: Nothing's the Same
# Monster Hunter: Legends of the Guild
# Bake Squad
# Brother Jekwu
# La diosa del asfalto
# Misha and the Wolves
# The Kissing Booth 3
# The Railway Man
# Gabby's Dollhouse
# I Need Romance
# Las muñecas de la mafia
# The Crowned Clown
# Untold: Malice at the Palace
# SHAMAN KING
# Quartet
# Slay
# Takizawa Kabuki ZERO 2020 The Movie
# The Paper Tigers
# Hit & Run
# Navarasa
# Quam's Money
# The Swarm
# Vivo
# Chennai Express
# City of God: 10 Years Later
# Esperando la carroza
# Lady Boss: The Jackie Collins Story
# Tango Feroz
# '76
# Aftermath
# American Masters: Inventing David Geffen
# Car Masters: Rust to Riches
# Cocaine Cowboys: The Kings of Miami
# Control Z
# Cooking With Paris
# Autumn's Concerto
# Heavy
# Ije: The Journey
# Office Girls
# Pray Away
# Shiny_Flakes: The Teenage Drug Lord
# The Prince Who Turns into a Frog
# Top Secret UFO Projects: Declassified
# Two Fathers
# You're My Destiny
# 30 Rock
# 44 Cats
# Beethoven
# Beethoven's 2nd
# Beowulf
# Boyka: Undisputed
# Catch Me If You Can
# Cloudy with a Chance of Meatballs
# Darwin’s Game
# Deep Blue Sea
# Ferris Bueller's Day Off
# Five Feet Apart
# Freedomland
# Friday Night Lights
# Good Luck Chuck
# Hunter X Hunter (2011)
# I missed you: Director's Cut
# Inception
# Magnolia
# Major Payne
# My Girl
# My Girl 2
# Open Season: Scared Silly
# Pineapple Express
# Planet 51
# Poms
# Seabiscuit
# Space Cowboys
# Team America: World Police
# The Edge of Seventeen
# The Haunting in Connecticut 2: Ghosts of Georgia
# The Last Boy Scout
# The Lincoln Lawyer
# The Losers
# The Machinist
# The Net
# The Original Kings of Comedy
# Valentine's Day
# Charmed
# The Lost Café
# The Vault
# Centaurworld
# Eyes of a Thief
# Glow Up
# I'm Glad I Did
# Khawatir
# Myth & Mogul: John DeLorean
# Outer Banks
# Pomegranates and Myrrh
# Rurouni Kenshin: The Beginning
# The Last Mercenary
# Flower Girl
# Resort to Love
# Transformers: War for Cybertron: Kingdom
# Bartkowiak
# Fantastic Fungi
# Tattoo Redo
# The Flash
# The Snitch Cartel: Origins
# All American
# Department
# Hostage House
# How to Sell Drugs Online (Fast)
# Mighty Express
# Mimi
# Plastic Cup Boyz: Laughing My Mask Off!
# The Operative
# The Walking Dead
# Wynonna Earp
# Django Unchained
# A Second Chance:  Rivals!
# African America
# Bankrolled
# Blood Red Sky
# Feels Like Ishq
# Kingdom: Ashin of the North
# Masters of the Universe: Revelation
# Revelations: The Masters of the Universe: Revelation Aftershow
# Sky Rojo
# The Last Letter From Your Lover
# The Movies That Made Us
# 9to5: The Story of a Movement
# Chhota Bheem - Dinosaur World
# Chhota Bheem - Neeli Pahaadi
# Chhota Bheem & Ganesh
# Chhota Bheem & Krishna: Mayanagari
# Chhota Bheem & Krishna: Pataliputra- City of the Dead
# Chhota Bheem And The Broken Amulet
# Chhota Bheem And The Crown of Valhalla
# Chhota Bheem and the Incan Adventure
# Chhota Bheem and The ShiNobi Secret
# Chhota Bheem Aur Hanuman
# Chhota Bheem aur Krishna
# Chhota Bheem aur Krishna vs Zimbara
# Chhota Bheem in African Safari
# Chhota Bheem Ka Roosi Romanch
# Chhota Bheem: Bheem vs Aliens
# Chhota Bheem: Dholakpur to Kathmandu
# Chhota Bheem: Dus Pe Dus
# Chhota Bheem: Journey to Petra
# Chhota Bheem: Master of Shaolin
# Chhota Bheem: The Rise of Kirmada
# Chicago Med
# Cousins
# Wannabe Courageous
# Words Bubble Up Like Soda Pop
# Sanitation Day
# Sexy Beasts
# Too Hot to Handle: Brazil
# Trollhunters: Rise of the Titans
# Milkwater
# Okupas
# Touch Your Heart
# The Tambour of Retribution
# Cosmic Sin
# 2 Weeks in Lagos
# Deep
# Explained
# Fear Street Part 3: 1666
# Johnny Test
# La ley de Herodes
# Naomi Osaka
# The Beguiled
# The Book of Henry
# The Twilight Saga: Breaking Dawn: Part 1
# The Twilight Saga: Breaking Dawn: Part 2
# The Twilight Saga: Eclipse
# The Twilight Saga: New Moon
# Twilight
# A Perfect Fit
# BEASTARS
# Cheech & Chong's Still Smokin
# Emicida: AmarElo - Live in São Paulo
# Her Private Life
# Lift Like a Girl
# My Amanda
# Never Have I Ever
# Surf's Up
# The Unknown Saint
# This Changes Everything
# A Classic Horror Story
# Gunpowder Milkshake
# Heist
# My Unorthodox Life
# Private Network: Who Killed Manuel Buendía?
# The Guide to the Perfect Family
# American Woman
# Bridgerton - The Afterparty
# Day of Destiny
# Ridley Jones
# Born to Play
# American Ultra
# The Stand-Up
# The Tour
# Atypical
# Biohackers
# Fear Street Part 2: 1978
# Finding Hubby
# How I Became a Superhero
# How to Become a Tyrant
# Last Summer
# Lee Su-geun: The Sense Coach
# Lethal Love
# Ratchet and Clank
# The Cook of Castamar
# Virgin River
# Back to Q82
# Elize Matsunaga: Once Upon a Crime
# Home Again
# Midnight Sun
# RESIDENT EVIL: Infinite Darkness
# Rock the Kasbah
# Awon Boyz
# Brick Mansions
# Cat People
# Clash
# Dogs
# Major Grom: Plague Doctor
# Mama Drama
# Tango With Me
# The Mire
# The War Next-door
# Therapy
# This Little Love Of Mine
# Three Thieves
# A Land Imagined
# Ask the StoryBots
# Between
# Chelsea
# Code Lyoko
# Colony
# Cuckoo
# Derry Girls
# Girl from Nowhere
# Good Morning Call
# Har Kisse Ke Hisse: Kaamyaab
# I AM A KILLER
# I Think You Should Leave with Tim Robinson
# Kim's Convenience
# Larva
# Marcella
# Midnight Diner: Tokyo Stories
# My Little Pony: Friendship Is Magic
# Orange Is the New Black
# Puffin Rock
# Rehmataan
# Return of the Prodigal Son
# Richie Rich
# Rise: Ini Kalilah
# Scream
# Shtisel
# Si Doel the Movie 2
# Some Assembly Required
# Tales by Light
# Terrace House: Opening New Doors
# The A List
# The New Legends of Monkey
# The Worst Witch
# Truckbhar Swapna
# Ujala
# Undercover
# Workin' Moms
# YooHoo to the Rescue
# You Are My Spring
# We the People
# Grey's Anatomy
# Big Timber
# Fear Street Part 1: 1994
# Haseen Dillruba
# Holiday on Mars
# Mortel
# RattleSnake - The Ahanna Story
# Snowpiercer
# The 8th Night
# Winchester
# 6 Bullets
# Air Force One
# Audible
# Austin Powers in Goldmember
# Austin Powers: International Man of Mystery
# Austin Powers: The Spy Who Shagged Me
# Boogie Nights
# Bureau of Magical Things
# Charlie's Angels
# Congo
# Dennis the Menace
# Dreamy Eyes
# Dynasty Warriors
# Generation 56k
# Hampstead
# Kung Fu Panda
# Kung Fu Panda 2
# Life as We Know It
# Mary Magdalene
# Masameer County
# Memoirs of a Geisha
# Midnight Run
# Mobile Suit Gundam Hathaway
# Mortal Kombat
# Mother's Day
# No Strings Attached
# Not Another Teen Movie
# Ophelia
# Pet Sematary 2
# Quarantine Tales
# Rainbow Rangers
# Red Joan
# Sailor Moon Crystal
# Seven Pounds
# She's Out of My League
# Snow Day
# Star Trek
# Stuart Little
# Sword of Trust
# Talladega Nights: The Ballad of Ricky Bobby
# The American
# The Best of Enemies
# The Game
# The Karate Kid
# The Karate Kid Part II
# The Karate Kid Part III
# The Life of David Gale
# The Long Riders
# The Queen
# The Strangers
# The Sum of All Fears
# The Tourist
# Underworld
# Underworld: Awakening
# Underworld: Rise of the Lycans
# Voiceless
# What Dreams May Come
# Why Do Fools Fall in Love
# Working Title
# Young Royals
# America: The Motion Picture
# Deranged
# Droppin' Cash: Los Angeles
# Legend of Exorcism
# Lying and Stealing
# Mommy Issues
# Prime Time
# Somos.
# Sophie: A Murder in West Cork
# The Daily Life of the Immortal King
# StarBeam
# A Way Back Home
# Killing Them Softly
# The Seven Deadly Sins
# Wanted
# Into the Wind
# Wonder Boy
# Here Comes the Rain
# The Ice Road
# Ray
# Sex/Life
# Godzilla Singular Point
# Jiva!
# Sisters on Track
# The Naked Director
# The Seventh Day
# Good on Paper
# Murder by the Coast
# The House of Flowers: The Movie
# The Parisian Agency: Exclusive Properties
# Too Hot to Handle
# Broken
# O Vendedor de Sonhos
# Osuofia in London
# Osuofia in London II
# This Is Pop
# #Selfie
# #Selfie 69
# Love Is a Story
# The Mole
# Nevertheless,
# Bangkok Love Stories: Innocence
# Black Lightning
# Call My Agent!
# Champions
# Charité at War
# Cleo & Cuquin
# Deadwind
# Gameboys Level-Up Edition
# Glee
# Hap and Leonard
# Locked Up
# Mobile Suit Gundam II: Soldiers of Sorrow
# Mobile Suit Gundam III: Encounters in Space
# Mobile Suit Gundam: Char's Counterattack
# No Time for Shame
# Pose
# REA(L)OVE
# Riverdale
# Schitt's Creek
# The Assassination of Gianni Versace
# The Judgement
# The Last Dance
# They've Gotta Have Us
# Why Are You Like This
# A Family
# Elite
# Fatherhood
# Hospital Playlist
# Jagame Thandhiram
# Kambili: The Whole 30 Yards
# Mobile Suit Gundam I
# Rurouni Kenshin: The Final
# So Not Worth It
# The Rational Life
# Ali & Ratu Ratu Queens
# Aziza
# Besieged Bread
# Black Summer
# Elite Short Stories: Carla Samuel
# Fan Girl
# Katla
# Record of Ragnarok
# Red Snow
# Silver Linings Playbook
# The Gift
# A Man For The Week End
# Biking Borders
# Elite Short Stories: Omar Ander Alexis
# Let's Eat
# Lowriders
# Millennials
# Penguin Town
# Security
# Silver Skates
# Avengers Climate Conundrum
# Beyond Evil
# Elite Short Stories: Nadia Guzmán
# FTA
# Headspace: Unwind Your Mind
# Life of Crime
# Power Rangers Dino Fury
# Rhyme Time Town
# Rogue Warfare: Death of a Nation
# Sir! No Sir!
# The American Bible Challenge
# The Reason I Jump
# Elite Short Stories: Guzmán Caye Rebe
# Metallica: Some Kind of Monster
# Picture a Scientist
# The Devil Below
# Bling Empire - The Afterparty
# Cobra Kai - The Afterparty
# Love (ft. Marriage and Divorce)
# To All the Boys: Always and Forever - The Afterparty
# LEGO Friends: The Power of Friendship
# Lupin
# Sarbath
# Skater Girl
# Trese
# Trese After Dark
# Wish Dragon
# A Haunted House 2
# Blind Intersections
# Camellia Sisters
# Copenhagen
# Locombianos
# Until Midnight
# Awake
# Confusion Na Wa
# Fresh, Fried & Crispy
# L.A.’s Finest
# Tragic Jungle
# Guru Aur Bhole
# Vampire Academy
# Newly Rich, Newly Poor
# A Private War
# Kitty Love: An Homage to Cats
# Small Chops
# Breaking Boundaries: The Science Of Our Planet
# Feel Good
# Fireplace 4K: Classic Crackling Fireplace from Fireplace for Your Home
# Fireplace 4K: Crackling Birchwood from Fireplace for Your Home
# Human: The World Within
# Sweet & Sour
# Sweet Tooth
# Trippin' with the Kandasamys
# Xtreme
# Alan Saldaña: Locked Up
# Creator's File: GOLD
# Dancing Queens
# From Stress to Happiness
# Myriam Fares: The Journey
# Pretty Guardian Sailor Moon Eternal The Movie
# Summertime
# The Girl and the Gun
# 2 Hearts
# A Perfect Ending
# American Outlaws
# And Then Came Lola
# Attack on Titan
# Battlefield Earth
# Ben & Holly's Little Kingdom
# Black Holes | The Edge of All We Know
# Bliss
# Carnaval
# Cloudburst
# Cocomelon
# Company of Heroes
# Cradle 2 the Grave
# Domestic Disturbance
# Downton Abbey
# Dream/Killer
# Felon
# Flipped
# Fools Rush In
# Gold Statue
# Happy Endings
# Hostel: Part III
# I Am Sam
# Love Jones
# Million Dollar Baby
# Mosquita y Mari
# Never Back Down 2: The Beatdown
# Ninja Assassin
# Ouran High School Host Club
# Population 436
# Racket Boys
# Seven Souls in the Skull Castle: Season Moon Jogen
# Seven Souls in the Skull Castle: Season Moon Kagen
# Sniper: Legacy
# Starsky & Hutch
# Streets of Fire
# Super Monsters: Once Upon a Rhyme
# Swordfish
# The Adventures of Sonic the Hedgehog
# The Four Seasons
# The Girl King
# The Interpreter
# The Meddler
# The Mirror Has Two Faces
# The Outlaw Josey Wales
# The Platform
# The Wedding Guest
# The Wind
# Then Came You
# Welcome Home
# Dirty John
# Bo Burnham: Inside
# One Lagos Night
# Collateral Beauty
# Dog Gone Trouble
# The Kominsky Method
# The Least Expected Day: Inside the Movistar Team 2019
# Word of Honor
# Black Space
# Blue Miracle
# Eden
# Ghost Lab
# Ragnarok
# Soy Rada: Serendipity
# The Day I lost My Shadow
# Baggio: The Divine Ponytail
# Gatao - The Last Stray
# High on the Hog: How African American Cuisine Transformed America
# JoJo's Bizarre Adventure
# Nail Bomber: Manhunt
# A Place in the Stars
# Home
# Mad for Each Other
# Master of None
# Sam Smith: Love Goes - Live at Abbey Road Studios
# 99 Songs
# 99 Songs (Tamil)
# 99 Songs (Telugu)
# Army of the Dead
# Creating an Army of the Dead
# Jurassic World Camp Cretaceous
# Strain
# The Neighbor
# 678
# Asmaa
# Hating Peter Tatchell
# Little Singham Future mein Satakli
# Special
# Spy Kids: All the Time in the World
# Taxi No. 9211
# Sabotage
# Small Town Crime
# The Last Days
# The Magic School Bus
# Who Killed Sara?
# Amy Tan: Unintended Memoir
# Sardar Ka Grandson
# Sleight
# Ahaan
# Booba: Food Puzzle
# Love or Money
# Alma Matters
# Cinema Bandi
# Ferry
# Halston
# Haunted
# I Am All Girls
# Jungle Beat: The Movie
# Love, Death & Robots
# Move to Heaven
# Table Manners
# The Mystic River
# The Strange House
# The Upshaws - The Afterparty
# The Woman in the Window
# Castlevania
# Layer Cake
# Tottaa Pataaka Item Maal
# Wave of Cinema: Filosofi Kopi
# Dance of the Forty One
# Oxygen
# The Upshaws
# Use For My Talent
# Dear Affy
# Illegal Woman
# Money, Explained
# Deadly Switch
# Mine
# Nayattu
# Sleepless
# Super Me
# Have You Ever Seen Fireflies? - Theatre Play
# In Our Mothers' Gardens
# Jupiter's Legacy
# Milestone
# Monster
# Sab Jholmaal Hai
# The Circle - The Afterparty
# Time to Dance
# Unrest
# And Tomorrow the Entire World
# Dead Man Down
# Framing John DeLorean
# Lava Ka Dhaava
# The Sons of Sam: A Descent into Darkness
# Selena: The Series
# StartUp
# The Clovehitch Killer
# Trash Truck
# Aliens Stole My Body
# Angelina Ballerina
# Au coeur des gangs
# Barney and Friends
# Best of the Best
# Dead Again in Tombstone
# Due Date
# Fun with Dick & Jane
# Green Zone
# Hachi: A Dog's Tale
# JT LeRoy
# Madagascar 3: Europe's Most Wanted
# Miniforce: Super Dino Power
# Motu Patlu in Dragon's World
# Motu Patlu in the Game of Zones
# Motu Patlu in Wonderland
# Motu Patlu: Deep Sea Adventure
# Motu Patlu: Mission Moon
# Mystic River
# Never Back Down
# S.M.A.R.T Chase
# Sitting in Limbo
# Stargate
# State of Play
# Swiped
# The Darkest Hour
# The Lovely Bones
# The Sweetest Thing
# The Whole Nine Yards
# The Whole Truth
# The Yeti Adventures
# Under Siege
# Zack and Miri Make a Porno
# Pet Stars
# Seven
# The Disciple
# The Innocent
# The Mitchells vs. The Machines
# The Strangers: Prey at Night
# The Unremarkable Juanquini
# Things Heard & Seen
# Yasuke
# Get the Grift
# Headspace Guide to Sleep
# Sexify
# August: Osage County
# Battle: Los Angeles
# Between Worlds
# Fatma
# One
# Ram Prasad Ki Tehrvi
# Shadow and Bone - The Afterparty
# Among Family
# Dedemin Fisi
# Deliha
# Düğün Dernek
# Dügün Dernek 2: Sünnet
# G.O.R.A
# Hayat Öpücügü
# Heroes: Silence and Rock & Roll
# Kara Bela
# Kocan Kadar Konus
# Kocan Kadar Konus 2: Dirilis
# Legal Hash
# Let's Fight Ghost
# My Travel Buddy
# Niyazi Gül Dörtnala
# One Like It
# Perfume Imaginary Museum “Time Warp”
# Shadow and Bone
# This Lady Called Life
# Vizontele
# HOMUNCULUS
# Life in Color with David Attenborough
# Searching For Sheela
# Stowaway
# Wild Dog
# Oloibiri
# Tell Me When
# Zero
# Izzy's Koala World
# Keymon and Nani in Space Adventure
# Motu Patlu Dino Invasion
# Motu Patlu in Octupus World
# Motu Patlu VS Robo Kids
# Rudra: Secret of the Black Moon
# Rudra: The Rise of King Pharaoh
# Free to Play
# Luis Miguel - The Series
# Miss Sloane
# PJ Masks
# American Me
# Delhi Belly
# Dhobi Ghat (Mumbai Diaries)
# Jaane Tu... Ya Jaane Na
# Lagaan
# Madness in the Desert
# Peepli Live
# Taare Zameen Par
# Ajeeb Daastaans
# Arlo the Alligator Boy
# Bakugan: Geogan Rising
# Barbie & Chelsea: The Lost Birthday
# Crimson Peak
# Dad Stop Embarrassing Me - The Afterparty
# Doctor Bello
# Four Sisters Before the Wedding
# Into the Beat
# Love Naggers
# Rush
# Synchronic
# The Zookeeper's Wife
# Time Trap
# Tuesdays & Fridays
# Dancing Angels
# Dark City Beneath the Beat
# Durarara!!
# GANTZ:O
# Garth Brooks: The Road I’m On
# Gilmore Girls
# High-Rise Invasion
# Next in Fashion
# Only Mine
# Peasants Rebellion
# Power Players
# Ricky Zoom
# Ride or Die
# Sonic X
# The Master
# Time Is Illmatic
# Wave of Cinema: One Day We'll Talk About Today
# Zoot Suit
# Ajaibnya Cinta
# Dad Stop Embarrassing Me!
# Fate: The Winx Saga
# House of Cards
# Indian Matchmaking
# Jeffrey Epstein: Filthy Rich
# Law School
# Living with Yourself
# Signal
# Slasher
# The Soul
# The Underclass
# Unnatural Selection
# Uppena
# Why Did You Kill Me?
# Motu Patlu in Hong Kong: Kung Fu Kings 3
# Motu Patlu in the City of Gold
# Motu Patlu Kung Fu Kings 4 The Challenge of Kung Fu Brothers
# Motu Patlu the Superheroes – Super Villains from Mars
# My Love: Six Stories of True Love
# Shiva VS Autobots
# Shiva: Journey to Plunotaria
# Shiva: The Secret World Of Vedas City
# The Baker and the Beauty
# New Gods: Nezha Reborn
# Nicky, Ricky, Dicky & Dawn
# Don't be the First one
# The Stand-In
# Heaven Official's Blessing
# Night in Paradise
# Ojukokoro: Greed
# Roohi
# Thunder Force
# Two Distant Strangers
# Story of Kale: When Someone's in Love
# The Way of the Househusband
# Dolly Parton: A MusiCares Tribute
# The Big Day
# The Wedding Coach
# This Is a Robbery: The World's Biggest Art Heist
# The Last Kids on Earth: Happy Apocalypse to You
# Coded Bias
# Mandela
# The Fisherman's Diary
# What Lies Below
# Escape from Planet Earth
# Accepted
# Air Strike
# An American Girl: McKenna Shoots for the Stars
# Concrete Cowboy
# Cross: Rise of the Villains
# God Calling
# Irul
# Just Say Yes
# Madame Claude
# Wild Child
# Woody Woodpecker
# 2012
# 3 Idiots
# Ferrari Ki Sawaari
# Glimpses of a Future
# Ibrahim a Fate to Define
# Insidious
# Into the Grizzly Maze
# Kingsglaive: Final Fantasy XV
# Legally Blonde
# Madam Chief Minister
# Magical Andes
# Maximum Risk
# Murder Maps
# My Fair Lady
# Prank Encounters
# S.W.A.T.: Under Siege
# Secrets of Great British Castles
# Seven Souls in the Skull Castle: Season Bird
# Seven Souls in the Skull Castle: Season Flower
# Seven Souls in the Skull Castle: Season Wind
# Sniper: Ghost Shooter
# Starship Troopers: Traitor of Mars
# Takers
# Tersanjung the Movie
# The Knight and the Princess
# The Pianist
# The Stepfather
# Universal Soldier: The Return
# Wazir
# White Boy
# Worn Stories
# Yes Man
# At Eternity's Gate
# Haunted: Latin America
# Not a Game
# Robocar Poli
# Yu-Gi-Oh!
# 7 Yards: The Chris Norton Story
# Octonauts & the Ring of Fire
# Rainbow High
# Mandela: Long Walk to Freedom
# Lawless
# Marked
# A Week Away
# Bad Trip
# Big Time Rush
# Black Is Beltza
# Croupier
# Elizabeth and Margaret: Love and Loyalty
# Keeping the Bees
# Magic for Humans Spain
# Ni de coña
# Pagglait
# The Irregulars
# Caught by a Wave
# DOTA: Dragon's Blood
# Pui Pui Molcar
# Secret Magic Control Agency
# Seaspiracy
# Loyiso Gola: Unlearning
# Men on a Mission
# Navillera
# Philomena
# Any Crybabies Around?
# Hospital
# Jiu Jitsu
# Mighty Morphin Power Rangers
# Alien TV
# Country Comfort
# Formula 1: Drive to Survive
# Reframe THEATER EXPERIENCE with you
# The Yin Yang Master
# Who's the Boss
# B: The Beginning
# Deadly Illusions
# Get the Goat
# Nate Bargatze: The Greatest Average American
# Skylines
# The Fluffy Movie
# The Present
# Wave of Cinema: 90's Generation
# Catch.er
# Operation Varsity Blues: The College Admissions Scandal
# Under Suspicion: Uncovering the Wesphael Case
# Get on Up
# RebellComedy: Straight Outta the Zoo
# Savages
# Waffles + Mochi
# Abla Fahita: Drama Queen
# C/O Kaadhal
# The BFG
# The Last Blockbuster
# The Lost Pirate Kingdom
# Zero Chill
# Audrey
# Çarsi Pazar
# Just In Time
# Love Alarm
# Mucize
# Paper Lives
# Paradise PD
# Quiet
# Romantik Komedi
# Romantik Komedi 2: Bekarlığa Veda
# The One
# YES DAY
# You're Everything To Me
# Coven of Sisters
# Generasi 90an: Melankolia
# The Block Island Sound
# Dealer
# Last Chance U: Basketball
# Marriage or Mortgage
# The Houseboat
# Bombay Begums
# Bombay Rose
# My Way
# Aelay
# City of Ghosts
# Dogwashers
# Fate of Alakada
# Nevenka: Breaking the Silence
# Pokémon Journeys: The Series
# Sentinelle
# Mariposa
# Pacific Rim: The Black
# Parker
# Safe Haven
# Moxie
# Murder Among the Mormons
# Black or White
# Indoo Ki Jawani
# Word Party
# A Perfect Day For Arsenide
# Banyuki
# Biggie: I Got a Story to Tell
# Blanche Gardin: The All-Nighter
# Connected
# Dances with Wolves
# How to Be Really Bad
# LEGO Marvel Spider-Man: Vexed by Venom
# Rain Man
# Seven Souls in the Skull Castle 2011
# Tenacious D in The Pick of Destiny
# TIGER & BUNNY
# Bigfoot Family
# Captain Fantastic
# Crazy About Her
# Fuga
# Ginny & Georgia - The Afterparty
# No Escape
# Our Idiot Brother
# The Girl on the Train
# Tony Manero
# Who Am I
# El final del paraíso
# Geez & Ann
# Sin senos sí hay paraíso
# The Last Bastion
# Age of Samurai: Battle for Japan
# Blue, Painful, Fragile
# Canine Intervention
# Ginny & Georgia
# M8 - When Death Rescues Life
# Two Sentence Horror Stories
# Brian Regan: On the Rocks
# Made You Look: A True Story About Fake Art
# Pelé
# Red
# Zindagi in Short
# The Conjuring
# The Conjuring 2
# Vincenzo
# Classmates Minus
# Fate: The Winx Saga - The Afterparty
# Operation Finale
# Wave of Cinema: Surat dari Timur
# I Care a Lot
# Love
# Perú: Tesoro escondido
# Pitta Kathalu
# Tribes of Europa
# Eeb Allay Ooo!
# Hello, Me!
# No Escape Room
# Sisyphus
# Thus Spoke Kishibe Rohan
# Amend: The Fight for America
# Behind Her Eyes
# MeatEater
# The Most Unknown
# Animals on the Loose: A You vs. Wild Movie
# Awara Paagal Deewana
# Good Girls
# The Resurrection of Gavin Stone
# Booba
# My Teacher, My Obsession
# The Crew
# Namaste Wahala
# Monsoon
# Buried by the Bernards
# Chappelle's Show
# Hate by Dani Rovira
# Mundina Nildana
# Nadiya Bakes
# To All The Boys: Always And Forever
# Xico's Journey
# Capitani
# El Chema
# Growing up and other problems
# Layla Majnun
# Middle of Nowhere
# Red Dot
# Squared Love
# This Is the Life
# Crime Scene: The Vanishing at the Cecil Hotel
# The Misadventures of Hedi and Cokeman
# The World We Make
# Five Came Back: The Reference Films
# ICarly
# War Dogs
# Monster Run
# The Sinner
# Blanche Gardin: I talk to myself
# Doob: No Bed of Roses
# Hache
# Invisible City
# Little Big Women
# Malcolm & Marie
# Space Sweepers
# Strip Down, Rise Up
# The Last Paradiso
# The Yin-Yang Master: Dream Of Eternity
# All My Friends Are Dead
# Black Beach
# Firefly Lane
# Pablo Escobar, el patrón del mal
# Power Rangers Ninja Steel
# Our Lady of San Juan, Four Centuries of Miracles
# Tiffany Haddish Presents: They Ready
# Beverly Hills Ninja
# Heartland
# Love Daily
# My Dead Ex
# Rocks
# Shutter Island
# The Bank Job
# The House Arrest of Us
# The Unsettling
# Total Drama
# Zac and Mia
# Zathura
# Zig & Sharko
# Fatima
# Hell Fest
# Below Zero
# Finding ‘Ohana
# The Dig
# We Are: The Brooklyn Saints
# June & Kopi
# 50M2
# Accomplice
# BONDING
# Kilometers and Kilometers
# Outlander
# Penguin Bloom
# Black Rose
# Go Dog Go
# Hire a Woman
# She Is
# Blown Away
# Busted!
# Demon Slayer: Kimetsu no Yaiba
# So My Grandma’s a Lesbian!
# The Next Three Days
# The White Tiger
# Friendsgiving
# The Shadow of Violence
# Cut Throat City
# Daughter From Another Mother
# Sightless
# Spycraft
# Hello Ninja
# Homefront
# A Monster Calls
# Death of Me
# Radium Girls
# Bling Empire
# Carmen Sandiego
# Disenchantment
# Double Dad
# Henry Danger
# Outside the Wire
# Penguins of Madagascar: The Movie
# Pinkfong & Baby Shark's Space Adventure
# The Magicians
# The Vanished
# Tribhanga - Tedhi Medhi Crazy
# What Would Sophia Loren Do?
# Wish You
# Tanda Tanya
# The Heartbreak Club
# An Imperfect Murder
# Night Stalker: The Hunt for a Serial Killer
# Al acecho
# Chris Rock Total Blackout: The Tamborine Extended Cut
# Last Tango in Halifax
# Crack: Cocaine, Corruption & Conspiracy
# The Intouchables
# Apaharan
# BluffMaster!
# Charming
# Creating The Queen's Gambit
# Gangaajal
# Inside the World’s Toughest Prisons
# Is Love Enough? Sir
# Mighty Little Bheem: Kite Festival
# Pretend It’s a City
# Stuck Apart
# The Idhun Chronicles
# 100% Halal
# Leap!
# Pieces of a Woman
# Ratones Paranoicos: The Band that Rocked Argentina
# Surviving Death
# Tony Parker: The Final Shot
# History of Swear Words
# Nailed It! Mexico
# Hello Brother
# Korean Pork Belly Rhapsody
# QB1: Beyond the Lights
# Playing for Keeps
# Asphalt Burning
# Bad Grandpa .5
# Case 39
# Cobra Kai
# Dream Home Makeover
# Eddie Murphy: Raw
# Full Out 2: You Got This!
# Gimme Shelter
# Good Burger
# Good Hair
# Headspace Guide to Meditation
# Into the Wild
# Jenni Rivera: Mariposa de Barrio
# London Heist
# Mean Girls 2
# Monarca
# Mystic Pizza
# Running Man
# The Cat in the Hat Knows a Lot About That!
# The Creative Brain
# The Haunted Hathaways
# The Minimalists: Less Is Now
# Unknown
# What Happened to Mr. Cha?
# What's Eating Gilbert Grape
# Alaska Is a Drag
# Best of Stand-Up 2020
# Bobby Jasoos
# Chilling Adventures of Sabrina
# Tarung Sarung
# Too Handsome to Handle
# Best Leftovers Ever!
# Dare Me
# Equinox
# SanPa: Sins of the Savior
# Still Game
# The Rope Curse 2
# Transformers: War for Cybertron: Earthrise
# A Love So Beautiful
# Cops and Robbers
# Rango
# Death to 2020
# Sakho & Mangane
# DNA
# Regiment Diaries
# The Magic School Bus Rides Again In the Zone
# AK vs AK
# Bridgerton
# Isa Pa with Feelings
# We Can Be Heroes
# Bridezilla
# Cemara's Family
# Hello, Love, Goodbye
# The History of Future Folk
# The Midnight Sky
# Your Name Engraved Herein
# After We Collided
# London Hughes: To Catch a D*ck
# Lovestruck in the City
# QLIMAX THE SOURCE
# Rhyme Time Town Singalongs
# Shaun the Sheep
# Shaun the Sheep: The Farmer’s Llamas
# Timmy Time
# Ariana grande: excuse me, i love you
# The Con Is On
# Mohamed Hussein
# Rhys Nicholson Live at the Athenaeum
# Atlas Shrugged: Part II
# Diamond City
# Guest House
# Home for Christmas
# Ma Rainey's Black Bottom
# Ma Rainey's Black Bottom: A Legacy Brought to Screen
# Mukhsin
# Paava Kadhaigal
# Rabun
# Talentime
# An Unremarkable Christmas
# Braven
# Eggnoid: Love & Time Portal
# Love You to the Stars and Back
# Morphle
# Run On
# Sakaling Maging Tayo
# Schulz Saves America
# The Wedding Shaman
# Anitta: Made In Honório
# BREAK IT ALL: The History of Rock in Latin America
# Bwakaw
# How To Ruin Christmas
# Incarnate
# Lee Daniels' The Butler
# Marvel Anime: Wolverine
# Marvel Anime: X-Men
# Nocturnal Animals
# The Ripper
# Vir Das: Outside In - The Lockdown Special
# Black Ink Crew New York
# Grizzlies
# Pup Academy
# Song Exploder
# Teen Mom 2
# The Challenge
# The Professor and the Madman
# A California Christmas
# Hilda
# Tiny Pretty Things
# The Netflix Afterparty: The Best Shows of The Worst Year
# Children of Adam
# Grizzy et les Lemmings
# A Trash Truck Christmas
# Canvas
# Giving Voice
# The Mess You Leave Behind
# The Prom
# Torbaaz
# Alice in Borderland
# Funny Boy
# Futmalls.com
# Just The Way You Are
# She's the One
# The Panti Sisters
# Kalel, 15
# Masameer Classics
# Once Upon a Time
# Rose Island
# The Big Show Show
# The Expanding Universe of Ashley Garcia
# The Surgeon's Cut
# André & his olive tree
# Bobbleheads The Movie
# Emicida: AmarElo - It’s All For Yesterday
# Juman
# Mr. Iglesias
# Spirit Riding Free: Ride Along Adventure
# Super Monsters: Santa’s Super Monster Helpers
# Triple 9
# 100 Days My Prince
# Ava
# Manhunt: Deadly Games
# Room 2806: The Accusation
# Detention
# Mighty Express: A Mighty Christmas
# Bhaag Beanie Bhaag
# Big Mouth
# Captain Underpants Mega Blissmas
# Christmas Crossfire
# Kings of Jo'Burg
# Leyla Everlasting
# MANK
# The Great British Baking Show: Holidays
# You Are My Home
# Between Maybes
# Break
# Chico Bon Bon and the Very Berry Holiday
# Just Another Christmas
# Must Be... Love
# Alien Worlds
# Ari Eldjárn: Pardon My Icelandic
# Check The Store Next Door: The Next Chapter
# Fierce
# Hazel Brugger: Tropical
# 3 Days to Kill
# Angela's Christmas Wish
# Angels & Demons
# Are You The One
# Chef
# Effie Gray
# Gormiti
# Ink Master
# Monster House
# Natalie Palamides: Nate - A One Man Show
# Octonauts
# Oddbods
# Peppermint
# Quigley Down Under
# Stargate SG-1
# The Bachelorette
# The Da Vinci Code
# The Guest
# The Happytime Murders
# The Holiday Movies That Made Us
# The Repair Shop
# U-Turn
# Finding Agnes
# Rust Creek
# Spookley and the Christmas Kittens
# The 2nd
# The Uncanny Counter
# A Go! Go! Cory Carson Christmas
# Dance Dreams: Hot Chocolate Nutcracker
# Don’t Listen
# Fabulous Lives of Bollywood Wives
# Heartbreak High
# Over Christmas
# Sugar Rush Christmas
# The Beast
# The Call
# Fantastica
# Larry the Cable Guy: Remain Seated
# Mosul
# Unexpectedly Yours
# Ghosts of War
# Great Pretender
# Shawn Mendes: Live in Concert
# The Christmas Chronicles: Part Two
# Andhaghaaram
# Andhakaaram
# Before 30
# Dragons: Rescue Riders: Huttsgalor Holiday
# Hillbilly Elegy
# Notes for My Son
# Valentino
# Hard Kill
# Shawn Mendes: In Wonder
# Strongest Deliveryman
# The Suit
# Dolly Parton’s Christmas on the Square
# Machete Kills
# 40 Sticks
# Alien Xmas
# Flavorful Origins
# Heart & Soul
# If Anything Happens I Love You
# Mismatched
# The App That Stole Christmas
# Voices of Fire
# Black Friday
# Bodyguard
# Break Ke Baad
# Hawaizaada
# My Amnesia Girl
# Raman Raghav 2.0
# Singham
# TE3N
# The Princess Switch: Switched Again
# Three Words to Forever
# Well Done Abba
# Holiday Home Makeover with Mr. Christmas
# Ainu Mosir
# Kevin Hart: Zero F**ks Given
# The Boss Baby: Back in Business
# We Are the Champions
# Loving
# Whose Streets?
# A Very Country Christmas
# America's Next Top Model
# Beyblade Burst Rise
# Cloudy with a Chance of Meatballs 2
# Hometown Holiday
# Polly Pocket
# Survivor
# The Crown
# White Christmas
# Killer Cove
# American Horror Story
# Fukrey Boyzzz: Space Mein Fukrapanti
# Jingle Jangle: A Christmas Journey
# The Beginning of Life 2: Outside
# The Life Ahead
# The Minions of Midas
# A Very Special Love
# Ethos
# First Love
# Fruitvale Station
# Graceful Friends
# Ludo
# Memories of a Teenager
# Prom Night
# A Queen Is Born
# Aunty Donna's Big Ol' House of Fun
# The Liberator
# Trial 4
# We Are All For The Fatherland
# What We Wanted
# A Lion in the House
# DASH & LILY
# Bakugan: Armored Alliance
# Bakugan: Battle Planet
# Citation
# Country Ever After
# Girl's Revenge
# The Endless Trench
# The Late Bloomer
# Wrong Kind of Black
# A New York Christmas Wedding
# Alone/Together
# Carmel: Who Killed Maria Marta?
# Midnight at the Magnolia
# One More Try
# Operation Christmas Drop
# Paranormal
# A Christmas Catch
# Christmas with a Prince
# Love & Anarchy
# Miss India
# Felix Lobrecht: Hype
# MOTHER
# The Beginning of Life
# Ya no estoy aquí: Una conversación entre Guillermo del Toro y Alfonso Cuarón
# Can You Hear Me?
# Prospect
# 60 Days In
# Christmas Break-In
# Dawson's Creek
# Elf Pets: A Fox Cub’s Christmas Tale
# Elf Pets: Santa’s Reindeer Rescue
# Elliot the Littlest Reindeer
# Forged in Fire
# Leah Remini: Scientology and the Aftermath
# LEGO Jurassic World: Legend of Isla Nublar
# LEGO Jurassic World: Secret Exhibit
# LEGO Ninjago
# LEGO Ninjago: Masters of Spinjitzu
# LEGO: CITY Adventures
# Little Monsters
# Mile 22
# Piercing
# Snowden
# The Garfield Show
# The Good Detective
# The Impossible
# The Next Karate Kid
# Voice
# Wheels of Fortune
# Afronta! Facing It!
# The 12th Man
# Zumbo's Just Desserts
# Hidden in Plain Sight
# His House
# In Line
# Kaali Khuhi
# Kongsuni and Friends
# Marvel's Agents of S.H.I.E.L.D.
# Rogue City
# Somebody Feed Phil
# Suburra: Blood on Rome
# The Day of the Lord
# Pagpag: Nine Lives
# Holidate
# La Gran Ilusión
# Metallica Through The Never
# Nobody Sleeps in the Woods Tonight
# Secrets of the Saqqara Tomb
# Blood of Zeus
# Chico Bon Bon: Monkey with a Tool Belt
# Guillermo Vilas: Settling the Score
# Sarah Cooper: Everything's Fine
# The Devil Punisher
# Ajab Prem Ki Ghazab Kahani
# Black '47
# I Am Woman
# Alice Junior
# Barbarians
# Move
# Over the Moon
# Shattered Memories
# Stolen Away
# The Queen's Gambit
# Bending the Arc
# Cadaver
# Exes Baggage
# Fisherman's Friends
# The Hows of Us
# The Hummingbird Project
# Yes, God, Yes
# Brave Blue World: Racing to Solve Our Water Crisis
# My Next Guest Needs No Introduction With David Letterman
# Rebecca
# The Magic School Bus Rides Again The Frizz Connection
# Tremors: Shrieker Island
# Beirut Oh Beirut
# Bosta
# Ghadi
# Heritages
# Listen
# Out of Life
# Panoptic
# Taxi Ballad
# The Kite
# The Little Wars
# Under the Bombs
# Unsolved Mysteries
# West Beirut
# What Did I Mess
# Whispers
# Zozo
# ParaNorman
# Start-Up
# I Am Vengeance: Retaliation
# Disconnect
# Grand Army
# In a Valley of Violence
# La Révolution
# Someone Has to Die
# The Last Kids on Earth
# The Trial of the Chicago 7
# Unfriended
# A Babysitter's Guide to Monster Hunting
# Batman: The Killing Joke
# El-Khawaga's Dilemma
# Fireman Sam
# Half & Half
# Kartini: Princess of Java
# Love Like the Falling Rain
# One on One
# Power Rangers Beast Morphers
# Rooting for Roona
# Social Distance
# A Choo
# BLACKPINK: Light Up the Sky
# The Three Deaths of Marisela Escobedo
# Fida
# Octonauts & the Great Barrier Reef
# The Cabin with Bert Kreischer
# Dil
# Disco Dancer
# Hunterrr
# Kipo and the Age of Wonderbeasts
# Phir Hera Pheri
# The Legend of Bhagat Singh
# House of the Witch
# Deaf U
# Ginny Weds Sunny
# My Step Dad: The Hippie
# Super Monsters: Dia de los Monsters
# The Forty-Year-Old Version
# The Haunting of Bly Manor
# Bigflo & Oli: Hip Hop Frenzy
# Do Do Sol Sol La La Sol
# Palermo Hollywood
# Private Lives
# The 100
# Hubie Halloween
# To the Lake
# American Pie 9: Girls' Rules
# Dolly Parton: Here I Am
# StarBeam: Halloween Hero
# Walk Away from Love
# Bad Boy Billionaires: India
# David Attenborough: A Life on Our Planet
# Best Wishes, Warmest Regards: A Schitt's Creek Farewell
# Good Game: The Beginning
# Pat a Pat Como
# Qurious Como
# A Chaster Marriage
# A Go! Go! Cory Carson Halloween
# DreamWorks Happy Holidays from Madagascar
# Emily in Paris
# H2O: Just Add Water
# Òlòtūré
# Serious Men
# The Binding
# Turkish Dance School
# Vampires vs. the Bronx
# You've Got This
# All Because of You
# An Ordinary Man
# Carlos Almaraz: Playing with Fire
# Cold Harbour
# Evil
# Familiar Wife
# Food Wars!: Shokugeki no Soma
# Free State of Jones
# Good Morning, Verônica
# Human Nature
# Hunt for the Wilderpeople
# I'm Leaving Now
# Journey of an African Colony
# Oktoberfest: Beer & Blood
# Rize
# Secreto bien guardado
# Sword Art Online
# The American Game
# The Book of Sun
# The Outpost
# The Parkers
# The Unicorn
# We Have Always Lived in the Castle
# You Cannot Hide
# American Murder: The Family Next Door
# Baxu and the Giants
# Black Butler
# Man with a Plan
# Poacher
# The Boys in the Band
# The Boys in the Band: Something Personal
# Wentworth
# Bully
# Michelle Buteau: Welcome to Buteaupia
# Welcome to Sudden Death
# Amandla! A Revolution in Four Part Harmony
# Ankhon Dekhi
# Dedh Ishqiya
# Golmaal Returns
# Ishq Vishk
# Ishqiya
# Jab We Met
# Mann
# Manorama Six Feet Under
# Welcome
# Whose Vote Counts, Explained
# Van Helsing
# The Good Place
# Time Out
# A Perfect Crime
# Mighty Little Bheem
# My Mother's Wound
# Sneakerheads
# The School Nurse Files
# Zulu Man in Japan
# Real Steel
# The Chef Show
# Enola Holmes
# Kiss the Ground
# The Playbook
# A Love Song for Latasha
# DTC Yukemuri Junjo Hen From High & Low
# High & Low The Movie
# High & Low The Movie 2 / End of Sky
# High & Low The Movie 3 / Final Mission
# High & Low The Red Rain
# High & Low The Worst
# Road To High & Low
# The Blue Elephant 2
# Bhaji In Problem
# Black
# Fukrey Boyzzz
# Saheb Biwi Aur Gangster Returns
# Santa Banta Pvt Ltd
# The Royal Bengal Tiger
# Dolly Kitty Aur Woh Chamakte Sitare
# Ratched
# The American Barbecue Showdown
# The Blacklist
# Whipped
# Anaamika
# Dragon's Dogma
# GIMS: On the Record
# Horrid Henry's Gross Day Out
# Nee Enge En Anbe
# Residue
# The Last Word
# Baby
# Challenger
# Criminal: UK
# Dr Jason Leong Hashtag Blessed
# Signs
# Sing On!
# The Devil All The Time
# The Paramedic
# The Take
# Call the Midwife
# Hope Frozen: A Quest to Live Twice
# Michael McIntyre: Showman
# Raising Victor Vargas
# Taco Chronicles
# The Smurfs 2
# Wish Upon a Unicorn
# Lara and the Beat
# Buddi
# Dad Wanted
# Family Business
# Girlfriends
# How to Train Your Dragon 2
# Pets United
# The Barrier
# The Duchess
# Wonho Chung: Live in New York
# Aapla Manus
# Ani... Dr. Kashinath Ghanekar
# Bhai: Vyakti Ki Valli - Poorvardha
# Bhai: Vyakti Ki Valli - Uttarardh
# Cycle
# Dhh
# Greenleaf
# Julie and the Phantoms
# Kaagar
# Night of Knots
# PhotoCopy
# Poshter Girl
# Satria Heroes: Revenge of the Darkness
# Son Of Adam
# The Babysitter: Killer Queen
# Cargo
# Cuties
# Get Organized with The Home Edit
# La Línea: Shadow of Narco
# So Much Love to Give
# The Social Dilemma
# #Alive
# Record of Youth
# My Octopus Teacher
# Toll Booth
# Transformers: Cyberverse
# Waiting for "Superman"
# Cleverman
# Villain
# Away
# I'm Thinking of Ending Things
# Kandasamys: The Wedding
# Spirit Riding Free: Riding Academy
# The Lost Okoroshi
# You're My Boss
# Afonso Padilha: Classless
# Ave Maryam
# Love, Guaranteed
# Young Wallander
# Chef's Table: BBQ
# Freaks – You're One of Us
# Hotel for Dogs
# Sky Tour: The Movie
# The Witcher: A Look Inside the Episodes
# Adrift
# Always Be My Maybe
# Barbie Princess Adventure
# Blue Exorcist
# Bookmarks
# Borgen
# Children of the Sea
# Erased
# Fate/Grand Order -First Order-
# Felipe Esparza: Bad Decisions
# H
# Heidi
# Puss in Boots
# Sex Drive
# Sister, Sister
# Soldier
# Take the Ball, Pass the Ball
# The Boss Baby: Get That Baby!
# The Match
# The Promised Neverland
# The Smurfs
# Thomas and Friends
# True: Friendship Day
# Maniyarayile Ashokan
# The Debt Collector 2
# All Together Now
# I AM A KILLER: RELEASED
# Masaba Masaba
# Santana
# Unknown Origins
# Aggretsuko
# Edge of Seventeen
# The Bridge Curse
# The Young Messiah
# Her Mother's Killer
# Lingua Franca
# Making The Witcher
# Million Dollar Beach House
# Rising Phoenix
# Emily's Wonder Lab
# Trinkets
# Septembers of Shiraz
# Baewatch: Parental Guidance
# Ojos in d' House
# Class of '83
# Dark Forces
# Hoops
# Rust Valley Restorers
# The Sleepover
# Goedam
# John Was Trying to Contact Aliens
# Scarecrow
# The Crimes That Bind
# DeMarcus Family Rules
# High Score
# Little Singham: Kaal Ka Badla
# Drunk Parents
# Meet the In-Laws
# Crazy Awesome Teachers
# Glitch Techs
# Islands of Faith
# Les Misérables
# Seventh Son
# Stranger
# Dérè: An African Tale
# Rita
# Takki
# What's Your Raashee?
# 3%
# Beyond the Boundary: ICC Women's T20 World Cup Australia 2020
# Fearless
# Nigerian Prince
# Octonauts & the Caves of Sac Actun
# Project Power
# Teenage Bounty Hunters
# The Great Heist
# The Legend of Korra
# Zoids Wild
# An Easy Girl
# Christine
# Simon Killer
# (Un)Well
# Gunjan Saxena: The Kargil Girl
# Mr. Peabody & Sherman
# Rob Schneider: Asian Momma, Mexican Kids
# GAME ON: A Comedy Crossover Event
# Terrace House: Tokyo 2019-2020
# The Lost Husband
# Diamonds in the Sky
# The Governor
# We Summon the Darkness
# Berlin, Berlin: Lolle on the Run
# High Seas
# Selling Sunset
# Sing On! Germany
# Stars in the Sky: A Hunting Story
# The Magic School Bus Rides Again Kids In Space
# Tiny Creatures
# Wizards: Tales of Arcadia
# Word Party Songs
# Work It
# Ever After High
# Nasha Natasha
# The Rain
# Anelka: Misunderstood
# Sin City
# World's Most Wanted
# A Go! Go! Cory Carson Summer Camp
# Malibu Rescue: The Next Wave
# Mystery Lab
# Sam Jay: 3 In The Morning
# Immigration Nation
# Almost Love
# Killing Hasselhoff
# Moesha
# My Perfect Landing
# Nagi-Asu: A Lull in the Sea
# Rogue Warfare: The Hunt
# Super Monsters: The New Class
# The Next Step
# The Ottoman Lieutenant
# Toradora!
# Transformers Rescue Bots Academy
# Tumi or not Tumi
# What Keeps You Alive
# Get Even
# Latte and the Magic Waterstone
# Raat Akeli Hai
# Seriously Single
# Sugar High
# Sugar Rush
# The Umbrella Academy
# Retablo
# Transformers: War For Cybertron Trilogy
# Uma Maheswara Ugra Roopasya
# Unlucky Ploy
# It's Her Day
# Redemption
# Shine Your Eyes
# The Hater
# The Speed Cubers
# Tread
# Last Chance U
# Banana Split
# Shameless (U.S.)
# Door Ke Darshan
# Double World
# Project Marathwada
# Animal Crackers
# Dragons: Rescue Riders: Secrets of the Songwing
# Nimbe
# Offering to the Storm
# Romance Doll
# Sing On! Spain
# The Kissing Booth 2
# Sinatra: All or Nothing at All
# The Larva Island Movie
# The Letter Reader
# Fear City: New York vs The Mafia
# Norsemen
# The Remix: Hip Hop X Fashion
# Ip Man 4: The Finale
# Jack Whitehall: I'm Only Joking
# Street Food: Latin America
# Killer Women with Piers Morgan
# Funan
# Gigantosaurus
# Single Wives
# Cursed
# Father Soldier Son
# In The Dark
# Kissing Game
# The Millions
# Fatal Affair
# MILF
# Cold Feet
# Dark Desire
# Little Singham: Legend of Dugabakka
# Skin Decision: Before and After
# Sunny Bunnies
# Sylvia
# The Players
# The Business of Drugs
# Urzila Carlson: Overqualified Loser
# We Are One
# Hole in the Wall
# Dating Around: Brazil
# Down to Earth with Zac Efron
# Mama's Boy
# The Claudia Kishi Club
# The Epic Tales of Captain Underpants in Space
# The Old Guard
# The Twelve
# Your Excellency
# Japan Sinks: 2020
# The Protector
# Was It Love?
# Born Racer
# Mucho Mucho Amor: The Legend of Walter Mercado
# Stateless
# The Long Dumb Road
# Dr. Seuss' The Lorax
# Jim Jefferies: Intolerant
# A Kid from Coney Island
# PNL - Dans la légende tour
# Aiyyaa
# Bbuddah Hoga Terra Baap
# Blood Money
# Bombay Talkies
# Boss
# Budhia Singh: Born to Run
# Chashme Baddoor
# Dharam Sankat Mein
# Drishyam
# Gabbar Is Back
# Gollu Aur Pappu
# Hook
# Inkaar
# Madras Café
# Mary Kom
# Michael
# Mumbai Delhi Mumbai
# Oh My God
# One by Two
# Only
# Penalty
# Players
# Pyaar Ka Punchnama 2
# Queen
# Shaitan
# Special 26
# Tanu Weds Manu
# What the Fish
# Little Singham
# Cable Girls
# Desperados
# Hunter in the Blue Side of Manchester
# I Am Not Your Negro
# JU-ON: Origins
# Southern Survival
# The Baby-Sitters Club
# The Perfect Picture: Ten Years Later
# Supermarket Sweep
# Thiago Ventura: POKAS
# Warrior Nun
# #AnneFrank - Parallel Stories
# 21 Again
# A Touch of Green
# Abby Hatcher
# Adú
# Ali Baba ve 7 Cüceler
# David Foster: Off the Record
# Double Jeopardy
# Pek Yakında
# Say I Do
# Stardust
# The F**k-It List
# The Silence of Others
# Total Recall
# Trotro
# Under the Riccione Sun
# BNA
# George Lopez: We'll Do It For Half
# Homemade
# The Mirror Boy
# #FriendButMarried 2
# Skin
# Thackeray (Marathi)
# Dark
# Ride Like a Girl
# All For Love
# Eurovision Song Contest: The Story of Fire Saga
# Home Game
# Kasanova
# Ordinary People
# Seven (Tamil)
# Seven (Telugu)
# Thackeray (Hindi)
# Twogether
# Krishna and His Leela
# Prem Ratan Dhan Payo
# Vivah
# Athlete A
# Bulbbul
# Crazy Delicious
# Nobody Knows I'm Here
# Eric Andre: Legalize Everything
# Roswell, New Mexico
# Kappela
# The Royal Hibiscus Hotel
# It's Okay to Not Be Okay
# Woodshock
# Elevator Baby
# Babies
# Chaman Bahaar
# Destiny
# Disclosure
# Feel the Beat
# Floor Is Lava
# Lost Bullet
# Most Beautiful Thing
# One-Way to Tomorrow
# The Emigrant
# The Politician
# Wasp Network
# A Whisker Away
# Alexandria ... Why?
# Alexandria: Again and Forever
# An Egyptian Story
# Cairo Station
# Dark Waters
# El límite infinito
# Lola Igna
# One Take
# Saladin
# Stray Bullet
# The Blazing Sun
# The Land
# The Nut Job
# The Order
# An Evening with Beverly Luff Linn
# Riding Faith
# Last Flight to Abuja
# The Darkness
# The Chase
# The Show Must Go On: The Queen + Adam Lambert Story
# Underdogs
# Wira
# 4th Republic
# Alexa & Katie
# Asura Guru
# How to Get Away with Murder
# Milea
# Axone
# Da 5 Bloods
# Dating Around
# F is for Family
# Frank Elstner: Just One Last Question
# Jo Koy: In His Elements
# Okko's Inn
# ONE PIECE
# The Search
# The Woods
# From A to B
# Menahi
# Curon
# DC's Legends of Tomorrow
# Lenox Hill
# Middle Men
# My Mister
# Reality Z
# The Witch: Part 1 - The Subversion
# Before I Fall
# 365 Days
# Forensic
# Project Papa
# Queen of the South
# The Night Clerk
# 13 Reasons Why
# Before the Summer Crowds
# Big Stone Gap
# Choked: Paisa Bolta Hai
# Merry Men 2: Another Mission
# Queer Eye
# Supernatural
# The Last Days of American Crime
# The Light of My Eyes
# BAKI
# Hot Sweet Sour
# Overnight Republic
# Can’t Complain
# Lady Bird
# Spelling the Dream
# Alone
# Andaleeb El Dokki
# Let's Dance
# Life's Speed Bump
# Mr. Romantic
# My Horrible Grandma
# Sorry To Disturb
# The Student Cop
# True: Rainbow Rescue
# What's Up?
# X Large
# 122
# Cardcaptor Sakura
# Chippa
# Cook Off
# Dear My Friends
# Kalek Shanab
# Megalobox
# Midnight Diner
# Mirai
# My Shy Boss
# Revolutionary Love
# The Disaster Artist
# The Stolen
# High Strung Free Dance
# Freej Al Taibeen
# Kenny Sebastian: The Most Interesting Person in the Room
# Space Force
# The Other
# Can't Cope, Won't Cope
# Dorohedoro
# Grandmother's Farm
# Grandmother's Farm Part 2
# Intuition
# Mako Mermaids: An H2O Adventure
# I'm No Longer Here
# Hannah Gadsby: Douglas
# Ne Zha
# Supergirl
# Uncut Gems
# Betaal
# Dynasty
# One Day We'll Talk About Today
# Si Doel the Movie 3
# History 101
# Living in Bondage: Breaking Free
# Modest Heroes: Ponoc Short Films Theatre
# The Lovebirds
# Trailer Park Boys: The Animated Series
# #FriendButMarried
# Bye Bye London
# Fifty Year Old Teenager
# Lock Your Girls In
# Mujeres arriba
# Mystic Pop-up Bar
# No Longer kids
# Raya and Sakina
# Sayed the Servant
# The Married Couples
# The School of Mischief
# The Witness Who Didn't See Anything
# Anchor Baby
# Ben Platt Live from Radio City Music Hall
# Especial 20 años Fútbol de Primera
# Honeytrap
# I Will Follow
# Mutiny of the Worker Bees
# The Queen and the Conqueror
# What Are the Odds?
# Either Me Or My Auntie
# Escaping Tel Aviv
# Game Over
# Karkar
# My Sleeping Lover
# Omar & Salma 2
# Patton Oswalt: I Love Everything
# Sweet Magnolias
# Tarek's Situation
# The Beach Loafer
# Wadjda
# Zaki Chan
# Light in the Dark
# The Big Flower Fight
# Patriot Act with Hasan Minhaj
# The End
# Boys Over Flowers
# Iris
# Avatar: The Last Airbender
# Heaven Without People
# I love you, stupid
# Inhuman Resources
# Madam Secretary
# Magic for Humans
# Parasyte: The Maxim
# She-Ra and the Princesses of Power
# Sleepless Society: Two Pillows & A Lost Soul
# Strangers from Hell
# The Wiggles
# White Lines
# Dilan 1990
# Dilan 1991
# Fan of Amoory
# Malang
# Match
# Rencor tatuado
# The Delivery Boy
# Wedy Atkalam
# Fire in the Blood
# The Wrong Missy
# Ali & Alia
# True: Terrific Tales
# Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend
# Action Replayy
# Andaz Apna Apna
# Bordertown
# Have a Good Trip: Adventures in Psychedelics
# Trial By Media
# John Henry
# 18 Presents
# Dead to Me
# Restaurants on the Edge
# The Eddy
# The Hollow
# Aerials
# In Paradox
# Scissor Seven
# Si Doel the Movie
# Becoming
# Sí, Mi Amor
# Jerry Seinfeld: 23 Hours To Kill
# Arctic Dogs
# Luccas Neto em: Acampamento de Férias 2
# One Day: Justice Delivered
# Almost Happy
# Bennett's War
# Death Can Wait
# Hangar 1: The UFO Files
# Hoarders
# Lady Driver
# Mike Birbiglia: My Girlfriend's Boyfriend
# Roped
# ...
# S.W.A.T.
# Saath Saath
# Sacro GRA
# Sadece Sen
# Sadie's Last Days on Earth
# Sadma
# Sadqay Tumhare
# Saeed Mirza: The Leftist Sufi
# Safety Not Guaranteed
# Saheb Bibi Golaam
# Sairat
# Sakhi
# Salem: His Sister's Father
# Samantaral
# Samarppanam
# Sameer Abu Alneel
# Samson
# Samudri Lootere
# San Pietro
# Sanai Choughade
# Sangam
# Santa Claws
# Santa's Apprentice
# Sarah's Key
# Sardaar ji
# Sardaarji 2
# Sarivar Sari
# Sarvopari Palakkaran
# Sat Sri Akal
# Satan & Adam
# Satrangi
# Satrangi Re
# Satte Pe Satta
# Saturday Church
# Savage Dog
# Savage Raghda
# Save Our Shelter
# Saving Mr. Banks
# Saving Zoë
# Say When
# Scales: Mermaids Are Real
# Scandal
# Scandal in Sorrento
# Scary Movie
# Scary Movie 5
# Schindler's List
# School Daze
# Scooby-Doo on Zombie Island
# Scott Pilgrim vs. the World
# Scream 2
# Scream 3
# Seal Team Six: The Raid on Osama Bin Laden
# Searching for Bobby Fischer
# Searching for Sugar Man
# Season of the Witch
# Secret
# Secret Affair
# Secret in Their Eyes
# Secrets of Althorp - The Spencers
# Secrets of Chatsworth
# Secrets of Henry VIII's Palace: Hampton Court
# Secrets of Her Majesty's Secret Service
# Secrets of Highclere Castle
# Secrets of Scotland Yard
# Secrets of Selfridges
# Secrets of the Tower of London
# Secrets of Underground London
# Secrets of Westminster
# Sen Kimsin?
# Senna
# Sensitive Skin
# Septiembre, un llanto en silencio
# Servant of the People
# Set Up
# Sex and the City 2
# Sex and the City: The Movie
# Sex Doll
# Sexo, Pudor y Lagrimas
# SGT. Will Gardner
# Shadow of Truth
# Shahanpan Dega Deva
# Shaka Zulu
# Shakti: The Power
# Shanghai
# Shararat
# Shark Busters
# Shark Night
# Shaurya: It Takes Courage to Make Right... Right
# She Did That
# Shelter
# Sherlock
# Sherlock Holmes
# Shiva
# Shopkins: Chef Club
# Shopkins: Wild
# Shopkins: World Vacation
# Shorgul
# Short Term 12
# Shorts
# SHOT! The Psycho-Spiritual Mantra of Rock
# Shuddhi
# Shutter
# Sicilian Ghost Story
# Sid the Science Kid
# Siddhant
# Silencer
# Silent Hill: Revelation
# Silicon Cowboys
# Silver Spoon
# Sin senos no hay paraíso
# Sin Senos sí Hay Paraíso
# Singh Saab the Great
# Single
# Singularity
# Sinister Circle
# Siren
# Sister Code
# Skin Trade
# Skin Wars
# Skin Wars: Fresh Paint
# Skiptrace
# Sky on Fire
# Skydancers
# Skyline
# Sleeping with Other People
# Sleepover
# Sling Blade
# Sliver
# Slobby's World
# Slow West
# Small Soldiers
# Smart People
# Smash: Motorized Mayhem
# SMOSH: The Movie
# Sniper: Special Ops
# Socha Na Tha
# Social Animals
# Soekarno
# Solo Con Tu Pareja
# Solo: A Star Wars Story
# Solo: A Star Wars Story (Spanish Version)
# Solomon Kane
# Some Freaks
# Something's Gotta Give
# Son of a Gun
# Sons of Ben
# Sotus The Series
# Soul Surfer
# Soul to Keep
# Sour Grapes
# Space Racers
# Sparkle
# Spartacus
# Speech & Debate
# Speed Is My Need
# Spider-Man 3
# Spider-Man: Into the Spider-Verse
# Spitfire: The Plane that Saved the World
# Splash and Bubbles
# Spotlight
# Spring Breakers
# Sprinter
# Spy Kids
# Spy Kids 2: The Island of Lost Dreams
# Spy Kids 3: Game Over
# Spy Time
# St. Agatha
# Staged Killer
# Standoff
# Star Men
# Star Wars: Episode VIII: The Last Jedi
# Star-Crossed
# Starred Up
# Station Horizon
# Stealing History
# Step Brothers
# Step Outside
# Stephanie
# Sthaniya Sambaad
# Still
# Stink!
# Stoked
# Stone Age
# Stonehearst Asylum
# Stop at Nothing: The Lance Armstrong Story
# Storage Wars: Northern Treasures
# Story of an Egg
# Straight Up
# Strange but True
# Stranger than Fiction
# Strawberry Shortcake: Berry Bitty Adventures
# Strictly Ballroom
# Strike a Pose
# Stripes
# Striptease
# Strong Girl Bong-soon
# Stronger Than the World
# Strongland
# Stuart Little 2
# Submission
# Suburra
# Suckseed
# Sudani from Nigeria
# Suicide (Hitabdut)
# Suite Française
# Suits
# Summer Night
# Summer of '92
# Sunrise
# Super Bheem
# Super Bheem Bana Vajraveer
# Super Dark Times
# Super Nani
# Super Wings
# Superbad
# Superfly
# Superman Returns
# SuperNature: Wild Flyers
# Superstar
# Surat Dari Praha
# Surviving R. Kelly Part II: The Reckoning
# Survivors Guide to Prison
# Susanne Bartsch: On Top
# Sustainable
# Swami
# Swami Baba Ramdev: The Untold Story
# Sweeney Todd: The Demon Barber of Fleet Street
# Sweet Virginia
# Swiss Army Man
# Sword Master
# Sword Masters: Two Champions of Shaolin
# Sym-Bionic Titan
# Taal
# Tahaan
# Take Me Home Tonight
# Taken
# Tales of the City (1993)
# Tamanchey
# Tarif de nuit
# Tarzan
# Tarzan 2
# Tattah
# Tayo the Little Bus Movie: Mission Ace
# Teach Us All
# Teen Patti
# Teenage Cocktail
# Teenage Mutant Ninja Turtles
# Teenage Mutant Ninja Turtles II: The Secret of the Ooze
# Teenage Mutant Ninja Turtles: The Movie
# Tees Maar Khan
# Tellur Aliens
# Temporada de Caza
# Ten Years
# Teresa
# Terminator 3: Rise of the Machines
# Terminator Salvation
# Terra
# Terrifier
# Teshan
# Tezz
# Th Eena Meena Deeka Chase Comedy Show
# Thackeray
# That '70s Show
# The 2000s
# The 24 Hour War
# The 4th Company
# The Accountant of Auschwitz
# The Adderall Diaries
# The Adjusters
# The Adventure Club
# The Adventures of Figaro Pho
# The Adventures of Sharkboy and Lavagirl
# The Adventures of Tintin
# The Aerial
# The Age of Shadows
# The American President
# The Amityville Horror
# The Andy Griffith Show
# The Angry Birds Movie 2
# The Animal People
# The Ant's Scream
# The Apartment
# The Apostate
# The Art of the Steal
# The Art of War
# The Assignment
# The Autopsy of Jane Doe
# The Bachelor
# The Bachelors
# The Bad Education Movie
#
# The Bad Kids
# The Bare-Footed Kid
# The Basement
# The Battle of Midway
# The Beat
# The Beginning of Life: The Series
# The Bible's Buried Secrets
# The Big Catch
# The Bill Murray Stories: Life Lessons Learned From a Mythical Man
# The Black Room
# The Blackcoat's Daughter
# The Bleeder
# The Blue Planet: A Natural History of the Oceans
# The Bomb
# The Bomb Squad
# The Book of Eli
# The Boss's Daughter
# The Bounty Hunter
# The Box
# The Boy
# The Boy in the Striped Pajamas
# The Brave One
# The Brawler
# The Breadwinner
# The Break-Up
# The Bridge
# The Brothers Grimm
# The Bucket List
# The Bulbul's Nest
# The Bund
# The Bye Bye Man
# The Bygone
# The Cakemaker
# The Calling
# The Captive
# The Car
# The Carter Effect
# The Case for Christ
# The Cell
# The CEO
# The Charnel House
# The Chefs' Line
# The Chord
# The Chosen
# The Chosen Ones
# The Christmas Candle
# The Christmas Project
# The Cincinnati Kid
# The Code
# The Company Men
# The Competition
# The Confirmation
# The Congress
# The Consul's Son
# The Craft
# The Cravings
# The Croods
# The Crow
# The Cruise
# The Crying Game
# The Curse of Oak Island
# The D Train
# The Damned Rain
# The Dancer
# The Dark Crystal
# The Dark Side of Life: Mumbai City
# The Darkest Dawn
# The Daughter
# The Dawn Wall
# The Day My Butt Went Psycho!
# The Departed
# The Desert Bride
# The Detained
# The Devil and Father Amorth
# The Devil Inside
# The Devil Is a Part-Timer!
# The Devil We Know
# The Diabolical
# The Dreamer
# The Drowning
# The Drunk and on Drugs Happy Funtime Hour
# The Duel
# The Dukes of Hazzard
# The Dukes of Hazzard: The Beginning
# The Eichmann Show
# The Eighties
# The End of the Tour
# The Endless
# The Evil Dead
# The Exception
# The Eyes of My Mother
# The Fear
# The Fear of 13
# The Feels
# The Fighter
# The Figurine (Araromire)
# The Final Destination
# The First Line
# The First Temptation of Christ
# The First Wives Club
# The Five
# The Five Venoms
# The Flintstones
# The Flintstones in Viva Rock Vegas
# The Flying Guillotine
# The Forbidden Kingdom
# The Force
# The Foreigner
# The Forgotten
# The Fosters
# The Founder
# The Free Man
# The Frozen Ground
# The Furchester Hotel
# The Future of Water
# The Gathering
# The Gentleman Driver
# The Ghost Who Walks
# The Girl with the Dragon Tattoo
# The Golden Years with Javed Akhtar
# The Golem
# The Good Catholic
# The Good Neighbor
# The Goods: Live Hard, Sell Hard
# The Gospel of John
# The Gospel of Luke
# The Gospel of Mark
# The Gospel of Matthew
# The Great Battle
# The Great British Baking Show: Masterclass
# The Great Gambler
# The Great Raid
# The Great Train Robbery
# The Green Hornet
# The Guild
# The Hatred
# The Haunting of Molly Hartley
# The Healer
# The Heat: A Kitchen (R)evolution
# The Help
# The Heretics
# The Heroes of Evil
# The Heyday of the Insensitive Bastards
# The Hollow Point
# The Holy Man
# The Homecoming
# The House on Coco Road
# The House That Made Me
# The Human Factor: The Untold Story of the Bombay Film Orchestras
# The Humanity Bureau
# The Hundred-Foot Journey
# The Hunt
# The Hurricane Heist
# The Hurt Business
# The Imaginarium of Doctor Parnassus
# The Inbetweeners
# The Incident
# The Incredible Story of the Giant Pear
# The Incredibles 2
# The Indian in the Cupboard
# The Informant!
# The Intent
# The Intent 2: The Come Up
# The Invention of Lying
# The Investigator: A British Crime Story
# The Invitation
# The Irish Mob
# The Iron Lady
# The Jack King Affair
# The Jaime Maussan Show
# The Jane Austen Book Club
# The Jungle Book
# The Jungle School
# The Keeping Hours
# The Kindness Diaries
# The King's Speech
# The L Word
# The Lady in Dignity
# The Lake House
# The Lamb
# The Land of the Enlightened
# The Last Days of Chez Nous
# The Last Exorcism
# The Last Face
# The Last Hangover
# The Last Man on the Moon
# The Last Resort
# The Last Whistle
# The Legend of 420
# The Legend of Michael Mishra
# The Liar
# The Little Hours
# The Little Mermaid
# The Little Prince
# The Lives of Others
# The Lizzie Borden Chronicles
# The Lobster
# The Lodgers
# The Long Goodbye: The Kara Tippetts Story
# The Longest Yard
# The Longshots
# The Look of Silence
# The Lord of the Rings: The Return of the King
# The Lord of the Rings: The Two Towers
# The Love Guru
# The Lovers and the Despot
# The lynx
# The Mad Monk
# The Magic Pill
# The Making of Frozen Planet
# The Man Who Would Be Polka King
# The Mask of Zorro
# The Matrix
# The Matrix Reloaded
# The Matrix Revolutions
# The Mayo Clinic
# The Mayor
# The Memphis Belle: A Story of a
#
# The Men Who Stare at Goats
# The Messengers
# The Mind of a Chef
# The Minimighty Kids
# The Ministry of Time
# The Model
# The Monster
# The Monster of Mangatiti
# The Mortified Guide
# The Most Beautiful Hands of Delhi
# The Muppets
# The Murder Detectives
# The Music of Silence
# The Naked Gun 2 1/2: The Smell of Fear
# The Naked Gun: From the Files of Police Squad!
# The Natural
# The Negro Soldier
# The Netflix Afterparty
# The New Romantic
# The Nineties
# The NSU-Complex
# The Nutcracker and the Four Realms
# The Office (U.S.)
# The One I Love
# The Only Mother To You All
# The Other Guys
# The Parole Officer
# The Pass
# The Peacemaker
# The Pelican Brief
# The Perfect Day
# The Perks of Being a Wallflower
# The Phantom of the Opera
# The Physician
# The Pink Panther
# The Pirate Fairy
# The Pirates of Somalia
# The Pirates! Band of Misfits
# The Place Beyond the Pines
# The Plan
# The Player
# The Polar Express
# The Power of Grayskull: The Definitive History of He-Man and the Masters of the Universe
# The President's Barber
# The Prince
# The Prince & Me
# The Princess and the Frog
# The Prison
# The Pursuit
# The Pursuit of Happyness
# The Push
# The Pyramid Code
# The Rainbow Troops
# The Rainmaker
# The Rap Game
# The Rat Race
# The Real Football Factories
# The Real Miyagi
# The Rebound
# The Redeemed and the Dominant: Fittest on Earth
# The Rehearsal
# The Republic of Imbaba
# The Returned
# The Rezort
# The Rift: The Dark Side of the Moon
# The Right One
# The Ring
# The Riot Club
# The River Thief
# The River Wild
# The Road to Calvary
# The Rolling Stones: Olé Olé Olé! A Trip Across Latin America
# The Roommate
# The Rover
# THE RUM DIARY
# The Runner
# The Salvation
# The Sapphires
# The Score
# The Sea of Trees
# The Search for Life in Space
# The Secret Life of Pets 2
# The Seven Five
# The Seventies
# The Shaukeens
# The Show
# The Sign of Venus
# The Signal
# The Similars
# The Sinking Of Van Der Wijck
# The Sniffer
# The Social Network
# The Space Between Us
# The Spectacular Now
# The spiral
# The Spy Next Door
# The Spy Who Fell to Earth
# The Stanford Prison Experiment
# The Story of God with Morgan Freeman
# The Story of Us with Morgan Freeman
# The Student
# The Sunshine Makers
# The Super
# The Super Mario Bros. Super Show!
# The Surrounding Game
# The Taking of Pelham 123
# The Talented Mr. Ripley
# The Texas Chainsaw Massacre
# The Thief and the Imbecile
# The Tiger Hunter
# The Tigers of Scotland
# The Time Machine
# The Time Traveler's Wife
# The Traffickers
# The Tribes of Palos Verdes
# The Trigger Effect
# The Trip to Spain
# The Trust
# The Truth About Alcohol
# The Tudors
# The Tuxedo
# The Twilight Zone (Original Series)
# The Ugly Truth
# The Unborn Child
# The Underwear
# The Universe
# The Unknown Girl
# The Unknown Known
# The Vatican Tapes
# The Vietnam War: A Film by Ken Burns and Lynn Novick
# The Walls of the Moon
# The War: A Film by Ken Burns and Lynn Novick
# The Water Diviner
# The Water Horse: Legend of the Deep
# The Waterboy
# The Wedding Curse
# The Wedding Party 2: Destination Dubai
# The West Wing
# The Witch
# The Witch Files
# The Womanizer
# The Women Who Kill Lions
# The Women's Balcony
# The Workshop
# The World Is Not Enough
# The World's Most Wanted Animal
# The Wrong Babysitter
# The Year of Happiness and Love
# The Young Offenders
# The Young Vagabond
# Theater of Life
# Theeram
# Thelonious Monk: Straight, No Chaser
# Theo Who Lived
# ThirTEEN Terrors
# This Is My Love
# This Is Not What I Expected
# This Was Tomorrow
# Thithi
# Thong Dee Fun Khao
# Thor: Ragnarok
# Thor: Tales of Asgard
# Thorne: Scaredy Cat
# Thorne: Sleepyhead
# Three
# Three-Quarters Decent
# Thumper
# Thunderbolt
# Tientsin Mystic
# Tik Tok
# Tikli and Laxmi Bomb
# Time Please
# Timeless Season
# Timeline
# Tinker Bell and the Legend of the NeverBeast
# Tinker'
# Tip the Mouse
# To Be a Miss
# To Wong Foo, Thanks for Everything! Julie Newmar
# Toast of London
# Tobot
# Tokyo Idols
# Tom and Jerry: The Magic Ring
# Tomorrow Never Dies
# Top 10 Secrets and Mysteries
# Top Grier
# Tope: The Bait
# Tortilla Soup
# Total Frat Movie
# Towies
# Tracers
# Traffic Signal
# Train of the Dead
# Train to Busan
# Trainspotting
# Traitor
# Transcendence
# Trash
# Trash Fire
# Treasures from the Wreck of the Unbelievable
# Tree Man
# Tremors
# Tremors 2: Aftershocks
# Tremors 3: Back to Perfection
# Tremors 4: The Legend Begins
# Tremors 5:  Bloodline
# Tremors 6: A Cold Day in Hell
# Trespass Against Us
# Trikal (Past, Present, Future)
# Trimurti
# Trip to Bhangarh: Asia's Most Haunted Place
# Trixie Mattel: Moving Parts
# Trophy
# Trotsky
# Troy: The Odyssey
# True Grit
# True to the Game
# Trumbo
# Tucker and Dale vs. Evil
# Tukaram
# Tunisian Victory
# Turbo
# Tusk
# Twice
# Twin Peaks
# Twinsanity
# Twirlywoos
# Twisted Trunk, Big Fat Body
# Two Graves
# Two Lovers and a Bear
# Tyke Elephant Outlaw
# Tyson
# Ugly
# Ugly Duckling
# Una
# Unaccompanied Minors
# Unacknowledged
# Under an Arctic Sky
# Under The Skin
# Undercover Grandpa
# Undercover: How to Operate Behind Enemy Lines
# Unfinished Song
# Union Leader
# Unruly Friends
# Up in the Air
# Urvi
# Used Goods
# USS Indianapolis: Men of Courage
# V for Vendetta
# V.R. Troopers
# Vantage Point
# Veerappan
# Veerey Ki Wedding
# Vegas Baby
# Viceroy's House
# Victor
# Viking Destiny
# Vikings Unearthed
# Vincent N Roxxy
# ViR: The Robot Boy
# Viswasapoorvam Mansoor
# Vitti Dandu
# Vizontele Tuuba
# Vodka Diaries
# Vroomiz
# VS.
# Waar
# Waarrior Savitri
# Waiting
# Waiting...
# Wake Up
# Wakefield
# Walk with Me
# Walking Out
# War
# War Chhod Na Yaar
# War Horse
# War on Everyone
# Warda
# Warehoused
# Wartime Portraits
# Water & Power: A California Heist
# Waterschool
# We Are Your Friends
# We Belong Together
# We Need to Talk
# We the Animals
# We, the Marines
# We're No Animals
# Weather forecast
# Weeds
# Weeds on Fire
# Weird Wonders of the World
# Welcome 2 Karachi
# Welcome to Monster High: The Origin Story
# Welcome to New York
# Welcome to Willits
# Westerplatte Resists
# Westside vs. the World
# What a Wonderful Family!
# What Happens to My Family
# What Is Love?
# What Lies Beneath
# What Makes a Psychopath?
# What Still Remains
# What's Up With Love?
# When Calls the Heart
# When Hari Got Married
# When Two Worlds Collide
# Where the Money Is
# Where's the Money
# While We're Young
# White Chamber
# White Island
# Who the F**k Is That Guy?
# Who's That Knocking at My Door?
# Who's the One
# Why Are We Getting So Fat?
# Why Knot
# Why We Fight: The Battle of Russia
# Wild Alaska
# Wild Arabia
# Wild Wild West
# Wildlife
# Williams
# Willy Wonka & the Chocolate Factory
# Winnie
# Winsanity
# Winter of Our Dreams
# Winter Sun
# Winter's Bone
# Wish I Was Here
# Wish Man
# Withdrawn
# Wolves
# Women Behind Bars
# Woodstock
# World Trade Center
# World's Busiest Cities
# World's Weirdest Homes
# Would You Rather
# Wrong No.
# Wrong Side Raju
# WWII: Report from the Aleutians
# Wyatt Earp
# XX
# XXx
# XXX: State of the Union
# Y Tu Mamá También
# Y.M.I.: Yeh Mera India
# Yaadein
# Yaara O Dildaara
# Yamla Pagla Deewana 2
# Yanda Kartavya Aahe
# يوم الدين
# Yeh Meri Family
# Yellowbird
# Yes or No
# Yes or No 2
# Yes or No 2.5
# Yo-Kai Watch
# Yo-Kai Watch: The Movie
# Yoga Hosers
# Yoko
# Yoko and His Friends
# YOM
# You Can Tutu
# You Can’t Fight Christmas
# You Carry Me
# You Changed My Life
# You Don't Mess with the Zohan
# Young Adult
# Young Tiger
# Yours, Mine and Ours
# اشتباك
# Yu-Gi-Oh! Arc-V
# Yunus Emre
# Zak Storm
# Zed Plus
# Zenda
# Zindagi Gulzar Hai
# Zinzana
# Zodiac
# Zombie Dumb
# Zombieland
# Zoom
# Zubaan

# %% [markdown]
# <br>

# %% [markdown]
# ## 1. Updated List of Movies and TV Shows
#
# We want an updated list removes all the blank spaces in the **director** and **cast** lists from the `netflix_titles.csv`. After getting rid of the empty spaces in the lists: `netflix_director` and `netflix_cast`; we will create a dictionary that contains the `netflix_show_id`, `netflix_title`, `updated_netflix_director`, `updated_netflix_cast`, and `netflix_release_year`.

# %%
def update_movie_list():
    
    
    updated_netflix_director = []
    updated_netflix_cast = []
    netflix_dictionary = {}
    updated_movie_list = []
   

    for index in range(0, len(netflix_show_id)): 
        #print(index)
        netflix_dictionary.update({
            "ID": netflix_show_id[index],
            "Type" : netflix_type[index],
            "Title": netflix_title[index],
            "Director(s)": netflix_director[index],
            "Cast": netflix_cast[index],
            "Year Released": netflix_release_year[index]
        })
        #print(movie_dictionary)
        #print("")
    
        updated_movie_list.append(netflix_dictionary.copy())
    #print(movie_list)
    
    #This removes the dictionary if it doesn't contain a director or directors.
    updated_movie_list = [director for director in updated_movie_list if director['Director(s)'] != '']
    #This removes the dictionary if it doesn't contain any cast members.
    updated_movie_list = [cast for cast in updated_movie_list if cast['Cast'] != '']
    
    #print(movie_list)
    for dictionary in updated_movie_list:
        print(dictionary)
        print("")
         
    
update_movie_list()
# Out:
# {'ID': 2, 'Type': 'TV Show', 'Title': 'Ganglands', 'Director(s)': 'Julien Leclercq', 'Cast': 'Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera', 'Year Released': '2021'}
#
# {'ID': 5, 'Type': 'TV Show', 'Title': 'Midnight Mass', 'Director(s)': 'Mike Flanagan', 'Cast': 'Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver', 'Year Released': '2021'}
#
# {'ID': 6, 'Type': 'Movie', 'Title': 'My Little Pony: A New Generation', 'Director(s)': 'Robert Cullen, José Luis Ucha', 'Cast': 'Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr', 'Year Released': '2021'}
#
# {'ID': 7, 'Type': 'Movie', 'Title': 'Sankofa', 'Director(s)': 'Haile Gerima', 'Cast': 'Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri', 'Year Released': '1993'}
#
# {'ID': 8, 'Type': 'TV Show', 'Title': 'The Great British Baking Show', 'Director(s)': 'Andy Devonshire', 'Cast': 'Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood', 'Year Released': '2021'}
#
# {'ID': 9, 'Type': 'Movie', 'Title': 'The Starling', 'Director(s)': 'Theodore Melfi', 'Cast': "Melissa McCarthy, Chris O'Dowd, Kevin Kline, Timothy Olyphant, Daveed Diggs, Skyler Gisondo, Laura Harrier, Rosalind Chao, Kimberly Quinn, Loretta Devine, Ravi Kapoor", 'Year Released': '2021'}
#
# {'ID': 11, 'Type': 'TV Show', 'Title': 'Bangkok Breaking', 'Director(s)': 'Kongkiat Komesiri', 'Cast': 'Sukollawat Kanarot, Sushar Manaying, Pavarit Mongkolpisit, Sahajak Boonthanakit, Suthipongse Thatphithakkul, Bhasaworn Bawronkirati, Daweerit Chullasapya, Waratthaya Wongchayaporn, Kittiphoom Wongpentak, Abhicha Thanachanun, Nophand Boonyai, Kittipong Khamsat, Arisara Wongchalee, Jaytiya Naiwattanakul, Pantipa Arunwattanachai, Panupan Jantanawong, Kungtap Saelim, Phumphat Chartsuriyakiat, Issara Veranitinunt, Keerati Sivakuae, Panjai Sirisuwan, Supranee Charoenpol, Suda Chuenban, Visaka Banhansupavat, Pitchatorn Santinatornkul', 'Year Released': '2021'}
#
# {'ID': 12, 'Type': 'Movie', 'Title': 'Je Suis Karl', 'Director(s)': 'Christian Schwochow', 'Cast': 'Luna Wedler, Jannis Niewöhner, Milan Peschel, Edin Hasanović, Anna Fialová, Marlon Boess, Victor Boccard, Fleur Geffrier, Aziz Dyab, Mélanie Fouché, Elizaveta Maximová', 'Year Released': '2021'}
#
# {'ID': 13, 'Type': 'Movie', 'Title': 'Confessions of an Invisible Girl', 'Director(s)': 'Bruno Garotti', 'Cast': 'Klara Castanho, Lucca Picon, Júlia Gomes, Marcus Bessa, Kiria Malheiros, Fernanda Concon, Gabriel Lima, Caio Cabral, Leonardo Cidade, Jade Cardozo', 'Year Released': '2021'}
#
# {'ID': 18, 'Type': 'Movie', 'Title': 'Intrusion', 'Director(s)': 'Adam Salky', 'Cast': 'Freida Pinto, Logan Marshall-Green, Robert John Burke, Megan Elisabeth Kelly, Sarah Minnich, Hayes Hargrove, Mark Sivertsen, Brandon Fierro, Antonio Valles, Clint Obenchain', 'Year Released': '2021'}
#
# {'ID': 22, 'Type': 'Movie', 'Title': 'Avvai Shanmughi', 'Director(s)': 'K.S. Ravikumar', 'Cast': 'Kamal Hassan, Meena, Gemini Ganesan, Heera Rajgopal, Nassar, S.P. Balasubrahmanyam', 'Year Released': '1996'}
#
# {'ID': 23, 'Type': 'Movie', 'Title': 'Go! Go! Cory Carson: Chrissy Takes the Wheel', 'Director(s)': 'Alex Woo, Stanley Moore', 'Cast': 'Maisie Benson, Paul Killam, Kerry Gudjohnsen, AC Lim', 'Year Released': '2021'}
#
# {'ID': 24, 'Type': 'Movie', 'Title': 'Jeans', 'Director(s)': 'S. Shankar', 'Cast': 'Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi, Nassar', 'Year Released': '1998'}
#
# {'ID': 26, 'Type': 'Movie', 'Title': 'Minsara Kanavu', 'Director(s)': 'Rajiv Menon', 'Cast': 'Arvind Swamy, Kajol, Prabhu Deva, Nassar, S.P. Balasubrahmanyam, Girish Karnad', 'Year Released': '1997'}
#
# {'ID': 27, 'Type': 'Movie', 'Title': 'Grown Ups', 'Director(s)': 'Dennis Dugan', 'Cast': 'Adam Sandler, Kevin James, Chris Rock, David Spade, Rob Schneider, Salma Hayek, Maria Bello, Maya Rudolph, Colin Quinn, Tim Meadows, Joyce Van Patten', 'Year Released': '2010'}
#
# {'ID': 28, 'Type': 'Movie', 'Title': 'Dark Skies', 'Director(s)': 'Scott Stewart', 'Cast': 'Keri Russell, Josh Hamilton, J.K. Simmons, Dakota Goyo, Kadan Rockett, L.J. Benet, Rich Hutchman, Myndy Crist, Annie Thurman, Jake Brennan', 'Year Released': '2013'}
#
# {'ID': 29, 'Type': 'Movie', 'Title': 'Paranoia', 'Director(s)': 'Robert Luketic', 'Cast': 'Liam Hemsworth, Gary Oldman, Amber Heard, Harrison Ford, Lucas Till, Embeth Davidtz, Julian McMahon, Josh Holloway, Richard Dreyfuss, Angela Sarafyan', 'Year Released': '2013'}
#
# {'ID': 30, 'Type': 'Movie', 'Title': 'Ankahi Kahaniya', 'Director(s)': 'Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket Chaudhary', 'Cast': 'Abhishek Banerjee, Rinku Rajguru, Delzad Hiwale, Kunal Kapoor, Zoya Hussain, Nikhil Dwivedi, Palomi Ghosh', 'Year Released': '2021'}
#
# {'ID': 33, 'Type': 'TV Show', 'Title': 'Squid Game', 'Director(s)': 'Hwang Dong-hyuk', 'Cast': 'Lee Jung-jae, Park Hae-soo, Wi Ha-jun, Oh Young-soo, Jung Ho-yeon, Heo Sung-tae, Kim Joo-ryoung, Tripathi Anupam, You Seong-joo, Lee You-mi', 'Year Released': '2021'}
#
# {'ID': 35, 'Type': 'Movie', 'Title': 'The Father Who Moves Mountains', 'Director(s)': 'Daniel Sandu', 'Cast': 'Adrian Titieni, Elena Purea, Judith State, Valeriu Andriuță, Tudor Smoleanu, Virgil Aioanei, Radu Botar, Petronela Grigorescu, Bogdan Nechifor, Cristian Bota', 'Year Released': '2021'}
#
# {'ID': 36, 'Type': 'Movie', 'Title': 'The Stronghold', 'Director(s)': 'Cédric Jimenez', 'Cast': 'Gilles Lellouche, Karim Leklou, François Civil, Adèle Exarchopoulos, Kenza Fortas, Cyril Lecomte, Michaël Abiteboul, Idir Azougli, Vincent Darmuzey, Jean-Yves Berteloot', 'Year Released': '2021'}
#
# {'ID': 38, 'Type': 'Movie', 'Title': 'Birth of the Dragon', 'Director(s)': 'George Nolfi', 'Cast': 'Billy Magnussen, Ron Yuan, Qu Jingjing, Terry Chen, Vanness Wu, Jin Xing, Philip Ng, Xia Yu, Yu Xia', 'Year Released': '2017'}
#
# {'ID': 41, 'Type': 'Movie', 'Title': 'Jaws', 'Director(s)': 'Steven Spielberg', 'Cast': 'Roy Scheider, Robert Shaw, Richard Dreyfuss, Lorraine Gary, Murray Hamilton, Carl Gottlieb, Jeffrey Kramer, Susan Backlinie, Jonathan Filley, Ted Grossman', 'Year Released': '1975'}
#
# {'ID': 42, 'Type': 'Movie', 'Title': 'Jaws 2', 'Director(s)': 'Jeannot Szwarc', 'Cast': 'Roy Scheider, Lorraine Gary, Murray Hamilton, Joseph Mascolo, Jeffrey Kramer, Collin Wilcox Paxton, Ann Dusenberry, Mark Gruner, Barry Coe, Susan French', 'Year Released': '1978'}
#
# {'ID': 43, 'Type': 'Movie', 'Title': 'Jaws 3', 'Director(s)': 'Joe Alves', 'Cast': 'Dennis Quaid, Bess Armstrong, Simon MacCorkindale, Louis Gossett Jr., John Putch, Lea Thompson, P.H. Moriarty, Dan Blasko, Liz Morris, Lisa Maurer', 'Year Released': '1983'}
#
# {'ID': 44, 'Type': 'Movie', 'Title': 'Jaws: The Revenge', 'Director(s)': 'Joseph Sargent', 'Cast': 'Lorraine Gary, Lance Guest, Mario Van Peebles, Karen Young, Michael Caine, Judith Barsi, Mitchell Anderson, Lynn Whitfield', 'Year Released': '1987'}
#
# {'ID': 46, 'Type': 'Movie', 'Title': 'Safe House', 'Director(s)': 'Daniel Espinosa', 'Cast': 'Denzel Washington, Ryan Reynolds, Vera Farmiga, Brendan Gleeson, Sam Shepard, Rubén Blades, Nora Arnezeder, Robert Patrick, Liam Cunningham, Joel Kinnaman', 'Year Released': '2012'}
#
# {'ID': 47, 'Type': 'TV Show', 'Title': 'The Smart Money Woman', 'Director(s)': 'Bunmi Ajakaiye', 'Cast': 'Osas Ighodaro, Ini Dima-Okojie, Kemi Lala Akindoju, Toni Tones, Ebenezer Eno, Eso Okolocha DIke, Patrick Diabuah, Karibi Fubara, Temisan Emmanuel, Timini Egbuson', 'Year Released': '2020'}
#
# {'ID': 48, 'Type': 'Movie', 'Title': 'Training Day', 'Director(s)': 'Antoine Fuqua', 'Cast': 'Denzel Washington, Ethan Hawke, Scott Glenn, Tom Berenger, Harris Yulin, Raymond J. Barry, Cliff Curtis, Dr. Dre, Snoop Dogg, Macy Gray, Eva Mendes', 'Year Released': '2001'}
#
# {'ID': 51, 'Type': 'Movie', 'Title': 'InuYasha the Movie 2: The Castle Beyond the Looking Glass', 'Director(s)': 'Toshiya Shinohara', 'Cast': 'Kappei Yamaguchi, Satsuki Yukino, Mieko Harada, Koji Tsujitani, Houko Kuwashima, Kumiko Watanabe, Noriko Hidaka, Kenichi Ogata, Toshiyuki Morikawa, Izumi Ogami', 'Year Released': '2002'}
#
# {'ID': 52, 'Type': 'Movie', 'Title': 'InuYasha the Movie 3: Swords of an Honorable Ruler', 'Director(s)': 'Toshiya Shinohara', 'Cast': 'Kappei Yamaguchi, Satsuki Yukino, Koji Tsujitani, Houko Kuwashima, Kumiko Watanabe, Ken Narita, Akio Otsuka, Kikuko Inoue', 'Year Released': '2003'}
#
# {'ID': 53, 'Type': 'Movie', 'Title': 'InuYasha the Movie 4: Fire on the Mystic Island', 'Director(s)': 'Toshiya Shinohara', 'Cast': 'Kappei Yamaguchi, Satsuki Yukino, Koji Tsujitani, Houko Kuwashima, Kumiko Watanabe, Noriko Hidaka, Ken Narita, Cho, Mamiko Noto, Nobutoshi Canna', 'Year Released': '2004'}
#
# {'ID': 54, 'Type': 'Movie', 'Title': 'InuYasha the Movie: Affections Touching Across Time', 'Director(s)': 'Toshiya Shinohara', 'Cast': 'Kappei Yamaguchi, Satsuki Yukino, Koji Tsujitani, Houko Kuwashima, Kumiko Watanabe, Kenichi Ogata, Noriko Hidaka, Hisako Kyoda, Ken Narita, Tomokazu Seki', 'Year Released': '2001'}
#
# {'ID': 56, 'Type': 'Movie', 'Title': 'Naruto Shippuden the Movie: Blood Prison', 'Director(s)': 'Masahiko Murata', 'Cast': 'Junko Takeuchi, Chie Nakamura, Rikiya Koyama, Kazuhiko Inoue, Masaki Terasoma, Mie Sonozaki, Yuichi Nakamura, Kengo Kawanishi, Kosei Hirota, Masako Katsuki', 'Year Released': '2011'}
#
# {'ID': 57, 'Type': 'Movie', 'Title': 'Naruto Shippûden the Movie: Bonds', 'Director(s)': 'Hajime Kamegaki', 'Cast': 'Junko Takeuchi, Chie Nakamura, Noriaki Sugiyama, Unsho Ishizuka, Motoko Kumai, Kazuhiko Inoue, Rikiya Koyama, Showtaro Morikubo, Nana Mizuki, Satoshi Hino, Shinji Kawada', 'Year Released': '2008'}
#
# {'ID': 58, 'Type': 'Movie', 'Title': 'Naruto Shippûden the Movie: The Will of Fire', 'Director(s)': 'Masahiko Murata', 'Cast': 'Junko Takeuchi, Chie Nakamura, Kazuhiko Inoue, Satoshi Hino, Showtaro Morikubo, Kentaro Ito, Ryoka Yuzuki, Kohsuke Toriumi, Nana Mizuki, Shinji Kawada, Yoichi Masukawa, Koichi Tochika, Yukari Tamura', 'Year Released': '2009'}
#
# {'ID': 59, 'Type': 'Movie', 'Title': 'Naruto Shippuden: The Movie', 'Director(s)': 'Hajime Kamegaki', 'Cast': 'Junko Takeuchi, Chie Nakamura, Yoichi Masukawa, Koichi Tochika, Ayumi Fujimura, Keisuke Oda, Daisuke Kishio, Fumiko Orikasa, Hidetoshi Nakamura, Tetsuya Kakihara, Kisho Taniyama, Miyuki Sawashiro, Katsuyuki Konishi, Masako Katsuki, Keiko Nemoto, Masashi Ebara, Kazuhiko Inoue, Showtaro Morikubo, Romi Park, Daisuke Ono, Seizo Kato', 'Year Released': '2007'}
#
# {'ID': 60, 'Type': 'Movie', 'Title': 'Naruto Shippuden: The Movie: The Lost Tower', 'Director(s)': 'Masahiko Murata', 'Cast': 'Junko Takeuchi, Chie Nakamura, Satoshi Hino, Rikiya Koyama, Nobuaki Fukuda, Kenji Hamada, Keiko Nemoto, Saori Hayami, Yumi Toma, Yuko Kobayashi, Fujiko Takimoto, Mutsumi Tamura, Mayuki Makiguchi, Toshiyuki Morikawa', 'Year Released': '2010'}
#
# {'ID': 61, 'Type': 'Movie', 'Title': 'Naruto the Movie 2: Legend of the Stone of Gelel', 'Director(s)': 'Hirotsugu Kawasaki', 'Cast': 'Junko Takeuchi, Gamon Kaai, Chie Nakamura, Showtaro Morikubo, Akira Ishida, Yasuyuki Kase, Urara Takano, Sachiko Kojima, Houko Kuwashima, Takako Honda', 'Year Released': '2005'}
#
# {'ID': 62, 'Type': 'Movie', 'Title': 'Naruto the Movie 3: Guardians of the Crescent Moon Kingdom', 'Director(s)': 'Toshiyuki Tsuru', 'Cast': 'Junko Takeuchi, Chie Nakamura, Yoichi Masukawa, Kazuhiko Inoue, Akio Otsuka, Kyousuke Ikeda, Marika Hayashi, Umeji Sasaki, Masashi Sugawara, Hisao Egawa', 'Year Released': '2006'}
#
# {'ID': 63, 'Type': 'Movie', 'Title': 'Naruto the Movie: Ninja Clash in the Land of Snow', 'Director(s)': 'Tensai Okamura', 'Cast': 'Junko Takeuchi, Noriaki Sugiyama, Chie Nakamura, Kazuhiko Inoue, Yuhko Kaida, Tsutomu Isobe, Hirotaka Suzuoki, Jun Karasawa, Harii Kaneko, Ikuo Nishikawa', 'Year Released': '2004'}
#
# {'ID': 64, 'Type': 'Movie', 'Title': 'Nightbooks', 'Director(s)': 'David Yarovesky', 'Cast': 'Winslow Fegley, Lidya Jewett, Krysten Ritter', 'Year Released': '2021'}
#
# {'ID': 68, 'Type': 'Movie', 'Title': 'Schumacher', 'Director(s)': 'Hanns-Bruno Kammertöns, Vanessa Nöcker, Michael Wech', 'Cast': 'Michael Schumacher', 'Year Released': '2021'}
#
# {'ID': 71, 'Type': 'Movie', 'Title': 'A StoryBots Space Adventure', 'Director(s)': 'David A. Vargas', 'Cast': 'Evan Spiridellis, Erin Fitzgerald, Jeff Gill, Fred Tatasciore, Evan Michael Lee, Jared Isaacman, Sian Proctor, Chris Sembroski, Hayley Arceneaux', 'Year Released': '2021'}
#
# {'ID': 73, 'Type': 'Movie', 'Title': 'King of Boys', 'Director(s)': 'Kemi Adetiba', 'Cast': 'Sola Sobowale, Adesua Etomi, Remilekun "Reminisce" Safaru, Tobechukwu "iLLbliss" Ejiofor, Toni Tones, Paul Sambo, Jide Kosoko, Sharon Ooja', 'Year Released': '2018'}
#
# {'ID': 75, 'Type': 'Movie', 'Title': 'You vs. Wild: Out Cold', 'Director(s)': 'Ben Simms', 'Cast': 'Bear Grylls, Jason Derek Prempeh', 'Year Released': '2021'}
#
# {'ID': 77, 'Type': 'Movie', 'Title': 'Little Singham - Black Shadow', 'Director(s)': 'Prakash Satam', 'Cast': 'Sumriddhi Shukla, Jigna Bharadwaj, Sonal Kaushal, Neshma Chemburkar, Ganesh Divekar, Annamaya Verma, Anamay Verma, Manoj Pandey', 'Year Released': '2021'}
#
# {'ID': 78, 'Type': 'Movie', 'Title': 'Tughlaq Durbar', 'Director(s)': 'Delhiprasad Deenadayalan', 'Cast': 'Vijay Sethupathi, Parthiban, Raashi Khanna', 'Year Released': '2020'}
#
# {'ID': 79, 'Type': 'Movie', 'Title': 'Tughlaq Durbar (Telugu)', 'Director(s)': 'Delhiprasad Deenadayalan', 'Cast': 'Vijay Sethupathi, Parthiban, Raashi Khanna', 'Year Released': '2021'}
#
# {'ID': 80, 'Type': 'Movie', 'Title': 'Firedrake the Silver Dragon', 'Director(s)': 'Tomer Eshed', 'Cast': 'Thomas Brodie-Sangster, Felicity Jones, Freddie Highmore, Patrick Stewart, Meera Syal, Sanjeev Bhaskar, Nonso Anozie', 'Year Released': '2021'}
#
# {'ID': 81, 'Type': 'Movie', 'Title': 'Kate', 'Director(s)': 'Cedric Nicolas-Troyan', 'Cast': 'Mary Elizabeth Winstead, Jun Kunimura, Woody Harrelson, Tadanobu Asano, Miyavi, Michiel Huisman, Miku Martineau', 'Year Released': '2021'}
#
# {'ID': 84, 'Type': 'Movie', 'Title': 'Omo Ghetto: the Saga', 'Director(s)': 'JJC Skillz, Funke Akindele', 'Cast': 'Funke Akindele, Ayo Makun, Chioma Chukwuka Akpotha, Yemi Eberechi Alade, Blossom Chukwujekwu, Deyemi Okanlawon, Alexx Ekubo, Zubby Michael, Tina Mba, Femi Jacobs', 'Year Released': '2020'}
#
# {'ID': 86, 'Type': 'Movie', 'Title': 'Prey', 'Director(s)': 'Thomas Sieben', 'Cast': 'David Kross, Hanno Koffler, Maria Ehrich, Robert Finster, Yung Ngo, Klaus Steinbacher, Livia Matthes, Nellie Thalbach', 'Year Released': '2021'}
#
# {'ID': 88, 'Type': 'Movie', 'Title': 'Blood Brothers: Malcolm X & Muhammad Ali', 'Director(s)': 'Marcus Clarke', 'Cast': 'Malcolm X, Muhammad Ali', 'Year Released': '2021'}
#
# {'ID': 90, 'Type': 'Movie', 'Title': 'Paradise Hills', 'Director(s)': 'Alice Waddington', 'Cast': 'Emma Roberts, Danielle Macdonald, Awkwafina, Eiza González, Milla Jovovich, Jeremy Irvine, Arnaud Valois, Daniel Horvath', 'Year Released': '2019'}
#
# {'ID': 93, 'Type': 'Movie', 'Title': 'JJ+E', 'Director(s)': 'Alexis Almström', 'Cast': 'Elsa Öhrn, Mustapha Aarab, Jonay Pineda Skallak, Magnus Krepper, Loreen, Albin Grenholm, Simon Mezher, Elsa Bergström Terent, Josef Kadim, Yohannes Frezgi', 'Year Released': '2021'}
#
# {'ID': 94, 'Type': 'Movie', 'Title': 'Show Dogs', 'Director(s)': 'Raja Gosnell', 'Cast': "Will Arnett, Ludacris, Natasha Lyonne, Stanley Tucci, Jordin Sparks, Gabriel Iglesias, Shaquille O'Neal, Omar Chaparro, Alan Cumming, Andy Beckwith, Delia Sheppard, Kerry Shale", 'Year Released': '2018'}
#
# {'ID': 96, 'Type': 'Movie', 'Title': 'If I Leave Here Tomorrow: A Film About Lynyrd Skynyrd', 'Director(s)': 'Stephen Kijak', 'Cast': 'Ronnie Van Zandt, Gary Rossington, Allen Collins, Leon Wilkeson, Bob Burns, Billy Powell, Ed King, Artimus Pyle, Steve Gaines, Johnny Van Zant', 'Year Released': '2018'}
#
# {'ID': 103, 'Type': 'Movie', 'Title': 'Shadow Parties', 'Director(s)': 'Yemi Amodu', 'Cast': 'Jide Kosoko, Omotola Jalade-Ekeinde, Yemi Blaq, Sola Sobowale, Ken Erics, Toyin Aimakhu, Segun Arinze, Jibola Dabo, Rotimi Salami, Pa Jimi Solanke, Rachael Okonkwo, Bassey Okon, Lucien Morgan, Magdalena Korpas', 'Year Released': '2020'}
#
# {'ID': 105, 'Type': 'Movie', 'Title': 'Angamaly Diaries', 'Director(s)': 'Lijo Jose Pellissery', 'Cast': 'Antony Varghese, Reshma Rajan, Binny Rinky Benjamin, Vineeth Vishwam, Kichu Tellus, Sreekanth Dasan, Sarath Kumar, Tito Wilson, Anandhu, Bitto Davis, Sinoj Varghese', 'Year Released': '2017'}
#
# {'ID': 107, 'Type': 'Movie', 'Title': 'A Champion Heart', 'Director(s)': 'David de Vos', 'Cast': 'Mandy Grace, David de Vos, Donna Rusch, Devan Key, Isabella Mancuso, Ariana Guido', 'Year Released': '2018'}
#
# {'ID': 112, 'Type': 'Movie', 'Title': 'Worth', 'Director(s)': 'Sara Colangelo', 'Cast': 'Michael Keaton, Stanley Tucci, Amy Ryan, Shunori Ramanathan, Ato Blankson-Wood, Tate Donovan, Laura Benanti, Chris Tardio', 'Year Released': '2021'}
#
# {'ID': 113, 'Type': 'Movie', 'Title': 'Afterlife of the Party', 'Director(s)': 'Stephen Herek', 'Cast': 'Victoria Justice, Midori Francis, Robyn Scott, Adam Garcia, Timothy Renouf, Gloria Garcia, Myfanwy Waring, Spencer Sutherland', 'Year Released': '2021'}
#
# {'ID': 114, 'Type': 'Movie', 'Title': 'Anjaam', 'Director(s)': 'Rahul Rawail', 'Cast': 'Madhuri Dixit, Shah Rukh Khan, Tinnu Anand, Johny Lever, Kalpana Iyer, Himani Shivpuri, Sudha Chandran, Beena, Kiran Kumar', 'Year Released': '1994'}
#
# {'ID': 115, 'Type': 'Movie', 'Title': 'Bright Star', 'Director(s)': 'Jane Campion', 'Cast': 'Abbie Cornish, Ben Whishaw, Paul Schneider, Kerry Fox, Edie Martin, Thomas Brodie-Sangster, Claudie Blakley, Gerard Monaco, Antonia Campbell-Hughes, Samuel Roukin', 'Year Released': '2009'}
#
# {'ID': 116, 'Type': 'Movie', 'Title': 'Dhanak', 'Director(s)': 'Nagesh Kukunoor', 'Cast': 'Krrish Chhabria, Hetal Gada, Vipin Sharma, Gulfam Khan, Suresh Menon, Vijay Maurya, Rajiv Lakshman, Ninad Kamat', 'Year Released': '2015'}
#
# {'ID': 118, 'Type': 'Movie', 'Title': 'Gurgaon', 'Director(s)': 'Shanker Raman', 'Cast': 'Akshay Oberoi, Pankaj Tripathi, Ragini Khanna, Aamir Bashir, Shalini Vatsa, Ashish Verma', 'Year Released': '2017'}
#
# {'ID': 119, 'Type': 'Movie', 'Title': 'Here and There', 'Director(s)': 'JP Habac', 'Cast': 'Janine Gutierrez, JC Santos, Victor Anastacio, Yesh Burce, Lotlot De Leon', 'Year Released': '2020'}
#
# {'ID': 122, 'Type': 'Movie', 'Title': 'In the Cut', 'Director(s)': 'Jane Campion', 'Cast': 'Meg Ryan, Mark Ruffalo, Jennifer Jason Leigh, Nick Damici, Sharrieff Pugh, Kevin Bacon, Yaani King Mondschein, Heather Litteer', 'Year Released': '2003'}
#
# {'ID': 126, 'Type': 'Movie', 'Title': 'Shikara', 'Director(s)': 'Vidhu Vinod Chopra', 'Cast': 'Aadil Khan, Sadia Khateeb, Zain Khan Durrani, Priyanshu Chatterjee, Bhavna Chauhan, Ashwin Dhar, Farid Azad Khan, Saghar Sehrai', 'Year Released': '2020'}
#
# {'ID': 127, 'Type': 'Movie', 'Title': 'A Cinderella Story', 'Director(s)': 'Mark Rosman', 'Cast': 'Hilary Duff, Chad Michael Murray, Jennifer Coolidge, Dan Byrd, Regina King, Julie Gonzalo, Lin Shaye, Madeline Zima, Andrea Avery, Mary Pat Gleason, Paul Rodriguez, Whip Hubley, Kevin Kilner, Erica Hubbard, Simon Helberg', 'Year Released': '2004'}
#
# {'ID': 128, 'Type': 'Movie', 'Title': "Agatha Christie's Crooked House", 'Director(s)': 'Gilles Paquet-Brenner', 'Cast': 'Glenn Close, Terence Stamp, Max Irons, Gillian Anderson, Christina Hendricks, Stefanie Martini, Julian Sands, Honor Kneafsey, Christian McKay, Amanda Abbington', 'Year Released': '2017'}
#
# {'ID': 129, 'Type': 'Movie', 'Title': 'An Unfinished Life', 'Director(s)': 'Lasse Hallström', 'Cast': 'Robert Redford, Jennifer Lopez, Morgan Freeman, Josh Lucas, Damian Lewis, Camryn Manheim, Becca Gardner, Lynda Boyd, Rob Hayter, P. Lynn Johnson', 'Year Released': '2005'}
#
# {'ID': 130, 'Type': 'Movie', 'Title': 'Barbie Big City Big Dreams', 'Director(s)': 'Scott Pleydell-Pearce', 'Cast': 'America Young, Amber May, Giselle Fernandez, Alejandro Saab, Dinora Walcott', 'Year Released': '2021'}
#
# {'ID': 131, 'Type': 'Movie', 'Title': 'Blade Runner: The Final Cut', 'Director(s)': 'Ridley Scott', 'Cast': 'Harrison Ford, Rutger Hauer, Sean Young, Edward James Olmos, M. Emmet Walsh, Daryl Hannah, William Sanderson, Brion James, Joe Turkel, Joanna Cassidy, James Hong, Morgan Paull', 'Year Released': '1982'}
#
# {'ID': 133, 'Type': 'Movie', 'Title': 'Chappie', 'Director(s)': 'Neill Blomkamp', 'Cast': 'Sharlto Copley, Hugh Jackman, Sigourney Weaver, Dev Patel, Ninja, Yo-Landi Visser, Jose Pablo Cantillo, Brandon Auret, Johnny Selema, Maurice Carpede', 'Year Released': '2015'}
#
# {'ID': 134, 'Type': 'Movie', 'Title': 'Clear and Present Danger', 'Director(s)': 'Phillip Noyce', 'Cast': 'Harrison Ford, Willem Dafoe, Anne Archer, Joaquim de Almeida, Henry Czerny, Harris Yulin, Donald Moffat, Miguel Sandoval, Benjamin Bratt, Dean Jones, Thora Birch, James Earl Jones, Raymond Cruz', 'Year Released': '1994'}
#
# {'ID': 135, 'Type': 'Movie', 'Title': 'Cliffhanger', 'Director(s)': 'Renny Harlin', 'Cast': 'Sylvester Stallone, John Lithgow, Michael Rooker, Janine Turner, Rex Linn, Caroline Goodall, Leon, Craig Fairbrass, Ralph Waite, Max Perlich, Paul Winfield', 'Year Released': '1993'}
#
# {'ID': 136, 'Type': 'Movie', 'Title': 'Cold Mountain', 'Director(s)': 'Anthony Minghella', 'Cast': 'Jude Law, Nicole Kidman, Renée Zellweger, Eileen Atkins, Brendan Gleeson, Philip Seymour Hoffman, Natalie Portman, Giovanni Ribisi, Donald Sutherland, Ray Winstone', 'Year Released': '2003'}
#
# {'ID': 137, 'Type': 'Movie', 'Title': 'Crocodile Dundee in Los Angeles', 'Director(s)': 'Simon Wincer', 'Cast': 'Paul Hogan, Linda Kozlowski, Jere Burns, Jonathan Banks, Aida Turturro, Alec Wilson, Gerry Skilton, Steve Rackman, Serge Cockburn, Paul Rodriguez, Mark Adair-Rios, Tiriel Mora, Grant Piro, Mike Tyson', 'Year Released': '2001'}
#
# {'ID': 138, 'Type': 'Movie', 'Title': 'Dear John', 'Director(s)': 'Lasse Hallström', 'Cast': 'Channing Tatum, Amanda Seyfried, Richard Jenkins, Henry Thomas, D.J. Cotrona, Cullen Moss, Gavin McCulley, Jose Lucena Jr., Keith Robinson, Scott Porter', 'Year Released': '2010'}
#
# {'ID': 139, 'Type': 'Movie', 'Title': 'Do the Right Thing', 'Director(s)': 'Spike Lee', 'Cast': 'Danny Aiello, Ossie Davis, Ruby Dee, Richard Edson, Giancarlo Esposito, Spike Lee, Bill Nunn, John Turturro, Paul Benjamin, Frankie Faison, Samuel L. Jackson, Rosie Perez, Martin Lawrence, Miguel Sandoval', 'Year Released': '1989'}
#
# {'ID': 140, 'Type': 'Movie', 'Title': 'El patrón, radiografía de un crimen', 'Director(s)': 'Sebastián Schindel', 'Cast': 'Joaquín Furriel, Luis Ziembrowski, Guillermo Pfening, Mónica Lairana, Germán de Silva, Victoria Raposo, Andrea Garrote', 'Year Released': '2014'}
#
# {'ID': 141, 'Type': 'Movie', 'Title': 'Extraction', 'Director(s)': 'Steven C. Miller', 'Cast': 'Bruce Willis, Kellan Lutz, Gina Carano, D.B. Sweeney, Joshua Mikel, Steve Coulter, Dan Bilzerian, Heather Johansen', 'Year Released': '2015'}
#
# {'ID': 142, 'Type': 'Movie', 'Title': 'Freedom Writers', 'Director(s)': 'Richard LaGravenese', 'Cast': 'Hilary Swank, Patrick Dempsey, Scott Glenn, Imelda Staunton, April L. Hernandez, Mario, Kristin Herrera, Jaclyn Ngan, Sergio Montalvo, Jason Finn, Deance Wyatt, Vanetta Smith', 'Year Released': '2007'}
#
# {'ID': 143, 'Type': 'Movie', 'Title': 'Green Lantern', 'Director(s)': 'Martin Campbell', 'Cast': 'Ryan Reynolds, Blake Lively, Peter Sarsgaard, Mark Strong, Tim Robbins, Jay O. Sanders, Taika Waititi, Angela Bassett', 'Year Released': '2011'}
#
# {'ID': 144, 'Type': 'Movie', 'Title': 'House Party', 'Director(s)': 'Reginald Hudlin', 'Cast': 'Christopher Reid, Christopher Martin, Robin Harris, Tisha Campbell, A.J. Johnson, Martin Lawrence, Paul Anthony, Bowlegged Lou, B-Fine, Edith Fields, Kelly Jo Minter, Clifton Powell, Verda Bridges', 'Year Released': '1990'}
#
# {'ID': 145, 'Type': 'Movie', 'Title': 'House Party 2', 'Director(s)': 'George Jackson, Doug McHenry', 'Cast': 'Christopher Reid, Christopher Martin, Martin Lawrence, Bowlegged Lou, Paul Anthony, B-Fine, Tisha Campbell, Kamron, Iman, Queen Latifah', 'Year Released': '1991'}
#
# {'ID': 146, 'Type': 'Movie', 'Title': 'House Party 3', 'Director(s)': 'Eric Meza', 'Cast': 'Christopher Reid, Christopher Martin, Tisha Campbell, David Edwards, Angela Means, Ketty Lester, Bernie Mac, Michael Colyar, Chris Tucker, Khandi Alexander', 'Year Released': '1994'}
#
# {'ID': 148, 'Type': 'TV Show', 'Title': 'HQ Barbers', 'Director(s)': 'Gerhard Mostert', 'Cast': 'Hakeem Kae-Kazim, Chioma Omeruah, Orukotan Adejola, Flora Chiedo, Emeka Nwagbaraocha, Anthony Oseyemi, Oluwabukola Thomas, Soibifaa Dokubo', 'Year Released': '2020'}
#
# {'ID': 149, 'Type': 'Movie', 'Title': 'I Got the Hook Up', 'Director(s)': 'Michael Martin', 'Cast': "Master P, Anthony Johnson, Gretchen Palmer, Frantz Turner, Richard Keats, Joe Estevez, William Knight, Anthony Boswell, Tommy 'Tiny' Lister, Helen Martin, John Witherspoon, Mia X", 'Year Released': '1998'}
#
# {'ID': 150, 'Type': 'Movie', 'Title': 'In Too Deep', 'Director(s)': 'Michael Rymer', 'Cast': "Omar Epps, LL Cool J, Nia Long, Stanley Tucci, Pam Grier, Hill Harper, Jake Weber, David Patrick Kelly, Veronica Webb, Ron Canada, Robert LaSardo, Gano Grills, Ivonne Coll, Don Harvey, Mya, Nasir 'Nas' Jones, Jermaine Dupri", 'Year Released': '1999'}
#
# {'ID': 151, 'Type': 'Movie', 'Title': 'Initial D', 'Director(s)': 'Andrew Lau Wai-keung, Alan Mak', 'Cast': 'Jay Chou, Anne Suzuki, Edison Chen, Anthony Wong Chau-sang, Shawn Yue, Chapman To, Jordan Chan, Kenny Bee', 'Year Released': '2005'}
#
# {'ID': 152, 'Type': 'Movie', 'Title': 'Janoskians: Untold and Untrue', 'Director(s)': 'Brett Weiner', 'Cast': 'Jai Brooks, Luke Brooks, James Yammouni, Daniel Sahyounie, Beau Brooks', 'Year Released': '2016'}
#
# {'ID': 155, 'Type': 'Movie', 'Title': 'Labyrinth', 'Director(s)': 'Jim Henson', 'Cast': 'David Bowie, Jennifer Connelly, Frank Oz, Kevin Clash, Anthony Asbury, Dave Goelz, Brian Henson, Ron Mueck, Karen Prell, Shari Weiser', 'Year Released': '1986'}
#
# {'ID': 156, 'Type': 'Movie', 'Title': 'Letters to Juliet', 'Director(s)': 'Gary Winick', 'Cast': 'Amanda Seyfried, Christopher Egan, Gael García Bernal, Vanessa Redgrave, Franco Nero, Luisa Ranieri, Marina Massironi, Milena Vukotic, Marcia DeBonis, Luisa De Santis, Lidia Biondi, Giordano Formenti, Chris Egan', 'Year Released': '2010'}
#
# {'ID': 157, 'Type': 'Movie', 'Title': 'Level 16', 'Director(s)': 'Danishka Esterhazy', 'Cast': 'Katie Douglas, Celina Martin, Peter Outerbridge, Sara Canning, Alexis Whelan, Amalia Williamson, Josette Halpert, Kiana Madeira', 'Year Released': '2018'}
#
# {'ID': 158, 'Type': 'Movie', 'Title': "Love Don't Cost a Thing", 'Director(s)': 'Troy Byer', 'Cast': 'Nick Cannon, Christina Milian, Kenan Thompson, Kal Penn, Steve Harvey, Al Thompson, Ashley Monique Clark, Elimu Nelson, Nichole Robinson, Melissa Schuman', 'Year Released': '2003'}
#
# {'ID': 159, 'Type': 'Movie', 'Title': 'Love in a Puff', 'Director(s)': 'Pang Ho-cheung', 'Cast': 'Miriam Chin Wah Yeung, Shawn Yue, Singh Hartihan Bitto, Isabel Chan, Cheung Tat-ming, Matt Chow, Chui Tien-you, Queenie Chu, Charmaine Fong, Vincent Kok', 'Year Released': '2010'}
#
# {'ID': 161, 'Type': 'Movie', 'Title': 'Mars Attacks!', 'Director(s)': 'Tim Burton', 'Cast': 'Jack Nicholson, Glenn Close, Annette Bening, Pierce Brosnan, Danny DeVito, Martin Short, Sarah Jessica Parker, Michael J. Fox, Rod Steiger, Tom Jones, Lukas Haas, Natalie Portman', 'Year Released': '1996'}
#
# {'ID': 162, 'Type': 'Movie', 'Title': 'Marshall', 'Director(s)': 'Reginald Hudlin', 'Cast': 'Chadwick Boseman, Josh Gad, Kate Hudson, Sterling K. Brown, Dan Stevens, James Cromwell, Keesha Sharp, Roger Guenveur Smith, Derrick Baskin, Barrett Doss', 'Year Released': '2017'}
#
# {'ID': 163, 'Type': 'Movie', 'Title': "My Boss's Daughter", 'Director(s)': 'David Zucker', 'Cast': 'Ashton Kutcher, Tara Reid, Jeffrey Tambor, Andy Richter, Michael Madsen, Jon Abrahams, David Koechner, Carmen Electra, Kenan Thompson, Terence Stamp, Molly Shannon', 'Year Released': '2003'}
#
# {'ID': 164, 'Type': 'Movie', 'Title': 'Mystery Men', 'Director(s)': 'Kinka Usher', 'Cast': 'Ben Stiller, Hank Azaria, William H. Macy, Janeane Garofalo, Kel Mitchell, Paul Reubens, Wes Studi, Greg Kinnear, Geoffrey Rush, Lena Olin, Eddie Izzard, Artie Lange, Pras, Claire Forlani, Tom Waits', 'Year Released': '1999'}
#
# {'ID': 166, 'Type': 'Movie', 'Title': 'Once Upon a Time in America', 'Director(s)': 'Sergio Leone', 'Cast': 'Robert De Niro, James Woods, Elizabeth McGovern, Treat Williams, Tuesday Weld, Burt Young, Joe Pesci, Danny Aiello, William Forsythe, James Hayden', 'Year Released': '1984'}
#
# {'ID': 167, 'Type': 'Movie', 'Title': 'Open Season 2', 'Director(s)': "Matthew O'Callaghan, Todd Wilderman", 'Cast': 'Joel McHale, Mike Epps, Jane Krakowski, Billy Connolly, Crispin Glover, Steve Schirripa, Georgia Engel, Diedrich Bader, Cody Cameron, Fred Stoller, Olivia Hack', 'Year Released': '2008'}
#
# {'ID': 168, 'Type': 'Movie', 'Title': 'Osmosis Jones', 'Director(s)': 'Bobby Farrelly, Peter Farrelly', 'Cast': 'Chris Rock, Laurence Fishburne, David Hyde Pierce, Brandy Norwood, William Shatner, Ron Howard, Kid Rock, Ben Stein', 'Year Released': '2001'}
#
# {'ID': 169, 'Type': 'Movie', 'Title': 'Poseidon', 'Director(s)': 'Wolfgang Petersen', 'Cast': 'Josh Lucas, Kurt Russell, Jacinda Barrett, Richard Dreyfuss, Emmy Rossum, Mía Maestro, Mike Vogel, Kevin Dillon, Freddy Rodríguez', 'Year Released': '2006'}
#
# {'ID': 170, 'Type': 'Movie', 'Title': 'Rhyme & Reason', 'Director(s)': 'Peter Spirer', 'Cast': 'Too $hort, B-Real, Kurtis Blow, Da Brat, Grandmaster Caz, Sean "P. Diddy" Combs, Chuck D., Desiree Densiti, Dr. Dre, E-40, MC Eiht, Heavy D, Lauryn Hill, Ice-T, Wyclef Jean, Ras Kass, KRS-One, L.V., Mack 10, Craig Mack, Method Man, Keith Murray, Nasir \'Nas\' Jones, The Notorious B.I.G., Master P, Q-Tip, Raekwon, Redman, Senen Reyes, Busta Rhymes, RZA, DJ Scratch, Erick Sermon, Tupac Shakur, Adario Strange, Suave', 'Year Released': '1997'}
#
# {'ID': 171, 'Type': 'Movie', 'Title': 'Same Kind of Different as Me', 'Director(s)': 'Michael Carney', 'Cast': 'Greg Kinnear, Renée Zellweger, Djimon Hounsou, Jon Voight, Olivia Holt', 'Year Released': '2017'}
#
# {'ID': 172, 'Type': 'Movie', 'Title': 'School of Rock', 'Director(s)': 'Richard Linklater', 'Cast': 'Jack Black, Joan Cusack, Mike White, Sarah Silverman, Lee Wilkof, Kate McGregor-Stewart, Adam Pascal, Suzzanne Douglas, Miranda Cosgrove, Kevin Alexander Clark, Joey Gaydos Jr., Robert Tsai, Veronica Afflerbach, Jordan-Claire Green', 'Year Released': '2003'}
#
# {'ID': 173, 'Type': 'Movie', 'Title': 'Snervous Tyler Oakley', 'Director(s)': 'Amy Rice', 'Cast': 'Tyler Oakley', 'Year Released': '2015'}
#
# {'ID': 174, 'Type': 'Movie', 'Title': 'Tears of the Sun', 'Director(s)': 'Antoine Fuqua', 'Cast': 'Bruce Willis, Monica Bellucci, Cole Hauser, Eamonn Walker, Johnny Messner, Nick Chinlund, Charles Ingram, Paul Francis, Chad Smith, Tom Skerritt, Malick Bowens, Awaovieyi Agie', 'Year Released': '2003'}
#
# {'ID': 175, 'Type': 'Movie', 'Title': 'The Blue Lagoon', 'Director(s)': 'Randal Kleiser', 'Cast': 'Brooke Shields, Christopher Atkins, Leo McKern, William Daniels, Elva Josephson, Glenn Kohan, Alan Hopgood, Gus Mercurio', 'Year Released': '1980'}
#
# {'ID': 176, 'Type': 'Movie', 'Title': 'The Golden Child', 'Director(s)': 'Michael Ritchie', 'Cast': 'Eddie Murphy, J.L. Reate, Charles Dance, Charlotte Lewis, Victor Wong, Randall Tex Cobb, James Hong, Shakti Chen, Tau Logo, Tiger Chung Lee', 'Year Released': '1986'}
#
# {'ID': 177, 'Type': 'Movie', 'Title': 'The Guns of Navarone', 'Director(s)': 'J. Lee Thompson', 'Cast': 'Gregory Peck, David Niven, Anthony Quinn, Stanley Baker, Anthony Quayle, James Darren, Irene Papas, Gia Scala, James Robertson Justice, Richard Harris', 'Year Released': '1961'}
#
# {'ID': 178, 'Type': 'Movie', 'Title': 'The Interview', 'Director(s)': 'Evan Goldberg, Seth Rogen', 'Cast': 'James Franco, Seth Rogen, Lizzy Caplan, Randall Park, Diana Bang, Timothy Simons, Reese Alexander, James Yi', 'Year Released': '2014'}
#
# {'ID': 179, 'Type': 'Movie', 'Title': 'The Nutty Professor', 'Director(s)': 'Tom Shadyac', 'Cast': 'Eddie Murphy, Jada Pinkett Smith, James Coburn, Larry Miller, Dave Chappelle, John Ales, Patricia Wilson, Jamal Mixon', 'Year Released': '1996'}
#
# {'ID': 180, 'Type': 'Movie', 'Title': 'The Nutty Professor II: The Klumps', 'Director(s)': 'Peter Segal', 'Cast': 'Eddie Murphy, Janet Jackson, Larry Miller, John Ales, Richard Gant, Anna Maria Horsford, Melinda McGraw, Jamal Mixon, Gabriel Williams, Chris Elliott', 'Year Released': '2000'}
#
# {'ID': 182, 'Type': 'Movie', 'Title': 'Welcome Home Roscoe Jenkins', 'Director(s)': 'Malcolm D. Lee', 'Cast': "Martin Lawrence, James Earl Jones, Joy Bryant, Margaret Avery, Mike Epps, Mo'Nique, Cedric the Entertainer, Nicole Ari Parker, Michael Clarke Duncan, Louis C.K.", 'Year Released': '2008'}
#
# {'ID': 183, 'Type': 'Movie', 'Title': 'In the Line of Fire', 'Director(s)': 'Wolfgang Petersen', 'Cast': 'Clint Eastwood, John Malkovich, Rene Russo, Dylan McDermott, Gary Cole, Fred Thompson, John Mahoney, Gregory Alan Williams, Jim Curley, Sally Hughes', 'Year Released': '1993'}
#
# {'ID': 188, 'Type': 'Movie', 'Title': '2 Alone in Paris', 'Director(s)': 'Ramzy Bedia, Éric Judor', 'Cast': 'Ramzy Bedia, Éric Judor, Benoît Magimel, Kristin Scott Thomas, Élodie Bouchez, Édouard Baer, Fred Testot, Omar Sy', 'Year Released': '2008'}
#
# {'ID': 190, 'Type': 'Movie', 'Title': 'Thimmarusu', 'Director(s)': 'Sharan Koppisetty', 'Cast': 'Satya Dev, Priyanka Jawalkar, Brahmaji', 'Year Released': '2021'}
#
# {'ID': 191, 'Type': 'Movie', 'Title': 'Wind River', 'Director(s)': 'Taylor Sheridan', 'Cast': 'Jeremy Renner, Elizabeth Olsen, Jon Bernthal, Gil Birmingham, Kelsey Asbille, Tantoo Cardinal, Teo Briones, Matthew Del Negro, Hugh Dillon, Julia Jones, James Jordan, Eric Lange, Martin Sensmeier, Mason Davis, Graham Greene', 'Year Released': '2017'}
#
# {'ID': 192, 'Type': 'Movie', 'Title': 'C Kkompany', 'Director(s)': 'Sachin Yardi', 'Cast': 'Mithun Chakraborty, Tusshar Kapoor, Anupam Kher, Rajpal Yadav, Raima Sen, Dilip Prabhavalkar, Sanjay Mishra', 'Year Released': '2008'}
#
# {'ID': 195, 'Type': 'Movie', 'Title': 'EMI: Liya Hai To Chukana Padega', 'Director(s)': 'Saurabh Kabra', 'Cast': 'Sanjay Dutt, Arjun Rampal, Malaika Arora, Aashish Chaudhary, Neha Uberoi, Urmila Matondkar, Manoj Joshi, Daya Shankar Pandey, Pushkar Jog, Kulbhushan Kharbanda', 'Year Released': '2008'}
#
# {'ID': 196, 'Type': 'Movie', 'Title': "He's All That", 'Director(s)': 'Mark Waters', 'Cast': 'Addison Rae, Tanner Buchanan, Rachael Leigh Cook, Madison Pettis, Isabella Crovetti, Matthew Lillard, Peyton Meyer, Annie Jacob, Myra Molloy, Kourtney Kardashian', 'Year Released': '2021'}
#
# {'ID': 198, 'Type': 'TV Show', 'Title': 'King of Boys: The Return of the King', 'Director(s)': 'Kemi Adetiba', 'Cast': 'Sola Sobowale, Toni Tones, Richard Mofe-Damijo, Efa Iwara, Titi Kuti, Tobechukwu "iLLbliss" Ejiofor, Remilekun "Reminisce" Safaru, Charles  "Charly Boy" Oputa, Nse Ikpe-Etim, Keppy Ekpenyong Bassey, Bimbo Manuel, Akin Lewis, Lord Frank, Osas Ighodaro, Taiwo Ajai-Lycett, Paul Sambo', 'Year Released': '2021'}
#
# {'ID': 199, 'Type': 'Movie', 'Title': 'Koi Aap Sa', 'Director(s)': 'Partho Mitra', 'Cast': 'Aftab Shivdasani, Natassha, Dipannita Sharma, Himanshu Mallik, Vaidya Advai, Pushy Anand, Shama Deshpande, Rajendra Gupta', 'Year Released': '2006'}
#
# {'ID': 200, 'Type': 'Movie', 'Title': 'Krishna Cottage', 'Director(s)': 'Santram Varma', 'Cast': 'Sohail Khan, Isha Koppikar, Natassha, Rati Agnihotri, Vrajesh Hirjee, Divya Palat, Hiten Tejwani, Rajendranath Zutshi', 'Year Released': '2004'}
#
# {'ID': 201, 'Type': 'Movie', 'Title': 'Kucch To Hai', 'Director(s)': 'Anil V. Kumar, Anurag Basu', 'Cast': 'Tusshar Kapoor, Esha Deol, Natassha, Vrajesh Hirjee, Kusumit Sana, Rishi Kapoor, Moon Moon Sen, Johny Lever, Ashay Chitre, Jeetendra', 'Year Released': '2003'}
#
# {'ID': 202, 'Type': 'Movie', 'Title': 'Kyaa Kool Hai Hum', 'Director(s)': 'Sangeeth Sivan', 'Cast': 'Tusshar Kapoor, Riteish Deshmukh, Isha Koppikar, Neha Dhupia, Anupam Kher, Jay Sean', 'Year Released': '2005'}
#
# {'ID': 203, 'Type': 'Movie', 'Title': 'Kyaa Kool Hain Hum 3', 'Director(s)': 'Umesh Ghadge', 'Cast': 'Tusshar Kapoor, Aftab Shivdasani, Krishna Abhishek, Mandana Karimi, Shakti Kapoor, Darshan Jariwala, Sushmita Mukherjee, Meghna Naidu, Anand Kumar, Claudia Ciesla', 'Year Released': '2016'}
#
# {'ID': 204, 'Type': 'Movie', 'Title': 'Kyaa Super Kool Hain Hum', 'Director(s)': 'Sachin Yardi', 'Cast': 'Tusshar Kapoor, Riteish Deshmukh, Anupam Kher, Rohit Shetty, Neha Sharma, Chunky Pandey, Sarah-Jane Dias, Razak Khan, Kavin Dave', 'Year Released': '2012'}
#
# {'ID': 205, 'Type': 'Movie', 'Title': 'Kyo Kii... Main Jhuth Nahin Bolta', 'Director(s)': 'David Dhawan', 'Cast': 'Govinda, Sushmita Sen, Rambha, Anupam Kher, Satish Kaushik, Sharad Kapoor, Kiran Kumar, Mohnish Bahl', 'Year Released': '2001'}
#
# {'ID': 206, 'Type': 'Movie', 'Title': 'LSD: Love, Sex Aur Dhokha', 'Director(s)': 'Dibakar Banerjee', 'Cast': 'Nushrat Bharucha, Anshuman Jha, Neha Chauhan, Rajkummar Rao, Arya Banerjee, Amit Sial, Herry Tangri', 'Year Released': '2010'}
#
# {'ID': 207, 'Type': 'Movie', 'Title': 'Mission Istaanbul: Darr Ke Aagey Jeet Hai', 'Director(s)': 'Apoorva Lakhia', 'Cast': 'Vivek Oberoi, Zayed Khan, Shriya Saran, Nikitin Dheer, Shabbir Ahluwalia, Sunil Shetty, Shweta Bhardwaj', 'Year Released': '2008'}
#
# {'ID': 208, 'Type': 'Movie', 'Title': 'Once Upon a Time in Mumbaai', 'Director(s)': 'Milan Luthria', 'Cast': 'Ajay Devgn, Emraan Hashmi, Kangana Ranaut, Prachi Desai, Randeep Hooda, Naved Aslam, Asif Basra, Avtar Gill', 'Year Released': '2010'}
#
# {'ID': 209, 'Type': 'Movie', 'Title': 'Once Upon a Time in Mumbai Dobaara!', 'Director(s)': 'Milan Luthria', 'Cast': 'Akshay Kumar, Imran Khan, Sonakshi Sinha, Sonali Bendre, Sarfaraz Khan, Mahesh Manjrekar, Abhimanyu Singh, Kurush Deboo, Pitobash, Chetan Hansraj', 'Year Released': '2013'}
#
# {'ID': 210, 'Type': 'Movie', 'Title': 'Ragini MMS', 'Director(s)': 'Pawan Kripalani', 'Cast': 'Kainaz Motivala, Rajkummar Rao, Rajat Kaul, Janice, Shernaza, Mangala Ahire, Vinod Rawat', 'Year Released': '2011'}
#
# {'ID': 211, 'Type': 'Movie', 'Title': 'Ragini MMS 2', 'Director(s)': 'Bhushan Patel', 'Cast': 'Sunny Leone, Saahil Prem, Parvin Dabas, Sandhya Mridul, Divya Dutta, Soniya Mehra, Kainaz Motivala, Karan Mehra', 'Year Released': '2014'}
#
# {'ID': 214, 'Type': 'Movie', 'Title': 'SAS: Rise of the Black Swan', 'Director(s)': 'Magnus Martens', 'Cast': 'Sam Heughan, Ruby Rose, Andy Serkis, Hannah John-Kamen, Tom Wilkinson, Tom Hopper, Noel Clarke, Anne Reid, Owain Yeoman, Jing Lusi, Ray Panthaki, Richard McCabe, Douglas Reith', 'Year Released': '2021'}
#
# {'ID': 215, 'Type': 'Movie', 'Title': 'Shootout at Lokhandwala', 'Director(s)': 'Apoorva Lakhia', 'Cast': 'Amitabh Bachchan, Sanjay Dutt, Sunil Shetty, Arbaaz Khan, Abhishek Bachchan, Vivek Oberoi, Tusshar Kapoor, Rohit Roy, Shabbir Ahluwalia, Dia Mirza, Amrita Singh, Neha Dhupia', 'Year Released': '2007'}
#
# {'ID': 216, 'Type': 'Movie', 'Title': 'Shor In the City', 'Director(s)': 'Raj Nidimoru, Krishna D.K.', 'Cast': 'Sendhil Ramamurthy, Tusshar Kapoor, Nikhil Dwivedi, Preeti Desai, Sundeep Kishan, Radhika Apte, Pitobash, Girija Oak, Alok Chaturvedi, Sudhir Chowdhary', 'Year Released': '2011'}
#
# {'ID': 217, 'Type': 'Movie', 'Title': 'The Dirty Picture', 'Director(s)': 'Milan Luthria', 'Cast': 'Vidya Balan, Emraan Hashmi, Tusshar Kapoor, Naseeruddin Shah, Rajesh Sharma, Imran Hasnee, Anju Mahendru', 'Year Released': '2011'}
#
# {'ID': 221, 'Type': 'Movie', 'Title': 'Bob Ross: Happy Accidents, Betrayal & Greed', 'Director(s)': 'Joshua Rofé', 'Cast': 'Bob Ross', 'Year Released': '2021'}
#
# {'ID': 222, 'Type': 'TV Show', 'Title': 'Clickbait', 'Director(s)': 'Brad Anderson', 'Cast': 'Zoe Kazan, Betty Gabriel, Adrian Grenier, Phoenix Raei, Abraham Lim, Jessica Collins, Camaron Engels, Jaylin Fletcher, Liz Alexander, Joyce Guy, Daniel Henshall, Ian Meadows, Jamie Timony, Steve Mouzakis, Becca Lish', 'Year Released': '2021'}
#
# {'ID': 227, 'Type': 'Movie', 'Title': 'Really Love', 'Director(s)': 'Angel Kristi Williams', 'Cast': 'Kofi Siriboe, Yootha Wong-Loi-Sing, Michael Ealy, Uzo Aduba', 'Year Released': '2020'}
#
# {'ID': 228, 'Type': 'Movie', 'Title': 'The November Man', 'Director(s)': 'Roger Donaldson', 'Cast': 'Pierce Brosnan, Luke Bracey, Olga Kurylenko, Eliza Taylor, Caterina Scorsone, Bill Smitrovich, Will Patton, Amila Terzimehic, Lazar Ristovski, Mediha Musliovic', 'Year Released': '2014'}
#
# {'ID': 229, 'Type': 'Movie', 'Title': 'The Old Ways', 'Director(s)': 'Christopher Alender', 'Cast': 'Brigitte Kali Canales, Andrea Cortes, Julia Vera, Sal Lopez', 'Year Released': '2020'}
#
# {'ID': 231, 'Type': 'Movie', 'Title': 'The Water Man', 'Director(s)': 'David Oyelowo', 'Cast': 'David Oyelowo, Rosario Dawson, Lonnie Chavis, Amiah Miller, Alfred Molina, Maria Bello', 'Year Released': '2021'}
#
# {'ID': 236, 'Type': 'Movie', 'Title': 'Boomika', 'Director(s)': 'Rathindran R Prasad', 'Cast': 'Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madhuri, Pavel Navageethan, Avantika Vandanapu', 'Year Released': '2021'}
#
# {'ID': 237, 'Type': 'Movie', 'Title': 'Boomika (Hindi)', 'Director(s)': 'Rathindran R Prasad', 'Cast': 'Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madhuri, Pavel Navageethan, Avantika Vandanapu', 'Year Released': '2021'}
#
# {'ID': 238, 'Type': 'Movie', 'Title': 'Boomika (Malayalam)', 'Director(s)': 'Rathindran R Prasad', 'Cast': 'Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madhuri, Pavel Navageethan, Avantika Vandanapu', 'Year Released': '2021'}
#
# {'ID': 239, 'Type': 'Movie', 'Title': 'Boomika (Telugu)', 'Director(s)': 'Rathindran R Prasad', 'Cast': 'Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madhuri, Pavel Navageethan, Avantika Vandanapu', 'Year Released': '2021'}
#
# {'ID': 240, 'Type': 'Movie', 'Title': 'The Witcher: Nightmare of the Wolf', 'Director(s)': 'Han Kwang Il', 'Cast': 'Theo James, Mary McDonnell, Lara Pulver, Graham McTavish, Tom Canton, David Errigo Jr, Jennifer Hale, Kari Wahlgren, Matt Yang King, Darryl Kurylo, Keith Ferguson', 'Year Released': '2021'}
#
# {'ID': 244, 'Type': 'Movie', 'Title': 'Gunshot', 'Director(s)': 'Karim El Shenawy', 'Cast': 'Ahmed El Fishawy, Ruby, Mohamed Mamdouh, Ahmed Malek, Asmaa Abulyazeid, Samy Maghawry, Safaa El-Toukhy, Ahmed Kamal, Arfa Abdel Rassoul, Hana Shiha', 'Year Released': '2018'}
#
# {'ID': 246, 'Type': 'Movie', 'Title': 'Man in Love', 'Director(s)': 'Yin Chen-hao', 'Cast': 'Roy Chiu, Ann Hsu, Tsai Chen-nan, Chung Hsin-ling, Lan Wei-hua, Peace Yang, Huang Lu Tz-yin', 'Year Released': '2021'}
#
# {'ID': 247, 'Type': 'Movie', 'Title': 'Sweet Girl', 'Director(s)': 'Brian Andrew Mendoza', 'Cast': 'Jason Momoa, Isabela Merced, Manuel Garcia-Rulfo, Amy Brenneman, Adria Arjona, Raza Jaffrey, Justin Bartha, Lex Scott Davis, Michael Raymond-James', 'Year Released': '2021'}
#
# {'ID': 249, 'Type': 'Movie', 'Title': 'The Loud House Movie', 'Director(s)': 'Dave Needham', 'Cast': 'Asher Bishop, David Tennant, Michelle Gomez, Jill Talley, Brian Stepanek, Catherine Taber, Liliana Mumy, Nika Futterman, Cristina Pucelli, Jessica DiCicco, Grey Griffin, Lara Jill Miller', 'Year Released': '2021'}
#
# {'ID': 250, 'Type': 'Movie', 'Title': 'A Faraway Land', 'Director(s)': 'Veronica Velasco', 'Cast': 'Paolo Contis, Yen Santos, Hans Tórgarð, Ruby Ruiz, Zweden Obias, Maria Rianne Castro, Arianne Mavis Uera, Maricor Canlas', 'Year Released': '2020'}
#
# {'ID': 251, 'Type': 'Movie', 'Title': 'Like Crazy', 'Director(s)': 'Drake Doremus', 'Cast': 'Anton Yelchin, Felicity Jones, Jennifer Lawrence, Charlie Bewley, Alex Kingston, Oliver Muirhead, Finola Hughes, Chris Messina, Ben York Jones, Jamie Thomas King', 'Year Released': '2011'}
#
# {'ID': 252, 'Type': 'Movie', 'Title': 'Black Island', 'Director(s)': 'Miguel Alexandre', 'Cast': 'Philip Froissant, Alice Dwyer, Hanns Zischler, Mercedes Müller, Sammy Scheuritzel, Lieselotte Voß, Katharina Schütz, Jodie Leslie Ahlborn, Marco Wittorf, Ilknur Boyraz', 'Year Released': '2021'}
#
# {'ID': 253, 'Type': 'Movie', 'Title': 'Bombay', 'Director(s)': 'Mani Ratnam', 'Cast': 'Arvind Swamy, Manisha Koirala, Nasser, Raja Krishnamoorthy', 'Year Released': '1995'}
#
# {'ID': 256, 'Type': 'Movie', 'Title': 'Nneka The Pretty Serpent', 'Director(s)': 'Tosin Igho', 'Cast': 'Idia Aisien, Ndidi Obi, Kenneth Okolie, Zack Orji, Bovi Ugboma, Bimbo Ademoye, Beverly Osu, Beverly Naya, Larry Gaaga, Shaffy Bello, Chioma Chukwuka Akpotha, Waje', 'Year Released': '2020'}
#
# {'ID': 257, 'Type': 'Movie', 'Title': 'O Kadhal Kanmani', 'Director(s)': 'Mani Ratnam', 'Cast': 'Dulquer Salmaan, Nithya Menon, Prakash Raj, Leela Samson, Vinodhini, Ramya Subramanian, Siva Ananth, John Devasahayam, Prabhu Lakshman', 'Year Released': '2015'}
#
# {'ID': 258, 'Type': 'Movie', 'Title': 'Out of my league', 'Director(s)': 'Alice Filippi', 'Cast': 'Ludovica Francesconi, Giuseppe Maggio, Gaja Masciale, Jozef Gjura, Eleonora Gaggero, Franco Ravera, Elisabetta Coraini, Michele Franco, Edoardo Rossi', 'Year Released': '2020'}
#
# {'ID': 259, 'Type': 'Movie', 'Title': 'Pahuna', 'Director(s)': 'Paakhi Tyrewala', 'Cast': 'Anmol Limbu, Ishika Gurung, Manju Chettri, Banita Lagun, Binod Pradhan, Mahindra Bajgai, Rupa Tamang, Saran Rai', 'Year Released': '2018'}
#
# {'ID': 261, 'Type': 'Movie', 'Title': 'The Secret Diary of an Exchange Student', 'Director(s)': 'Bruno Garotti', 'Cast': 'Larissa Manoela, Thati Lopes, Bruno Montaleone, David Sherod James, Maiara Walsh, Flávia Garrafa, Kathy-Ann Hart, Ray Faiola, Noa Graham', 'Year Released': '2021'}
#
# {'ID': 264, 'Type': 'Movie', 'Title': 'Walk of Shame', 'Director(s)': 'Steve Brill', 'Cast': "Elizabeth Banks, James Marsden, Gillian Jacobs, Sarah Wright, Ethan Suplee, Bill Burr, Ken Davitian, Lawrence Gilliard Jr., Alphonso Mcauley, Da'Vone McDonald, John Marsden, Willie Garson, Oliver Hudson, P.J. Byrne", 'Year Released': '2014'}
#
# {'ID': 267, 'Type': 'Movie', 'Title': 'The Piano', 'Director(s)': 'Jane Campion', 'Cast': 'Holly Hunter, Harvey Keitel, Sam Neill, Anna Paquin, Kerry Walker, Genevieve Lemon, Tungia Baker, Ian Mune', 'Year Released': '1993'}
#
# {'ID': 268, 'Type': 'Movie', 'Title': 'Unroyal', 'Director(s)': 'Moses Inwang', 'Cast': 'Matilda Lambert, Ik Ogbonna, Prince Sontoye, Blossom Chukwujekwu, Linda Osifo, Emem Inwang, Pete Edochie, Shaffy Bello, Okon Imeh  Bishop, Chinenye Nnebe, Femi Adebayo', 'Year Released': '2020'}
#
# {'ID': 270, 'Type': 'Movie', 'Title': 'Beckett', 'Director(s)': 'Ferdinando Cito Filomarino', 'Cast': 'John David Washington, Boyd Holbrook, Alicia Vikander, Vicky Krieps, Lena Kitsopoulou, Panos Koronis, Maria Votti', 'Year Released': '2021'}
#
# {'ID': 273, 'Type': 'TV Show', 'Title': 'Gone for Good', 'Director(s)': 'Juan Carlos Medina', 'Cast': 'Finnegan Oldfield, Nicolas Duvauchelle, Guillaume Gouix, Garance Marillier, Nailia Harzoune', 'Year Released': '2021'}
#
# {'ID': 276, 'Type': 'TV Show', 'Title': 'Valeria', 'Director(s)': 'Inma Torrente', 'Cast': 'Diana Gómez, Silma López, Paula Malia, Teresa Riott, Maxi Iglesias, Ibrahim Al Shami', 'Year Released': '2021'}
#
# {'ID': 278, 'Type': 'Movie', 'Title': "Lokillo: Nothing's the Same", 'Director(s)': 'Julián Gaviria', 'Cast': 'Lokillo Florez', 'Year Released': '2021'}
#
# {'ID': 279, 'Type': 'Movie', 'Title': 'Monster Hunter: Legends of the Guild', 'Director(s)': 'Steven Yamamoto', 'Cast': 'Ben Rausch, Erica Lindbeck, Dante Basco, Brando Eaton, Stephen Kramer Glickman, Caroline Caliston, G.K. Bowes, Dan McCoy', 'Year Released': '2021'}
#
# {'ID': 281, 'Type': 'Movie', 'Title': 'Brother Jekwu', 'Director(s)': 'Charles Uwagbai', 'Cast': 'Mike Ezuruonye, Juliet Ochienge, Angela Okorie, Huddah Monroe, Catherine Kamau, Naomi Mburu, Derrick Aduwo, Chris Kamau, Abubakar Salum, Celebrity Landlord', 'Year Released': '2016'}
#
# ...
#
# {'ID': 8719, 'Type': 'Movie', 'Title': 'Westerplatte Resists', 'Director(s)': 'Stanisław Różewicz', 'Cast': 'Zygmunt Hübner, Arkadiusz Bazak, Tadeusz Schmidt, Józef Nowak, Tadeusz Pluciński, Bogusz Bilewski', 'Year Released': '1967'}
#
# {'ID': 8720, 'Type': 'Movie', 'Title': 'Westside vs. the World', 'Director(s)': 'Michael Fahey', 'Cast': 'Ron Perlman, Louie Simmons', 'Year Released': '2019'}
#
# {'ID': 8721, 'Type': 'Movie', 'Title': 'What a Wonderful Family!', 'Director(s)': 'Huang Lei', 'Cast': 'Huang Lei, Sun Li, Lee Li-Chun, Zhang Weixin, Hai Qing, Wang Xun, Wei Daxun, Lorene Ren, Lei Huang', 'Year Released': '2017'}
#
# {'ID': 8724, 'Type': 'Movie', 'Title': 'What Lies Beneath', 'Director(s)': 'Robert Zemeckis', 'Cast': 'Harrison Ford, Michelle Pfeiffer, Diana Scarwid, Joe Morton, James Remar, Miranda Otto, Wendy Crewson, Ray Baker, Micole Mercurio, Amber Valletta, Sloane Shelton', 'Year Released': '2000'}
#
# {'ID': 8726, 'Type': 'Movie', 'Title': 'What Still Remains', 'Director(s)': 'Josh Mendoza', 'Cast': "Lulu Antariksa, Colin O'Donoghue, Mimi Rogers, Peter O'Brien, Dohn Norwood, Jeff Kober, Roshon Fegan, Siena Goines, Chris Ellis, Tobias Jelinek", 'Year Released': '2018'}
#
# {'ID': 8727, 'Type': 'Movie', 'Title': "What's Up With Love?", 'Director(s)': 'Rudy Soedjarwo, Riri Riza', 'Cast': 'Dian Sastrowardoyo, Nicholas Saputra, Ladya Cheryll, Titi Kamal, Sissy Priscillia, Adinia Wirasti, Dennis Adhiswara', 'Year Released': '2002'}
#
# {'ID': 8731, 'Type': 'Movie', 'Title': 'Where the Money Is', 'Director(s)': 'Marek Kanievska', 'Cast': 'Paul Newman, Linda Fiorentino, Dermot Mulroney, Susan Barnes, Anne Pitoniak, Bruce MacVittie, Irma St. Paule, Michel Perron, Dorothy Gordon, Rita Tuckett', 'Year Released': '2000'}
#
# {'ID': 8732, 'Type': 'Movie', 'Title': "Where's the Money", 'Director(s)': 'Scott Zabielski', 'Cast': 'Andrew Bachelor, Kat Graham, Mike Epps, Terry Crews, Method Man, Logan Paul, Allen Maldonado, Josh Brener, Devon Werkheiser, Retta', 'Year Released': '2017'}
#
# {'ID': 8733, 'Type': 'Movie', 'Title': "While We're Young", 'Director(s)': 'Noah Baumbach', 'Cast': 'Ben Stiller, Naomi Watts, Adam Driver, Amanda Seyfried, Charles Grodin, Adam Horovitz, Dree Hemingway, Brady Corbet, Maria Dizzia, Matthew Maher, Peter Yarrow, Dean Wareham', 'Year Released': '2015'}
# {'ID': 8734, 'Type': 'Movie', 'Title': 'White Chamber', 'Director(s)': 'Paul Raschid', 'Cast': 'Shauna MacDonald, Oded Fehr, Amrita Acharia, Sharon Maughan, Nicholas Farrell, Candis Nergaard, Marcus Griffiths, Adrianna Edwards, Sumit Chakravarti, Lisa Reynolds', 'Year Released': '2018'}
#
# {'ID': 8735, 'Type': 'Movie', 'Title': 'White Island', 'Director(s)': 'Benjamin Turner', 'Cast': 'Lyndon Ogbourne, Billy Zane, Billy Boyd, Joel Dommett, Elliot Gleave, Gala Gordon, Darren Day, Owain Arthur, Craig Gazey, Ben Cura', 'Year Released': '2016'}
#
# {'ID': 8736, 'Type': 'Movie', 'Title': 'Who the F**k Is That Guy?', 'Director(s)': 'Drew Stone', 'Cast': 'Michael Alago', 'Year Released': '2017'}
#
# {'ID': 8737, 'Type': 'Movie', 'Title': "Who's That Knocking at My Door?", 'Director(s)': 'Martin Scorsese', 'Cast': 'Zina Bethune, Harvey Keitel, Anne Collette, Lennard Kuras, Michael Scala, Harry Northup, Susan Wood, Marissa Mathes, Catherine Scorsese', 'Year Released': '1967'}
#
# {'ID': 8739, 'Type': 'Movie', 'Title': 'Why Are We Getting So Fat?', 'Director(s)': 'Milla Harrison-Hansley, Alicky Sussman', 'Cast': 'Giles Yeo', 'Year Released': '2016'}
#
# {'ID': 8744, 'Type': 'Movie', 'Title': 'Wild Wild West', 'Director(s)': 'Barry Sonnenfeld', 'Cast': 'Will Smith, Kevin Kline, Kenneth Branagh, Salma Hayek, M. Emmet Walsh, Ted Levine, Frederique Van Der Wal, Musetta Vander, Sofia Eng, Bai Ling', 'Year Released': '1999'}
#
# {'ID': 8745, 'Type': 'Movie', 'Title': 'Wildlife', 'Director(s)': 'Paul Dano', 'Cast': 'Carey Mulligan, Ed Oxenbould, Bill Camp, Jake Gyllenhaal, Mollie Milligan, Darryl Cox', 'Year Released': '2018'}
#
# {'ID': 8747, 'Type': 'Movie', 'Title': 'Willy Wonka & the Chocolate Factory', 'Director(s)': 'Mel Stuart', 'Cast': 'Gene Wilder, Jack Albertson, Peter Ostrum, Roy Kinnear, Julie Dawn Cole, Leonard Stone, Denise Nickerson, Dodo Denney, Paris Themmen, Ursula Reit', 'Year Released': '1971'}
#
# {'ID': 8750, 'Type': 'Movie', 'Title': 'Winter of Our Dreams', 'Director(s)': 'John Duigan', 'Cast': 'Judy Davis, Bryan Brown, Cathy Downes, Baz Luhrmann, Peter Mochrie, Mervyn Drake, Margie McCrae', 'Year Released': '1981'}
#
# {'ID': 8752, 'Type': 'Movie', 'Title': "Winter's Bone", 'Director(s)': 'Debra Granik', 'Cast': 'Jennifer Lawrence, John Hawkes, Kevin Breznahan, Dale Dickey, Garret Dillahunt, Sheryl Lee, Lauren Sweetser, Tate Taylor', 'Year Released': '2010'}
#
# {'ID': 8753, 'Type': 'Movie', 'Title': 'Wish I Was Here', 'Director(s)': 'Zach Braff', 'Cast': 'Zach Braff, Kate Hudson, Donald Faison, Joey King, Josh Gad, Jim Parsons, Pierce Gagnon, Mandy Patinkin, Ashley Greene, Michael Weston', 'Year Released': '2014'}
#
# {'ID': 8754, 'Type': 'Movie', 'Title': 'Wish Man', 'Director(s)': 'Theo Davies', 'Cast': 'Andrew Steel, Kirby Bliss Blanton, Tom Sizemore, Danny Trejo, Frank Whaley, Robert Pine, Fay Masterson, Steven Michael Quezada, Bruce Davison, Dale Dickey, Kenny Roberts, Colin Edwards, Casey Stoner, Freddie Spencer', 'Year Released': '2019'}
#
# {'ID': 8755, 'Type': 'Movie', 'Title': 'Withdrawn', 'Director(s)': 'Adrian Murray', 'Cast': 'Aaron Keogh, Molly Reisman, Dean Tardioli, Greg Wasylyszn, Adrian Murray, Kelly Paoli, Earl Oliveros, Hallie Burt', 'Year Released': '2017'}
#
# {'ID': 8756, 'Type': 'Movie', 'Title': 'Wolves', 'Director(s)': 'Bart Freundlich', 'Cast': 'Michael Shannon, Carla Gugino, Taylor John Smith, Chris Bauer, John Douglas Thompson, Zazie Beetz, Wayne Duvall, Christopher Meyer, Richard Kohnke', 'Year Released': '2016'}
#
# {'ID': 8759, 'Type': 'Movie', 'Title': 'World Trade Center', 'Director(s)': 'Oliver Stone', 'Cast': 'Nicolas Cage, Michael Peña, Maggie Gyllenhaal, Maria Bello, Stephen Dorff, Jay Hernandez, Michael Shannon, Frank Whaley, Jon Bernthal, Morgan Flynn, Nick Damici, Viola Davis, William Mapother', 'Year Released': '2006'}
#
# {'ID': 8761, 'Type': 'Movie', 'Title': "World's Weirdest Homes", 'Director(s)': 'Storm Theunissen', 'Cast': 'Charlie Luxton', 'Year Released': '2015'}
#
# {'ID': 8762, 'Type': 'Movie', 'Title': 'Would You Rather', 'Director(s)': 'David Guy Levy', 'Cast': 'Brittany Snow, Jeffrey Combs, Jonny Coyne, Lawrence Gilliard Jr., Enver Gjokaj, Sasha Grey, John Heard, Charlie Hofheimer, Logan Miller, June Squibb, Eddie Steeples, Robin Lord Taylor, Robb Wells', 'Year Released': '2013'}
#
# {'ID': 8763, 'Type': 'Movie', 'Title': 'Wrong No.', 'Director(s)': 'Yasir Nawaz', 'Cast': 'Javed Sheikh, Danish Taimoor, Janita Asma, Nayyar Ejaz, Qavi Khan, Shafqat Cheema, Sohai Ali Abro, Nadeem Jafri', 'Year Released': '2015'}
#
# {'ID': 8764, 'Type': 'Movie', 'Title': 'Wrong Side Raju', 'Director(s)': 'Mikhil Musale', 'Cast': 'Pratik Gandhi, Kimberley Louisa McBeath, Asif Basra, Kavi Shastri, Hetal Puniwala, Ragi Jani, Makarand Shukla, Alok Gagdekar, Jayesh More, Siddharth Randeria, Kenneth Desai', 'Year Released': '2016'}
#
# {'ID': 8766, 'Type': 'Movie', 'Title': 'Wyatt Earp', 'Director(s)': 'Lawrence Kasdan', 'Cast': "Kevin Costner, Dennis Quaid, Gene Hackman, David Andrews, Linden Ashby, Jeff Fahey, Joanna Going, Mark Harmon, Michael Madsen, Catherine O'Hara, Bill Pullman, Isabella Rossellini, Tom Sizemore", 'Year Released': '1994'}
#
# {'ID': 8767, 'Type': 'Movie', 'Title': 'XX', 'Director(s)': 'Jovanka Vuckovic, Annie Clark, Roxanne Benjamin, Karyn Kusama', 'Cast': 'Natalie Brown, Jonathan Watton, Melanie Lynskey, Lindsay Burdge, Sheila Vand, Casey Adams, Breeda Wool, Angela Trimbur, Morgan Krantz, Christina Kirk, Kyle Allen, Mike Doyle', 'Year Released': '2017'}
#
# {'ID': 8768, 'Type': 'Movie', 'Title': 'XXx', 'Director(s)': 'Rob Cohen', 'Cast': 'Vin Diesel, Asia Argento, Marton Csokas, Samuel L. Jackson, Danny Trejo, Michael Roof, Tom Everett, Richy Müller, William Hope, Werner Daehn', 'Year Released': '2002'}
#
# {'ID': 8769, 'Type': 'Movie', 'Title': 'XXX: State of the Union', 'Director(s)': 'Lee Tamahori', 'Cast': 'Ice Cube, Samuel L. Jackson, Willem Dafoe, Scott Speedman, Peter Strauss, Xzibit, Michael Roof, Sunny Mabrey, Nona Gaye, John Gleeson Connolly', 'Year Released': '2005'}
#
# {'ID': 8770, 'Type': 'Movie', 'Title': 'Y Tu Mamá También', 'Director(s)': 'Alfonso Cuarón', 'Cast': 'Maribel Verdú, Gael García Bernal, Diego Luna, Daniel Giménez Cacho, Ana López Mercado, Nathan Grinberg, Verónica Langer, María Aura, Giselle Audirac, Arturo Ríos, Andrés Almeida, Diana Bracho, Emilio Echevarría', 'Year Released': '2001'}
#
# {'ID': 8771, 'Type': 'Movie', 'Title': 'Y.M.I.: Yeh Mera India', 'Director(s)': 'N. Chandra', 'Cast': 'Anupam Kher, Atul Kulkarni, Aakash Pandey, Milind Gunaji, Perizaad Zorabian, Smiley Suri, Parvin Dabas, Rajit Kapoor, Purab Kohli, Rajpal Yadav, Sarika, Sayaji Shinde, Seema Biswas, Vijay Raaz, Ashwin Mushran, Veerendra Saxena, Siddhant Karnick', 'Year Released': '2008'}
#
# {'ID': 8772, 'Type': 'Movie', 'Title': 'Yaadein', 'Director(s)': 'Subhash Ghai', 'Cast': 'Jackie Shroff, Hrithik Roshan, Kareena Kapoor, Amrish Puri, Kiran Rathod, Rati Agnihotri, Supriya Karnik, Anang Desai', 'Year Released': '2001'}
#
# {'ID': 8773, 'Type': 'Movie', 'Title': 'Yaara O Dildaara', 'Director(s)': 'Ksshitij Chaudhary', 'Cast': 'Harbhajan Mann, Tulip Joshi, Kabir Bedi, Gulzar Chahal, Jonita, Gurpreet Ghuggi, Gurpreet Grewal, Neena Cheema, Sunita Dhir', 'Year Released': '2011'}
#
# {'ID': 8774, 'Type': 'Movie', 'Title': 'Yamla Pagla Deewana 2', 'Director(s)': 'Sangeeth Sivan', 'Cast': 'Dharmendra, Sunny Deol, Bobby Deol, Neha Sharma, Kristina Akheeva, Annu Kapoor, Johnny Lever, Sucheta Khanna, Aidan Cook, Anupam Kher', 'Year Released': '2013'}
#
# {'ID': 8775, 'Type': 'Movie', 'Title': 'Yanda Kartavya Aahe', 'Director(s)': 'Kedar Shinde', 'Cast': 'Ankush Choudhary, Smita Shewale, Mohan Joshi, Atmaram Bhende, Asha Bhende', 'Year Released': '2006'}
#
# {'ID': 8776, 'Type': 'Movie', 'Title': 'يوم الدين', 'Director(s)': 'Abu Bakr Shawky', 'Cast': 'Rady Gamal, Ahmed Abdelhafiz, Shahira Fahmy, Shehab Ibrahim, Mohamed Abd El Azim, Osama Abdullah, Khaled Raafat, Mohamed Qishta, Shoq Emara, Mahmoud Fares', 'Year Released': '2018'}
#
# {'ID': 8778, 'Type': 'Movie', 'Title': 'Yellowbird', 'Director(s)': 'Christian De Vita', 'Cast': 'Dakota Fanning, Seth Green, Christine Baranski, Zachary Gordon, Richard Kind, Danny Glover, Elliott Gould, Ryan Lee, Jim Rash, Yvette Nicole Brown, Kostja Ullmann', 'Year Released': '2014'}
#
# {'ID': 8779, 'Type': 'Movie', 'Title': 'Yes or No', 'Director(s)': 'Saratswadee Wongsomphet', 'Cast': 'Sushar Manaying, Supanart Jittaleela, Arisara Thongborisut, Soranut Yupanun, Inthira Yeunyong', 'Year Released': '2010'}
#
# {'ID': 8780, 'Type': 'Movie', 'Title': 'Yes or No 2', 'Director(s)': 'Saratswadee Wongsomphet', 'Cast': 'Supanart Jittaleela, Sushar Manaying, Nisa Boonsantear, Apittha Khlaiudom, Apapattra Meesang', 'Year Released': '2012'}
#
# {'ID': 8781, 'Type': 'Movie', 'Title': 'Yes or No 2.5', 'Director(s)': 'Kirati Nakintanon', 'Cast': 'Supanart Jittaleela, Pimpakan Bangchawong, Chansakorn Kittiwattanakorn, Sunanta Yoonniyom', 'Year Released': '2015'}
#
# {'ID': 8783, 'Type': 'Movie', 'Title': 'Yo-Kai Watch: The Movie', 'Director(s)': 'Mark Risley', 'Cast': "Johnny Yong Bosch, Joey D'Auria, Alicyn Packard, Melissa Hutchison, Paul Greenberg, Brent Pendergrass", 'Year Released': '2016'}
#
# {'ID': 8784, 'Type': 'Movie', 'Title': 'Yoga Hosers', 'Director(s)': 'Kevin Smith', 'Cast': 'Harley Quinn Smith, Lily-Rose Depp, Johnny Depp, Justin Long, Austin Butler, Tyler Posey, Stan Lee, Jason Mewes, Adam Brody, Haley Joel Osment, Genesis Rodriguez', 'Year Released': '2016'}
#
# {'ID': 8788, 'Type': 'Movie', 'Title': 'You Can Tutu', 'Director(s)': 'James Brown', 'Cast': "Lily O'Regan, Jeannettsy Enriquez Borges, Joeley Gibson, Zahra Hassan Malik, Cleo Badcock, Stuart Manning, Ali Bastian, Amanda Holt", 'Year Released': '2017'}
#
# {'ID': 8789, 'Type': 'Movie', 'Title': 'You Can’t Fight Christmas', 'Director(s)': 'Kenny Young', 'Cast': 'Brely Evans, Andra Fuller, Persia White, Porscha Coleman, Travis Winfrey, Nathan Davis Jr., Dedrick Bonner, Matthew Jones, Larry Poindexter, Richard Gant, Marla Gibbs', 'Year Released': '2017'}
#
# {'ID': 8790, 'Type': 'Movie', 'Title': 'You Carry Me', 'Director(s)': 'Ivona Juka', 'Cast': 'Lana Baric, Vojislav Brajovic, Natasa Janjic, Goran Hajdukovic, Helena Beljan, Juraj Dabic, Natasa Dorcic, Sebastian Cavazza, Ana Begic, Krunoslav Saric', 'Year Released': '2015'}
#
# {'ID': 8791, 'Type': 'Movie', 'Title': 'You Changed My Life', 'Director(s)': 'Cathy Garcia-Molina', 'Cast': 'John Lloyd Cruz, Sarah Geronimo, Rayver Cruz, Dante Rivero, Rowell Santiago, Al Tantay, Irma Adlawan, Bernard Palanca, Matet De Leon, Joross Gamboa', 'Year Released': '2009'}
#
# {'ID': 8792, 'Type': 'Movie', 'Title': "You Don't Mess with the Zohan", 'Director(s)': 'Dennis Dugan', 'Cast': 'Adam Sandler, John Turturro, Emmanuelle Chriqui, Nick Swardson, Lainie Kazan, Ido Mosseri, Rob Schneider, Dave Matthews, Michael Buffer, Charlotte Rae', 'Year Released': '2008'}
#
# {'ID': 8793, 'Type': 'Movie', 'Title': 'Young Adult', 'Director(s)': 'Jason Reitman', 'Cast': 'Charlize Theron, Patton Oswalt, Patrick Wilson, Elizabeth Reaser, Jill Eikenberry, Mary Beth Hurt, Collette Wolfe, Richard Bekins, Kate Nowlin', 'Year Released': '2011'}
#
# {'ID': 8794, 'Type': 'Movie', 'Title': 'Young Tiger', 'Director(s)': 'Mu Chu', 'Cast': 'Qiu Yuen, Charlie Chin, Jackie Chan, Hu Chin, Nan Chiang', 'Year Released': '1973'}
#
# {'ID': 8795, 'Type': 'Movie', 'Title': 'Yours, Mine and Ours', 'Director(s)': 'Raja Gosnell', 'Cast': 'Dennis Quaid, Rene Russo, Sean Faris, Katija Pevec, Dean Collins, Tyler Patrick Jones, Haley Ramm, Brecken Palmer, Bridger Palmer, Ty Panitz', 'Year Released': '2005'}
#
# {'ID': 8796, 'Type': 'Movie', 'Title': 'اشتباك', 'Director(s)': 'Mohamed Diab', 'Cast': 'Nelly Karim, Hany Adel, Tarek Abdel Aziz, Ahmed Malek, Ahmed Dash, Husni Sheta, Aly Eltayeb, Amr El Kady, Mohamed Abd El Azim, Gameel Barsoum, Ashraf Hamdy', 'Year Released': '2016'}
#
# {'ID': 8800, 'Type': 'Movie', 'Title': 'Zed Plus', 'Director(s)': 'Chandra Prakash Dwivedi', 'Cast': 'Adil Hussain, Mona Singh, K.K. Raina, Sanjay Mishra, Anil Rastogi, Ravi Jhankal, Kulbhushan Kharbanda, Ekavali Khanna, Mukesh Tiwari, Vinod Acharya', 'Year Released': '2014'}
#
# {'ID': 8801, 'Type': 'Movie', 'Title': 'Zenda', 'Director(s)': 'Avadhoot Gupte', 'Cast': 'Santosh Juvekar, Siddharth Chandekar, Sachit Patil, Chinmay Mandlekar, Rajesh Shringarpure, Pushkar Shrotri, Tejashree Pradhan, Neha Joshi', 'Year Released': '2009'}
#
# {'ID': 8803, 'Type': 'Movie', 'Title': 'Zinzana', 'Director(s)': 'Majid Al Ansari', 'Cast': 'Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, Mansoor Alfeeli, Ahd', 'Year Released': '2015'}
#
# {'ID': 8804, 'Type': 'Movie', 'Title': 'Zodiac', 'Director(s)': 'David Fincher', 'Cast': 'Mark Ruffalo, Jake Gyllenhaal, Robert Downey Jr., Anthony Edwards, Brian Cox, Elias Koteas, Donal Logue, John Carroll Lynch, Dermot Mulroney, Chloë Sevigny', 'Year Released': '2007'}
#
# {'ID': 8806, 'Type': 'Movie', 'Title': 'Zombieland', 'Director(s)': 'Ruben Fleischer', 'Cast': 'Jesse Eisenberg, Woody Harrelson, Emma Stone, Abigail Breslin, Amber Heard, Bill Murray, Derek Graf', 'Year Released': '2009'}
#
# {'ID': 8807, 'Type': 'Movie', 'Title': 'Zoom', 'Director(s)': 'Peter Hewitt', 'Cast': 'Tim Allen, Courteney Cox, Chevy Chase, Kate Mara, Ryan Newman, Michael Cassidy, Spencer Breslin, Rip Torn, Kevin Zegers', 'Year Released': '2006'}
#
# {'ID': 8808, 'Type': 'Movie', 'Title': 'Zubaan', 'Director(s)': 'Mozez Singh', 'Cast': 'Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy', 'Year Released': '2015'}

# %% [markdown]
# The data above now shows the updated list of movies and TV shows that only contain cast members, and a director(s); meaning there won't be any blank slots in the cast members or directors column.

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ## 2. Number of Movies That Came Out in 2021, 2020, and 2019
#
# We want to know how many total movies were released* in those three years, and which year had the most movies added to Netflix. For this question, the `updated_movie_list` will not be used as we want to know **all** the movies that came out during those 3 years, regardless of if there's any cast members or director(s) or not.
#
# *This does not mean the movie was produced and released that year, but just released on Netflix.

# %%
count_of_movies = []

def movies_that_came_out():
    
    all_movies = []
    movies_2021 = []
    movies_2020 = []
    movies_2019 = []
    movie_dictionary = {}
    
    
    for index in range(0, len(netflix_show_id)):
        movie_dictionary.update({
            "ID" : netflix_show_id[index],
            "Year Released" : netflix_release_year[index],
            "Type" : netflix_type[index],
            "Movie" : netflix_title[index]
        })
        #print(movie_dictionary)
    
        all_movies.append(movie_dictionary.copy())
    #Takes out all the Types that are TV Show
    all_movies = [movie for movie in all_movies if movie["Type"] != "TV Show"]
    #print(all_movies)
    #for movie in all_movies:
        #print(movie)
    
    movies_2021 = all_movies.copy()
    #Takes out all the movies that weren't released in 2021
    movies_2021 = [movie for movie in movies_2021 if movie["Year Released"] == "2021"]
    #print(movies_2021)
    num_movies_2021 = len([movie for movie in movies_2021 if isinstance(movie, dict)])
    #print(num_movies_2021)
    
    movies_2020 = all_movies.copy()
    #Removes all the movies that weren't released in 2020
    movies_2020 = [movie for movie in movies_2020 if movie["Year Released"] == "2020"]
    #print(movies_2020)
    num_movies_2020 = len([movie for movie in movies_2020 if isinstance(movie, dict)])
    #print(num_movies_2020)
    
    movies_2019 = all_movies.copy()
    movies_2019 = [movie for movie in movies_2019 if movie["Year Released"] == "2019"]
    #print(movies_2019)
    num_movies_2019 = len([movie for movie in movies_2019 if isinstance(movie, dict)])
    #print(num_movies_2019)
    
    
    movies_2021_dict = {}
    movies_2021_dict[2021] = num_movies_2021
    #print(movies_2021_dict)
    
    movies_2020_dict = {}
    movies_2020_dict[2020] = num_movies_2020
    #print(movies_2020_dict)
    
    movies_2019_dict = {}
    movies_2019_dict[2019] = num_movies_2019
    #print(movies_2019_dict)
    
    count_of_movies.append(movies_2021_dict)
    count_of_movies.append(movies_2020_dict)
    count_of_movies.append(movies_2019_dict)
    #print(count_of_movies)
    for movies in count_of_movies:
        #print(movies)
        for year, m in movies.items():
            print("In " + str(year) + ", " + str(m) + " movies came out.")
        
movies_that_came_out()
# Out:
# In 2021, 277 movies came out.
# In 2020, 517 movies came out.
# In 2019, 633 movies came out.

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ## 3. Number of TV Shows That Came Out in 2021, 2020, and 2019
#
# Just as the previous question above, now we want to know the TV shows that were released* during those 3 years. We will continue to use the `netflix_title` list, as we want the most accurate number.
#
# *Due to how Netflix releases TV shows, each new season will also be considered as "newly released". So this data is based more on when the most recent season was released, not necessarily the entire TV show itself.

# %%
count_of_tv = []

def tv_that_came_out():
   
    all_tv_shows = []
    tv_2021 = []
    tv_2020 = []
    tv_2019 = []
    tv_dictionary = {}
    
    
    for index in range(0, len(netflix_show_id)):
        tv_dictionary.update({
            "ID": netflix_show_id[index],
            "Year Released" : netflix_release_year[index],
            "Type" : netflix_type[index],
            "TV Show" : netflix_title[index]
        })
        #print(tv_dictionary)
        all_tv_shows.append(tv_dictionary.copy())
    #print(all_tv_shows)
    
    #Removes all the types that are Movie.
    all_tv_shows = [tv for tv in all_tv_shows if tv["Type"] != "Movie"]
    #for tv in all_tv_shows:
        #print(tv)

    tv_2021 = all_tv_shows.copy()
    #Removes all the tv shows that weren't released in 2021
    tv_2021 = [tv for tv in tv_2021 if tv["Year Released"] == "2021"]
    num_tv_2021 = len([tv for tv in tv_2021 if isinstance(tv, dict)])
    #print(num_tv_2021)
    
    tv_2020 = all_tv_shows.copy()
    #Removes all the tv shows that weren't released in 2020
    tv_2020 = [tv for tv in tv_2020 if tv["Year Released"] == "2020"]
    num_tv_2020 = len([tv for tv in tv_2020 if isinstance(tv, dict)])
    #print(num_tv_2020)
    
    tv_2019 = all_tv_shows.copy()
    tv_2019 = [tv for tv in tv_2019 if tv["Year Released"] == "2019"]
    num_tv_2019 = len([tv for tv in tv_2019 if isinstance(tv, dict)])
    #print(num_tv_2019)
    
    
    tv_2021_dict = {}
    tv_2021_dict[2021] = num_tv_2021
    #print(tv_2021_dict)
    
    tv_2020_dict = {}
    tv_2020_dict[2020] = num_tv_2020
    #print(tv_2020_dict)
    
    tv_2019_dict = {}
    tv_2019_dict[2019] = num_tv_2019
    #print(tv_2019_dict)
    
    count_of_tv.append(tv_2021_dict)
    count_of_tv.append(tv_2020_dict)
    count_of_tv.append(tv_2019_dict)
    #print(count_of_tv)
    for tv in count_of_tv:
        #print(tv)
        for year, shows in tv.items():
            print("In " + str(year) + ", " + str(shows) + " TV shows came out.")
    
        
tv_that_came_out()
# Out:
# In 2021, 315 TV shows came out.
# In 2020, 436 TV shows came out.
# In 2019, 397 TV shows came out.

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ## 4. How Has Netflix Been Impacted By COVID-19?
#
# We will be using the results from questions two and three to answer this question.

# %%
from matplotlib import pyplot as plt
import numpy as np 

#print(count_of_tv)
#print(count_of_movies)
updated_tv_value = []
updated_tv_key = []

updated_movie_value = []
updated_movie_key = []

for tv in count_of_tv:
    #print(tv)
    tv_value = tv.values()
    new_tv_value = list(tv_value)
    #print(new_tv_value)
    updated_tv_value.append(new_tv_value[0])
    
    tv_key = tv.keys()
    new_tv_key = list(tv_key)
    #print(new_tv_key)
    updated_tv_key.append(new_tv_key[0])
updated_tv_value.reverse()
updated_tv_key.reverse()
#print(updated_tv_value)
#print(updated_tv_key)

for movie in count_of_movies:
    movie_value = movie.values()
    new_movie_value = list(movie_value)
    #print(new_movie_value)
    updated_movie_value.append(new_movie_value[0])
    
    movie_key = movie.keys()
    new_movie_key = list(movie_key)
    #print(new_movie_key)
    updated_movie_key.append(new_movie_key[0])
updated_movie_value.reverse()    
#print(updated_movie_value)
#print(updated_movie_key)


#----------------------------------------------------------------------------------------------#
#GRAPH

#x-axis
x = updated_tv_key #updated_movie_key is identical, so no need to use both

#y-axis
y = updated_tv_value
y_2 = updated_movie_value

x_axis = np.arange(len(x))

bar1 = plt.bar(x_axis - 0.2 ,y, 0.4, color='#eca1a6', edgecolor="gray") #Can use HTML HEX colors
bar2 = plt.bar(x_axis + 0.2, y_2, 0.4, color=(0.2, 0.4, 0.6, 0.6), edgecolor="gray")

plt.rcParams["figure.figsize"]=(10, 9)
plt.rcParams["font.size"]= 12.0

#This will give you the x-axis labels as 2019, 2020, 2021
plt.xticks(x_axis, x)
plt.legend((bar1, bar2), ('TV Shows', 'Movies'))

plt.title("Number of TV Shows Released vs. Number of Movies Released")
plt.xlabel("Year Released")
plt.ylabel("Number of Netflix Titles Released")

#This shows the value on top of the bars
for index, value in enumerate(y):
    plt.text(x_axis[index] - 0.25, value + 5.0, str(value))

for index, value in enumerate(y_2):
    plt.text(x_axis[index] + 0.13, value + 5.0, str(value))
    
plt.show()

# %% [markdown]
# ### Summary
#
# Based on the data from the two questions above (from both movies and TV shows), Netflix had released many movies and TV shows because of the lockdown; making it very easy for people to access their content.
#
# In **2019**, it's suggested that because of the lockdown, it was very difficult to continue filming TV shows, therefore, there wasn't a lot of TV shows that were released during 2019; but many movies (not necessarily released that specific year), both old and new, were able to be released.
#
# In **2020**, after the lockdown had been lifted; filming for TV shows and movies were able to resume, allowing for Netflix to go ahead and release more TV shows that were originally on hold. Since there were more TV shows released, it seems like Netflix didn't need to worry about releasing as many movies as the previous year.
#
# In **2021**, it has simply been the same as the year 2020. There has been more TV shows than movies that have been released, however, there has been a lower count of both TV shows and movies during this year, which may be due to other streaming services pushing out more content.
#
# We could assume that 2019 was the best year to release content for both movies and TV shows, however, movies would do a lot better than the TV shows.

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ## 5. Rating Distribution in Movies and TV
#
# We want to know how the ratings: TV-MA, TV-14, TV-PG, TV-G, TV-Y7, TV-Y are distributed in TV shows; and the ratings: R, PG-13, PG, G, NR, UR for movies*.
# <table>
#     <tr>
#         <th></th>
#         <th>TV Show Rating</th>
#         <th>Movie Rating</th>
#         <th></th>
#     </tr>
#     <tr>
#         <td>For Mature Audiences</td>
#         <td>TV-MA</td>
#         <td>R</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>For 14+</td>
#         <td>TV-14</td>
#         <td>PG-13</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Parental Guidance Suggested</td>
#         <td>TV-PG</td>
#         <td>PG</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>For All Ages</td>
#         <td>TV-G</td>
#         <td>G</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>For Children 7+</td>
#         <td>TV-Y7</td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>For Young Children</td>
#         <td>TV-Y</td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>NR</td>
#         <td>Not Rated**</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>UR</td>
#         <td>Unrated***</td>
#     </tr>
# </table>
#
# <br>
#
# We will be using `netflix_type` and `netflix_rating` to determine how many movies and shows in the industry have been marketed to difference age groups.
#
# <br>
# <br>
#
# <div>*TV ratings are assigned by the <i>TV Parental Guidelines</i>, while movie ratings are done by the <i>Motion Picture Association of America (MPAA)</i> in the United States. Different countries will have their own rating system, but due to the data, we will be using the American standard.</div>
# <div>**<b>Not Rated</b> means that it has not yet been rated by the <i>MPAA</i>. This does not mean it is necessarily worse than an 'R' rating; many International Films tend to have a 'NR' rating.</div>
# <div>***<b>Unrated</b> means it contains scenes that were cut from the movie that might have earned a stricter rating by <i>MPAA</i>.</div>

# %%
#This function is for TV rating ONLY

Count_All_TV_Ratings = []

def tv_rating_distribution():
    
    tv_shows = []
    tv_shows_dict = {}
    
    TV_MA = []
    TV_14 = []
    TV_PG = []
    TV_G = []
    TV_Y7 = []
    TV_Y = []
    
    Count_TV_MA = []
    Count_TV_14 = []
    Count_TV_PG = []
    Count_TV_G = []
    Count_TV_Y7 = []
    Count_TV_Y = []
    
    
    for index in range(0, len(netflix_show_id)):
        tv_shows_dict.update({
            "Title" : netflix_title[index],
            "Type" : netflix_type[index],
            "Rating" : netflix_rating[index]
        })
        #print(tv_shows_dict)
        tv_shows.append(tv_shows_dict.copy()) 
    #print(tv_shows)
    
    tv_shows = [tv for tv in tv_shows if tv["Type"] == "TV Show"]
    #print(tv_shows)
    
    
    TV_MA = tv_shows.copy()
    TV_MA = [tv for tv in TV_MA if tv["Rating"] == "TV-MA"]
    #print(TV_MA)
    num_TV_MA = len([tv for tv in TV_MA if isinstance(tv, dict)])
    #print(num_TV_MA)
    
    TV_14 = tv_shows.copy()
    TV_14 = [tv for tv in TV_14 if tv["Rating"] == "TV-14"]
    #print(TV_14)
    num_TV_14 = len([tv for tv in TV_14 if isinstance(tv, dict)])
    #print(num_TV_14)
    
    TV_PG = tv_shows.copy()
    TV_PG = [tv for tv in TV_PG if tv["Rating"] == "TV-PG"]
    #print(TV_PG)
    num_TV_PG = len([tv for tv in TV_PG if isinstance(tv, dict)])
    
    TV_G = tv_shows.copy()
    TV_G = [tv for tv in TV_G if tv["Rating"] == "TV-G"]
    #print(TV_G)
    num_TV_G = len([tv for tv in TV_G if isinstance(tv, dict)])
    
    TV_Y7 = tv_shows.copy()
    TV_Y7 = [tv for tv in TV_Y7 if tv["Rating"] == "TV-Y7"]
    #print(TV_Y7)
    num_TV_Y7 = len([tv for tv in TV_Y7 if isinstance(tv, dict)])
    
    TV_Y = tv_shows.copy()
    TV_Y = [tv for tv in TV_Y if tv["Rating"] == "TV-Y"]
    #print(TV_Y)
    num_TV_Y = len([tv for tv in TV_Y if isinstance(tv, dict)])
    
    
    TV_MA_dict = {}
    TV_MA_dict["TV-MA"] = num_TV_MA
    #print(TV_MA_dict)
    Count_TV_MA.append(TV_MA_dict)
    #print(Count_TV_MA)
    
    TV_14_dict = {}
    TV_14_dict["TV-14"] = num_TV_14
    #print(TV_14_dict)
    Count_TV_14.append(TV_14_dict)
    #print(Count_TV_14)
    
    TV_PG_dict = {}
    TV_PG_dict["TV-PG"] = num_TV_PG
    #print(TV_PG_dict)
    Count_TV_PG.append(TV_PG_dict)
    #print(Count_TV_PG)
    
    TV_G_dict = {}
    TV_G_dict["TV-G"] = num_TV_G
    #print(TV_G_dict)
    Count_TV_G.append(TV_G_dict)
    #print(Count_TV_G)
    
    TV_Y7_dict = {}
    TV_Y7_dict["TV-Y7"] = num_TV_Y7
    #print(TV_Y7_dict)
    Count_TV_Y7.append(TV_Y7_dict)
    #print(Count_TV_Y7)
    
    TV_Y_dict = {}
    TV_Y_dict["TV-Y"] = num_TV_Y
    #print(TV_Y_dict)
    Count_TV_Y.append(TV_Y_dict)
    #print(Count_TV_Y)
    
    
    Count_All_TV_Ratings.append(TV_MA_dict)
    Count_All_TV_Ratings.append(TV_14_dict)
    Count_All_TV_Ratings.append(TV_PG_dict)
    Count_All_TV_Ratings.append(TV_G_dict)
    Count_All_TV_Ratings.append(TV_Y7_dict)
    Count_All_TV_Ratings.append(TV_Y_dict)
    
    for tv_rating in Count_All_TV_Ratings:
        #print(tv_rating)
        for key, value in tv_rating.items():
            print("There are " + str(value) + " TV shows rated " + key + ".")
            
tv_rating_distribution()
# Out:
# There are 1145 TV shows rated TV-MA.
# There are 733 TV shows rated TV-14.
# There are 323 TV shows rated TV-PG.
# There are 94 TV shows rated TV-G.
# There are 195 TV shows rated TV-Y7.
# There are 176 TV shows rated TV-Y.

# %% [markdown]
# <br>

# %%
Count_All_Movie_Ratings = []

def movie_rating_distribution():
    
    movies = []
    movies_dict = {}
    
    R = []
    PG_13 = []
    PG = []
    G = []
    NR = []
    UR = []
    
    for index in range(0, len(netflix_show_id)):
        movies_dict.update({
            "Title" : netflix_title[index],
            "Type" : netflix_type[index],
            "Rating" : netflix_rating[index]
        })
        movies.append(movies_dict.copy())
    #print(movies) 
    
    movies = [m for m in movies if m["Type"] == "Movie"]
    #print(movies)
    
    R = movies.copy()
    R = [m for m in movies if m["Rating"] == "R"]
    #print(R)
    num_R = len([m for m in R if isinstance(m, dict)])
    #print(num_R)
    
    PG_13 = movies.copy()
    PG_13 = [m for m in movies if m["Rating"] == "PG-13"]
    #print(PG_13)
    num_PG_13 = len([m for m in PG_13 if isinstance(m, dict)])
    #print(num_PG_13)
    
    PG = movies.copy()
    PG = [m for m in movies if m["Rating"] == "PG"]
    #print(PG)
    num_PG = len([m for m in PG if isinstance(m, dict)])
    #print(num_PG)
    
    G = movies.copy()
    G = [m for m in movies if m["Rating"] == "G"]
    #print(G)
    num_G = len([m for m in G if isinstance(m, dict)])
    #print(num_G)
    
    NR = movies.copy()
    NR = [m for m in movies if m["Rating"] == "NR"]
    #print(NR)
    num_NR = len([m for m in NR if isinstance(m, dict)])
    #print(num_NR)
    
    UR = movies.copy()
    UR = [m for m in movies if m["Rating"] == "UR"]
    #print(UR)
    num_UR = len([m for m in UR if isinstance(m, dict)])
    #print(num_UR)
    
    
    R_dict = {}
    R_dict["R"] = num_R
    Count_R.append(R_dict)
    #print(Count_R)
    
    PG_13_dict = {}
    PG_13_dict["PG-13"] = num_PG_13
    Count_PG_13.append(PG_13_dict)
    #print(Count_PG_13)
    
    PG_dict = {}
    PG_dict["PG"] = num_PG
    Count_PG.append(PG_dict)
    #print(Count_PG)
    
    G_dict = {}
    G_dict["G"] = num_G
    Count_G.append(G_dict)
    #print(Count_G)
    
    NR_dict = {}
    NR_dict["NR"] = num_NR
    Count_NR.append(NR_dict)
    #print(Count_NR)
    
    UR_dict = {}
    UR_dict["UR"] = num_UR
    Count_UR.append(UR_dict)
    #print(Count_UR)
    
    
    Count_All_Movie_Ratings.append(R_dict)
    Count_All_Movie_Ratings.append(PG_13_dict)
    Count_All_Movie_Ratings.append(PG_dict)
    Count_All_Movie_Ratings.append(G_dict)
    Count_All_Movie_Ratings.append(NR_dict)
    Count_All_Movie_Ratings.append(UR_dict)
    
    for movie in Count_All_Movie_Ratings:
        #print(movie)
        for key, value in movie.items():
            print("There are " + str(value) + " movies rated " + key + ".")
    
movie_rating_distribution()
# Out:
# There are 797 movies rated R.
# There are 490 movies rated PG-13.
# There are 287 movies rated PG.
# There are 41 movies rated G.
# There are 75 movies rated NR.
# There are 3 movies rated UR.

# %% [markdown]
# <br>

# %%
from matplotlib import pyplot as plt
import numpy as np 

tv_rating_key = []
tv_rating_value = []

movie_rating_key = []
movie_rating_value = []

for tv in Count_All_TV_Ratings:
    #print(tv)
    for key, value in tv.items():
        tv_rating_key.append(key)
        tv_rating_value.append(value)
        
#print(tv_rating_key)
#print(tv_rating_value)

for m in Count_All_Movie_Ratings:
    #print(m)
    for key, value in m.items():
        movie_rating_key.append(key)
        movie_rating_value.append(value)
        
#print(movie_rating_key)
#print(movie_rating_value)


#-------------------------------------------------------------------------#
#GRAPH

pie_one = np.array(tv_rating_value)
label_one = tv_rating_key

pie_two = np.array(movie_rating_value)
label_two = movie_rating_key

myexplode = [0.03, 0.03, 0.03, 0.03, 0.03, 0.03]
colors = ['#b2b2b2', '#f4e1d2', '#f18973', '#bc5a45', '#92a8d1', '#667292']
    
                            #rows, columns
fig, (p1, p2) = plt.subplots(1, 2, figsize=(17, 17))

p1.pie(pie_one, labels = label_one, autopct = '%1.2f%%', startangle=50, explode=myexplode, colors=colors)
p2.pie(pie_two, labels = label_two, autopct = '%1.2f%%',startangle=50, explode=myexplode, colors=colors)
p1.set_title('TV Ratings', pad = 20)
p2.set_title('Movie Ratings', pad = 20)

plt.show()

# %% [markdown]
# ### Summary
#
# Now that we have the data and graph, we can see that almost half of the TV ratings are 'TV-MA', and more than half of the movie ratings are 'R'; which are meant for mature adults. Although there are some movies and shows for a younger age range, it is recommended for those who are younger than 13 should not use Netflix.
#
# We could safely assume that Netflix is supposed to be a streaming service meant for those who are 17 and older, with some TV shows and movies meant for those 13 and older.

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ## 6. Find the Most Popular Month for Released Movies in 2018
#
# In order to find the most popular month, we will be using `netflix_date_added`; and since we are only finding the movies most popular release month, we will need to use `netflix_type` as well. All we want to see, is which month(s) in **2018** was the had the most movies released.

# %%
from datetime import datetime
import dateutil.parser

year_2018_movie = []
count_all_movies_2018 = []

def popular_month_movie():
    
    movie_dict = {}
    movie_list = []
    
    updated_netflix_date_added = []
    netflix_month_added = []
    netflix_year_added = []
    
    jan_2018 = []
    feb_2018 = []
    mar_2018 = []
    apr_2018 = []
    may_2018 = []
    jun_2018 = []
    jul_2018 = []
    aug_2018 = []
    sep_2018 = []
    oct_2018 = []
    nov_2018 = []
    dec_2018 = []
    
    for date in netflix_date_added:
        if date != '' and date != "TV-PG": #for some reason it's bugging out with 'TV-PG' appearing as a date
            new_date_format = dateutil.parser.parse(date).strftime("%B %Y")
            month_format = dateutil.parser.parse(date).strftime("%b")
            year_format = dateutil.parser.parse(date).strftime("%Y")
        #print(new_date_format)
        updated_netflix_date_added.append(new_date_format)
        netflix_month_added.append(month_format)
        netflix_year_added.append(year_format)
    #print(updated_netflix_date_added)
            
    
    for index in range(0, len(netflix_show_id)):
        movie_dict.update({
            "Title": netflix_title[index],
            "Type": netflix_type[index],
            "Date Added": updated_netflix_date_added[index],
            "Month": netflix_month_added[index],
            "Year" : netflix_year_added[index]
        })
        #print(movie_dict)
        movie_list.append(movie_dict.copy())
    #print(movie_list)
    
    movie_list = [m for m in movie_list if m["Type"] == "Movie"]
    #print(movie_list)
    updated_movie_list = [m for m in movie_list if m["Date Added"]]
    #print(updated_movie_list)
    
    year_2018_movie = [m for m in updated_movie_list if m["Year"] == '2018']
    #print(year_2018_movie)
    
    jan_2018 = [m for m in year_2018_movie if m["Month"] == "Jan"]
    num_jan = len([m for m in jan_2018 if isinstance(m, dict)])
    #print(num_jan)
    jan_dict = {}
    jan_dict["Jan"] = num_jan
    
    feb_2018 = [m for m in year_2018_movie if m["Month"] == "Feb"]
    num_feb = len([m for m in feb_2018 if isinstance(m, dict)])
    #print(num_feb)
    feb_dict = {}
    feb_dict["Feb"] = num_feb
    
    mar_2018 = [m for m in year_2018_movie if m["Month"] == "Mar"]
    num_mar = len([m for m in mar_2018 if isinstance(m, dict)])
    #print(num_mar)
    mar_dict = {}
    mar_dict["Mar"] = num_mar
    
    apr_2018 = [m for m in year_2018_movie if m["Month"] == "Apr"]
    num_apr = len([m for m in apr_2018 if isinstance(m, dict)])
    apr_dict = {}
    apr_dict["Apr"] = num_apr
    
    may_2018 = [m for m in year_2018_movie if m["Month"] == "May"]
    num_may = len([m for m in may_2018 if isinstance(m, dict)])
    may_dict = {}
    may_dict["May"] = num_may
    
    jun_2018 = [m for m in year_2018_movie if m["Month"] == "Jun"]
    num_jun = len([m for m in jun_2018 if isinstance(m, dict)])
    jun_dict = {}
    jun_dict["Jun"] = num_jun
    
    jul_2018 = [m for m in year_2018_movie if m["Month"] == "Jul"]
    num_jul = len([m for m in jul_2018 if isinstance(m, dict)])
    jul_dict = {}
    jul_dict["Jul"] = num_jul
    
    aug_2018 = [m for m in year_2018_movie if m["Month"] == "Aug"]
    num_aug = len([m for m in aug_2018 if isinstance(m, dict)])
    aug_dict = {}
    aug_dict["Aug"] = num_aug
    
    sep_2018 = [m for m in year_2018_movie if m["Month"] == "Sep"]
    num_sep = len([m for m in sep_2018 if isinstance(m, dict)])
    sep_dict = {}
    sep_dict["Sep"] = num_sep
    
    oct_2018 = [m for m in year_2018_movie if m["Month"] == "Oct"]
    num_oct = len([m for m in oct_2018 if isinstance(m, dict)])
    oct_dict = {}
    oct_dict["Oct"] = num_oct
    
    nov_2018 = [m for m in year_2018_movie if m["Month"] == "Nov"]
    num_nov = len([m for m in nov_2018 if isinstance(m, dict)])
    nov_dict = {}
    nov_dict["Nov"] = num_nov
    
    dec_2018 = [m for m in year_2018_movie if m["Month"] == "Dec"]
    num_dec = len([m for m in dec_2018 if isinstance(m, dict)])
    dec_dict = {}
    dec_dict["Dec"] = num_dec
    
    
    count_all_movies_2018.append(jan_dict)
    count_all_movies_2018.append(feb_dict)
    count_all_movies_2018.append(mar_dict)
    count_all_movies_2018.append(apr_dict)
    count_all_movies_2018.append(may_dict)
    count_all_movies_2018.append(jun_dict)
    count_all_movies_2018.append(jul_dict)
    count_all_movies_2018.append(aug_dict)
    count_all_movies_2018.append(sep_dict)
    count_all_movies_2018.append(oct_dict)
    count_all_movies_2018.append(nov_dict)
    count_all_movies_2018.append(dec_dict)
    
    for movies in count_all_movies_2018:
        #print(movies)
        for key, value in movies.items():
            print("There are " + str(value) + " movies in " + key + " 2018.")
        
    
popular_month_movie()
# Out:
# There are 105 movies in Jan 2018.
# There are 63 movies in Feb 2018.
# There are 138 movies in Mar 2018.
# There are 87 movies in Apr 2018.
# There are 70 movies in May 2018.
# There are 50 movies in Jun 2018.
# There are 125 movies in Jul 2018.
# There are 130 movies in Aug 2018.
# There are 81 movies in Sep 2018.
# There are 146 movies in Oct 2018.
# There are 118 movies in Nov 2018.
# There are 124 movies in Dec 2018.

# %% [markdown]
# <br>

# %%
from matplotlib import pyplot as plt
import numpy as np 

#x-axis
key_movie_2018 = []

#y-axis
value_movie_2018 = []

for movie in count_all_movies_2018:
    #print(movie)
    for key, value in movie.items():
        key_movie_2018.append(key)
        value_movie_2018.append(value)
        
#print(key_movie_2018)
#print(value_movie_2018)



#-------------------------------------------------------------------------#
#GRAPH
x_axis = np.arange(len(key_movie_2018))
color = ['#ECDB54', '#E94B3C', '#6F9FD8', '#944743', '#DBB1CD', '#EC9787', '#00A591', '#6B5B95', '#6C4F3D', '#EADEDB', '#BC70A4', '#BFD641']

f, ax = plt.subplots(figsize=(15, 7))

plt.xlabel('Months')
plt.ylabel('Amount of Movies Released')
plt.title('Movies Released in 2018')

plt.bar(key_movie_2018, value_movie_2018, color=color)
for index, value in enumerate(value_movie_2018):
    plt.text(x_axis[index] - 0.15, value + 2.0, str(value))
    
plt.grid(color='#B4B7BA', linestyle='--', linewidth=1, axis='y', alpha=1)

plt.show()

# %% [markdown]
# ### Summary
#
# As we can see from the data above, **October** was the month were the most movies were released on Netflix. It seems like **October, November, and December** all have very high numbers when movies were released on Netflix; which we could assume that Netflix was releasing more movies due to the winter holidays, so viewers would have plenty of options to watch.
#
# **March** came in the second highest, which could easily be due to prepare for the upcoming summer months when many viewers are no longer in school, making it more easier for them to have many options to watch when the summer arrives. **July and August** also have a high count of movies released, which could also be due to the summer months.
#
# Surprisingly, **June** has the lowest number of movies released even though June is the month that is considered to be the beginning of summer vacation.

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ## 7. TV Shows That Only Have One Season
#
# We are going to create a list to figure out what TV shows have **one season**\* using `netflix_titles` and `netflix_duration`. It would also be useful to include the amount of shows the have one season as well.
#
# \*This is **not** TV shows that lasted **only** one season, but TV shows that have only one season so far. There may be more seasons for some of them in the future (or not), but as of now with the data, it will only be shown as having one season.

# %%
count_seasons_tv = []

def one_season_tv():
    
    tv_show_list = []
    one_season_list = []
    one_season_dict = {}
    
    count_one_season = {}
    count_rest_tv = {}
    
    for index in range(0, len(netflix_show_id)):
        one_season_dict.update({
            "Title": netflix_title[index],
            "Type": netflix_type[index],
            "Duration" : netflix_duration[index]
        })
        #print(one_season_dict)
        tv_show_list.append(one_season_dict.copy())
    #print(tv_show_list)
    
    tv_show_list = [tv for tv in tv_show_list if tv["Type"] == "TV Show"]
    #print(tv_show_list)
    num_all_tv_shows = len([tv for tv in tv_show_list if isinstance(tv, dict)])
    #print(num_all_tv_shows)
    
    one_season_list = [tv for tv in tv_show_list if tv["Duration"] == "1 Season"]
    #print(one_season_list)
    num_one_season = len([tv for tv in one_season_list if isinstance(tv, dict)])
    #print(num_one_season)
    
    num_rest_tv_shows = num_all_tv_shows - num_one_season
    
    count_one_season["One Season"] = num_one_season
    count_seasons_tv.append(count_one_season)
    
    count_rest_tv["Two or More Seasons"] = num_rest_tv_shows
    count_seasons_tv.append(count_rest_tv)
    
    #print("Out of " + str(num_all_tv_shows) + " TV Shows, " + str(num_one_season) + " have one season.")
    #print("")
    
    print("TV Shows with One Season:")
    for tv in one_season_list:
        for key, value in tv.items():
            if key == "Title":
                print("- " + value)
    
one_season_tv()
# Out:
# TV Shows with One Season:
# - Ganglands
# - Jailbirds New Orleans
# - Midnight Mass
# - Vendetta: Truth, Lies and The Mafia
# - Bangkok Breaking
# - Crime Stories: India Detectives
# - Jaguar
# - Monsters Inside: The 24 Faces of Billy Milligan
# - Chicago Party Aunt
# - Squid Game
# - Tayo and Little Wizards
# - Angry Birds
# - He-Man and the Masters of the Universe
# - The Smart Money Woman
# - Dharmakshetra
# - Raja Rasoi Aur Anya Kahaniyan
# - Stories by Rabindranath Tagore
# - Too Hot To Handle: Latino
# - Yowamushi Pedal
# - Metal Shop Masters
# - Pokémon Master Journeys: The Series
# - Octonauts: Above & Beyond
# - On the Verge
# - Countdown: Inspiration4 Mission to Space
# - Dive Club
# - Money Heist: From Tokyo to Berlin
# - Sharkdog
# - Heroes of Goo Jit Zu
# - Hotel Del Luna
# - Luv Kushh
# - Q-Force
# - Brave Animated Series
# - How to Be a Cowboy
# - HQ Barbers
# - Oldsters
# - Turning Point: 9/11 and the War on Terror
# - Sparking Joy
# - Hometown Cha-Cha-Cha
# - The Ingenuity of the Househusband
# - D.P.
# - Deadly Sins
# - I Heart Arlo
# - King of Boys: The Return of the King
# - Titletown High
# - EDENS ZERO
# - Clickbait
# - John of God: The Crimes of a Spiritual Healer
# - Motel Makeover
# - Open Your Eyes
# - Post Mortem: No One Dies in Skarnes
# - Oggy Oggy
# - Comedy Premium League
# - Everything Will Be Fine
# - Korean Cold Noodle Rhapsody
# - The Chair
# - The Defeated
# - Rascal Does Not Dream of Bunny Girl Senpai
# - The Creative Indians
# - Brand New Cherry Flavor
# - Gone for Good
# - The Kingdom
# - AlRawabi School for Girls
# - Bake Squad
# - I Need Romance
# - Las muñecas de la mafia
# - The Crowned Clown
# - SHAMAN KING
# - Hit & Run
# - Navarasa
# - Cocaine Cowboys: The Kings of Miami
# - Cooking With Paris
# - Autumn's Concerto
# - Office Girls
# - The Prince Who Turns into a Frog
# - Top Secret UFO Projects: Declassified
# - Two Fathers
# - You're My Destiny
# - Darwin’s Game
# - Centaurworld
# - Khawatir
# - Myth & Mogul: John DeLorean
# - Transformers: War for Cybertron: Kingdom
# - Tattoo Redo
# - The Snitch Cartel: Origins
# - Plastic Cup Boyz: Laughing My Mask Off!
# - Feels Like Ishq
# - Masters of the Universe: Revelation
# - Revelations: The Masters of the Universe: Revelation Aftershow
# - Sexy Beasts
# - Too Hot to Handle: Brazil
# - Okupas
# - Touch Your Heart
# - Johnny Test
# - Naomi Osaka
# - Her Private Life
# - Heist
# - My Unorthodox Life
# - Ridley Jones
# - How to Become a Tyrant
# - The Cook of Castamar
# - Elize Matsunaga: Once Upon a Crime
# - RESIDENT EVIL: Infinite Darkness
# - Cat People
# - The War Next-door
# - You Are My Spring
# - We the People
# - Big Timber
# - Bureau of Magical Things
# - Generation 56k
# - Masameer County
# - Quarantine Tales
# - Rainbow Rangers
# - Young Royals
# - Droppin' Cash: Los Angeles
# - Legend of Exorcism
# - Somos.
# - Sophie: A Murder in West Cork
# - The Daily Life of the Immortal King
# - Ray
# - Sex/Life
# - Godzilla Singular Point
# - Jiva!
# - The Parisian Agency: Exclusive Properties
# - This Is Pop
# - Nevertheless,
# - Bangkok Love Stories: Innocence
# - Champions
# - Charité at War
# - Gameboys Level-Up Edition
# - No Time for Shame
# - REA(L)OVE
# - The Assassination of Gianni Versace
# - The Judgement
# - The Last Dance
# - They've Gotta Have Us
# - Why Are You Like This
# - So Not Worth It
# - The Rational Life
# - Elite Short Stories: Carla Samuel
# - Katla
# - Record of Ragnarok
# - Elite Short Stories: Omar Ander Alexis
# - Let's Eat
# - Penguin Town
# - Avengers Climate Conundrum
# - Beyond Evil
# - Elite Short Stories: Nadia Guzmán
# - Power Rangers Dino Fury
# - The American Bible Challenge
# - Elite Short Stories: Guzmán Caye Rebe
# - Metallica: Some Kind of Monster
# - Trese
# - Locombianos
# - Fresh, Fried & Crispy
# - Newly Rich, Newly Poor
# - Human: The World Within
# - Sweet Tooth
# - Creator's File: GOLD
# - Pretty Guardian Sailor Moon Eternal The Movie
# - Attack on Titan
# - Ouran High School Host Club
# - Racket Boys
# - The Adventures of Sonic the Hedgehog
# - Word of Honor
# - Black Space
# - Eden
# - High on the Hog: How African American Cuisine Transformed America
# - Mad for Each Other
# - The Magic School Bus
# - Booba: Food Puzzle
# - Alma Matters
# - Halston
# - Move to Heaven
# - The Mystic River
# - The Upshaws
# - Use For My Talent
# - Money, Explained
# - Mine
# - Jupiter's Legacy
# - Lava Ka Dhaava
# - The Sons of Sam: A Descent into Darkness
# - Miniforce: Super Dino Power
# - Pet Stars
# - The Innocent
# - Yasuke
# - Headspace Guide to Sleep
# - Sexify
# - Fatma
# - Let's Fight Ghost
# - Shadow and Bone
# - Life in Color with David Attenborough
# - Zero
# - Bakugan: Geogan Rising
# - Love Naggers
# - Dancing Angels
# - Durarara!!
# - Garth Brooks: The Road I’m On
# - High-Rise Invasion
# - Next in Fashion
# - Peasants Rebellion
# - Ricky Zoom
# - Ajaibnya Cinta
# - Dad Stop Embarrassing Me!
# - Fate: The Winx Saga
# - Indian Matchmaking
# - Jeffrey Epstein: Filthy Rich
# - Law School
# - Living with Yourself
# - Signal
# - The Underclass
# - Unnatural Selection
# - My Love: Six Stories of True Love
# - The Baker and the Beauty
# - Don't be the First one
# - Heaven Official's Blessing
# - The Way of the Househusband
# - The Wedding Coach
# - This Is a Robbery: The World's Biggest Art Heist
# - Glimpses of a Future
# - Worn Stories
# - Haunted: Latin America
# - Yu-Gi-Oh!
# - Rainbow High
# - Magic for Humans Spain
# - The Irregulars
# - DOTA: Dragon's Blood
# - Pui Pui Molcar
# - Navillera
# - Country Comfort
# - Under Suspicion: Uncovering the Wesphael Case
# - Waffles + Mochi
# - Abla Fahita: Drama Queen
# - The Lost Pirate Kingdom
# - Zero Chill
# - The One
# - Dealer
# - Last Chance U: Basketball
# - Marriage or Mortgage
# - The Houseboat
# - Bombay Begums
# - My Way
# - City of Ghosts
# - Nevenka: Breaking the Silence
# - Pacific Rim: The Black
# - Murder Among the Mormons
# - A Perfect Day For Arsenide
# - TIGER & BUNNY
# - El final del paraíso
# - The Last Bastion
# - Age of Samurai: Battle for Japan
# - Canine Intervention
# - Ginny & Georgia
# - Zindagi in Short
# - Vincenzo
# - Pitta Kathalu
# - Tribes of Europa
# - Hello, Me!
# - Sisyphus
# - Thus Spoke Kishibe Rohan
# - Amend: The Fight for America
# - Behind Her Eyes
# - The Crew
# - Buried by the Bernards
# - Nadiya Bakes
# - Capitani
# - El Chema
# - Crime Scene: The Vanishing at the Cecil Hotel
# - Five Came Back: The Reference Films
# - Invisible City
# - Firefly Lane
# - Pablo Escobar, el patrón del mal
# - Love Daily
# - My Dead Ex
# - The House Arrest of Us
# - The Unsettling
# - We Are: The Brooklyn Saints
# - 50M2
# - Go Dog Go
# - Demon Slayer: Kimetsu no Yaiba
# - Daughter From Another Mother
# - Spycraft
# - Bling Empire
# - Night Stalker: The Hunt for a Serial Killer
# - Mighty Little Bheem: Kite Festival
# - Pretend It’s a City
# - Surviving Death
# - History of Swear Words
# - Korean Pork Belly Rhapsody
# - QB1: Beyond the Lights
# - Headspace Guide to Meditation
# - Jenni Rivera: Mariposa de Barrio
# - Running Man
# - The Cat in the Hat Knows a Lot About That!
# - Best Leftovers Ever!
# - Dare Me
# - Equinox
# - SanPa: Sins of the Savior
# - Transformers: War for Cybertron: Earthrise
# - A Love So Beautiful
# - Sakho & Mangane
# - Bridgerton
# - Lovestruck in the City
# - Rhyme Time Town Singalongs
# - Timmy Time
# - Diamond City
# - Paava Kadhaigal
# - Run On
# - Schulz Saves America
# - Anitta: Made In Honório
# - BREAK IT ALL: The History of Rock in Latin America
# - How To Ruin Christmas
# - Marvel Anime: Wolverine
# - Marvel Anime: X-Men
# - The Ripper
# - Tiny Pretty Things
# - Children of Adam
# - The Mess You Leave Behind
# - Alice in Borderland
# - Futmalls.com
# - Once Upon a Time
# - The Surgeon's Cut
# - Juman
# - 100 Days My Prince
# - Manhunt: Deadly Games
# - Room 2806: The Accusation
# - Detention
# - Bhaag Beanie Bhaag
# - Kings of Jo'Burg
# - Alien Worlds
# - Gormiti
# - Oddbods
# - The Bachelorette
# - The Guest
# - The Holiday Movies That Made Us
# - The Repair Shop
# - The Uncanny Counter
# - Fabulous Lives of Bollywood Wives
# - Over Christmas
# - Before 30
# - Valentino
# - Strongest Deliveryman
# - Heart & Soul
# - Mismatched
# - Voices of Fire
# - Holiday Home Makeover with Mr. Christmas
# - We Are the Champions
# - Beyblade Burst Rise
# - The Minions of Midas
# - Ethos
# - Graceful Friends
# - A Queen Is Born
# - Aunty Donna's Big Ol' House of Fun
# - The Liberator
# - Trial 4
# - A Lion in the House
# - DASH & LILY
# - Bakugan: Armored Alliance
# - Bakugan: Battle Planet
# - Country Ever After
# - Wrong Kind of Black
# - Carmel: Who Killed Maria Marta?
# - Paranormal
# - Love & Anarchy
# - 60 Days In
# - Forged in Fire
# - LEGO Jurassic World: Legend of Isla Nublar
# - LEGO Jurassic World: Secret Exhibit
# - LEGO: CITY Adventures
# - The Good Detective
# - Afronta! Facing It!
# - Zumbo's Just Desserts
# - Blood of Zeus
# - The Devil Punisher
# - Barbarians
# - Move
# - Stolen Away
# - The Queen's Gambit
# - Start-Up
# - Grand Army
# - La Révolution
# - Someone Has to Die
# - Social Distance
# - The Cabin with Bert Kreischer
# - Deaf U
# - The Haunting of Bly Manor
# - Do Do Sol Sol La La Sol
# - Private Lives
# - To the Lake
# - Bad Boy Billionaires: India
# - Pat a Pat Como
# - Qurious Como
# - DreamWorks Happy Holidays from Madagascar
# - Emily in Paris
# - Evil
# - Familiar Wife
# - Good Morning, Verônica
# - Journey of an African Colony
# - Oktoberfest: Beer & Blood
# - Secreto bien guardado
# - The Unicorn
# - You Cannot Hide
# - Whose Vote Counts, Explained
# - A Perfect Crime
# - Sneakerheads
# - The School Nurse Files
# - The Playbook
# - Fukrey Boyzzz
# - Ratched
# - The American Barbecue Showdown
# - Dragon's Dogma
# - The Last Word
# - Challenger
# - Sing On!
# - The Barrier
# - The Duchess
# - Julie and the Phantoms
# - Get Organized with The Home Edit
# - La Línea: Shadow of Narco
# - Record of Youth
# - Cleverman
# - Away
# - Young Wallander
# - Chef's Table: BBQ
# - The Witcher: A Look Inside the Episodes
# - Bookmarks
# - Erased
# - Felipe Esparza: Bad Decisions
# - Heidi
# - The Promised Neverland
# - I AM A KILLER: RELEASED
# - Masaba Masaba
# - Her Mother's Killer
# - Million Dollar Beach House
# - Emily's Wonder Lab
# - Baewatch: Parental Guidance
# - Ojos in d' House
# - Hoops
# - Goedam
# - DeMarcus Family Rules
# - High Score
# - Dérè: An African Tale
# - Teenage Bounty Hunters
# - The Great Heist
# - Zoids Wild
# - (Un)Well
# - GAME ON: A Comedy Crossover Event
# - The Governor
# - Sing On! Germany
# - Tiny Creatures
# - Wizards: Tales of Arcadia
# - Word Party Songs
# - World's Most Wanted
# - Mystery Lab
# - Immigration Nation
# - My Perfect Landing
# - Nagi-Asu: A Lull in the Sea
# - The Next Step
# - Toradora!
# - Get Even
# - Transformers: War For Cybertron Trilogy
# - Unlucky Ploy
# - Sing On! Spain
# - Sinatra: All or Nothing at All
# - Fear City: New York vs The Mafia
# - Street Food: Latin America
# - Killer Women with Piers Morgan
# - Gigantosaurus
# - Single Wives
# - Cursed
# - Kissing Game
# - Dark Desire
# - Skin Decision: Before and After
# - The Business of Drugs
# - Dating Around: Brazil
# - Down to Earth with Zac Efron
# - The Epic Tales of Captain Underpants in Space
# - The Twelve
# - Japan Sinks: 2020
# - Was It Love?
# - Stateless
# - Hook
# - JU-ON: Origins
# - Southern Survival
# - The Baby-Sitters Club
# - Supermarket Sweep
# - Warrior Nun
# - 21 Again
# - A Touch of Green
# - Abby Hatcher
# - Say I Do
# - Trotro
# - BNA
# - Homemade
# - All For Love
# - Home Game
# - Twogether
# - Crazy Delicious
# - It's Okay to Not Be Okay
# - Floor Is Lava
# - Frank Elstner: Just One Last Question
# - The Search
# - The Woods
# - Curon
# - Lenox Hill
# - My Mister
# - Reality Z
# - Alone
# - Dear My Friends
# - Megalobox
# - My Shy Boss
# - Revolutionary Love
# - Space Force
# - Dorohedoro
# - Betaal
# - History 101
# - Mystic Pop-up Bar
# - Especial 20 años Fútbol de Primera
# - The Queen and the Conqueror
# - Patton Oswalt: I Love Everything
# - Sweet Magnolias
# - The Big Flower Fight
# - Boys Over Flowers
# - Iris
# - Inhuman Resources
# - Parasyte: The Maxim
# - Sleepless Society: Two Pillows & A Lost Soul
# - Strangers from Hell
# - White Lines
# - True: Terrific Tales
# - Trial By Media
# - The Eddy
# - Almost Happy
# - Hangar 1: The UFO Files
# - Hoarders
# - The Universe: Ancient Mysteries Solved
# - WWII in HD
# - Hollywood
# - Monthly Girls' Nozaki Kun
# - Oh Yuck
# - Reckoning
# - DRIFTING DRAGONS
# - The Forest of Love: Deep Cut
# - The Victims' Game
# - Extracurricular
# - Nadiya’s Time to Eat
# - Coronavirus, Explained
# - My Secret Romance
# - دفعة القاهرة
# - DreamWorks Spooky Stories: Volume 2
# - Love 101
# - Ghost in the Shell: SAC_2045
# - Absurd Planet
# - Win the Wilderness
# - Middleditch & Schwartz
# - Nicky Jam: El Ganador
# - Cooked with Cannabis
# - The Midnight Gospel
# - ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# - The King: Eternal Monarch
# - #blackAF
# - Hasmukh
# - The Innocence Files
# - Brews Brothers
# - The Trial
# - The Circle France
# - How to Fix a Drug Scandal
# - The Iliza Shlesinger Sketch Show
# - Akbar Birbal
# - Bal Ganesh
# - Tree House Tales
# - Rugal
# - Ladies Up
# - Wassup Man GO!
# - Unorthodox
# - Freud
# - J-Style Trip
# - Self Made: Inspired by the Life of Madam C.J. Walker
# - She
# - The English Game
# - The Letter for the King
# - Tiger King: Murder, Mayhem and Madness
# - Vampires
# - Caliphate
# - Women Of The Night
# - Shaun the Sheep: Adventures from Mossy Bottom
# - We Speak Dance
# - Ken Burns Presents: College Behind Bars: A Film by Lynn Novick and Produced by Sarah Botstein
# - 100 Humans
# - Bloodride
# - The Valhalla Murders
# - The Circle Brazil
# - Mighty Little Bheem: Festival of Colors
# - Akame ga Kill!
# - Calico Critters Mini Episodes Clover
# - Queen Sono
# - Toy Boy
# - Unstoppable
# - Followers
# - Six Windows in the Desert
# - I Am Not Okay With This
# - The Trials of Gabriel Fernandez
# - Hi Bye, Mama!
# - Unabomber - In His Own Words
# - Gentefied
# - Hyena
# - Passion. Panache. Pep
# - Puerta 7
# - Spectros
# - DreamWorks Shrek's Swamp Stories
# - On the Real
# - Talking Tom and Friends
# - Taj Mahal 1989
# - Love Is Blind
# - Palazuelos mi rey
# - Sleepless Society: Insomnia
# - Locke & Key
# - My Holo Love
# - Who Killed Malcolm X?
# - Cagaster of an Insect Cage
# - The Pharmacist
# - Is It Wrong to Try to Pick Up Girls in a Dungeon?
# - Itaewon Class
# - No Game No Life
# - Pop Team Epic
# - Shopkins
# - Luna Nera
# - Ainori Love Wagon: African Journey
# - THE STRANGER
# - What the Love! with Karan Johar
# - Find Yourself
# - Night on Earth
# - Omniscient
# - Rise of Empires: Ottoman
# - The goop lab with Gwyneth Paltrow
# - October Faction
# - The Ghost Bride
# - Pandemic: How to Prevent an Outbreak
# - Playing with Fire
# - DreamWorks How to Train Your Dragon Legends
# - Ares
# - Nailed It! Germany
# - Handsome Siblings
# - Soul Eater
# - Killer Inside: The Mind of Aaron Hernandez
# - The Ollie & Moon Show
# - The Healing Powers of Dude
# - AJ and the Queen
# - Giri / Haji
# - Jamtara - Sabka Number Ayega
# - Medical Police
# - Until Dawn
# - Cheer
# - Dracula
# - Sex, Explained
# - Thieves of the Wood
# - Because This Is My First Life
# - Border Security: America's Front Line
# - Cells at Work!
# - Chhota Bheem Kung Fu Dhamaka Series
# - Live Up To Your Name
# - Messiah
# - Nisman: The Prosecutor, the President, and the Spy
# - Reply 1988
# - Save Me
# - Spinning Out
# - The Bride of Habaek
# - ARASHI's Diary -Voyage-
# - Pucca: Love Recipe
# - Rainbow Ruby
# - Yanxi Palace: Princess Adventures
# - The Disastrous Life of Saiki K.: Reawakened
# - Kevin Hart: Don’t F**k This Up
# - The Bonfire of Destiny
# - Agent
# - The Witcher
# - Twice Upon A Time
# - Don't F**k with Cats: Hunting an Internet Killer
# - Soundtrack
# - Cinderella and the Four Knights
# - Crash Landing on You
# - Crazy, Lovely, Cool
# - Girls und Panzer
# - Astronomy Club: The Sketch Show
# - Teasing Master Takagi-san
# - The Confession Killer
# - Three Days of Christmas
# - Triad Princess
# - V Wars
# - The Prince of Tennis ~ Match! Tennis Juniors ~
# - The Road to Love
# - Nightflyers
# - Chocolate
# - The Charming Stepmom
# - Levius
# - Lugar de Mulher
# - Merry Happy Whatever
# - Mythomaniac
# - Zona Rosa
# - Once Upon A Time In Lingjian Mountain
# - Dolly Parton's Heartstrings
# - Narcoworld: Dope Stories
# - Nobody's Looking
# - Singapore Social
# - Bangkok Buddies
# - Holiday Secrets
# - Who Killed Little Gregory?
# - Miss Culinary
# - Candy Online
# - At the Dolphin Bay
# - I'm with the Band: Nasty Cherry
# - Inheritors
# - La Robe De Mariee Des Cieux
# - My MVP Valentine
# - My Sassy Girl
# - The Club
# - The Stranded
# - Westside Story
# - My Dear Warrior
# - Maradona in Mexico
# - Put Your Head on My Shoulder
# - Greatest Events of WWII in Colour
# - Green Eggs and Ham
# - SCAMS
# - The Devil Next Door
# - Bella and the Bulldogs
# - A Year In Space
# - Ad Vitam
# - Maid-Sama!
# - Queer Eye: We're in Japan!
# - Vientos de agua
# - We Are the Wave
# - Nowhere Man
# - Sleepless Society: Bedtime Wishes
# - Bring It On, Ghost
# - Tomorrow with You
# - Tunnel
# - Shine On with Reese
# - Wait, My Youth
# - A Little Thing Called First Love
# - Brotherhood
# - Drug Squad: Costa del Sol
# - Monzón: A Knockout Blow
# - Nailed It! France
# - Nailed It! Spain
# - The Untamed
# - Daybreak
# - Breakfast, Lunch & Dinner
# - ChuChu TV Kids Songs, Learning Videos & Bedtime Stories
# - Interior Design Masters
# - Mighty Little Bheem: Diwali
# - MONKART
# - THE UNLISTED
# - Another Miss Oh
# - Second 20s
# - Black Money Love
# - The Lies Within
# - Beyblade Burst Turbo
# - Ultramarine Magmell
# - Rhythm + Flow
# - Legend Quest: Masters of Myth
# - My Country: The New Age
# - Raising Dion
# - Seis Manos
# - Living Undocumented
# - Cheese in the Trap
# - Chicago Typewriter
# - College Romance
# - Engineering Girls
# - Girls Hostel
# - Inmates
# - Miniforce X
# - The K2
# - The Liar and His Lover
# - Bard of Blood
# - The Inmate
# - Vagabond
# - Criminal: France
# - Criminal: Germany
# - Criminal: Spain
# - Inside Bill's Brain: Decoding Bill Gates
# - The Hockey Girls
# - When the Camellia Blooms
# - Surviving R. Kelly
# - Kabaneri of the Iron Fortress: The Battle of Unato
# - Marianne
# - Top Boy
# - Unbelievable
# - The I-Land
# - The Mind, Explained
# - The Spy
# - Loo Loo Kids: Johny & Friends Musical Adventures
# - Serial Killer with Piers Morgan
# - Luo Bao Bei
# - Styling Hollywood
# - The Dark Crystal: Age of Resistance
# - The Good Bandit
# - Hyperdrive
# - 45 rpm
# - Apache: The Life of Carlos Tevez
# - Better Than Us
# - Diagnosis
# - Green Frontier
# - The King's Avatar
# - Victim Number 8
# - Cannon Busters
# - Til Death Do Us Part
# - Happy Jail
# - DC Super Hero Girls
# - Sintonia
# - The Family
# - Bad Guys
# - Dollar
# - Let's Eat 2
# - Let’s Eat
# - Misaeng
# - Oh My Ghost
# - Reply 1994
# - Reply 1997
# - Wu Assassins
# - Basketball or Nothing
# - Sleepless Society: Nyctophobia
# - Twelve Forever
# - Another Life
# - Sexy Central
# - Typewriter
# - Rookie Historian Goo Hae-Ryung
# - Unrequited Love
# - Angel Beats!
# - Anohana: The Flower We Saw That Day
# - God Eater
# - GRANBLUE FANTASY the Animation
# - Extreme Engagement
# - One Spring Night
# - PILI Fantasy: War of Dragons
# - True Tunes
# - The Legend of White Snake
# - The Last Czars
# - Bangkok Love Stories: Objects of Affection
# - Bangkok Love Stories: Plead
# - Designated Survivor: 60 Days
# - DreamWorks Kung Fu Panda Awesome Secrets
# - Molang
# - Rabbids Invasion
# - Record of Grancrest War
# - Exhibit A
# - Answer for Heaven
# - Bolívar
# - Neon Genesis Evangelion
# - Kill la Kill
# - Puella Magi Madoka Magica
# - Somewhere Only We Know
# - The Alcàsser Murders
# - Unit 42
# - Awake: The Million Dollar Game
# - Leila
# - Yankee
# - Jinn
# - Upin & Ipin
# - Super Monsters Monster Pets
# - Tales of the City
# - Malibu Rescue: The Series
# - Arthdal Chronicles
# - A Thousand Goodnights
# - Killer Ratings
# - When They See Us
# - Historical Roasts
# - Hyper HardBoiled Gourmet Report
# - WHAT / IF
# - 1994
# - It's Bruno!
# - Dennis and Gnasher Unleashed
# - Heidi, bienvenida a casa
# - I Hear You
# - Revisions
# - The Defected
# - Jailbirds
# - The Princess Weiyoung
# - The Society
# - Away From Home
# - Bibik-Bibikku
# - Cinta 100KG
# - Cinta Iris
# - Cinta Si Wedding Planner
# - Cinta Teruna Kimchi
# - Secret of Success
# - The Missing Menu
# - Unchained Fate
# - Abyss
# - I Have a Script
# - In the Bosom of a Thorn
# - The Writer
# - What If?
# - Crime Diaries: Night Out
# - Flinch
# - Tuca & Bertie
# - Angel 'N' Devil
# - Hong Kong West Side Stories
# - Ingress: The Animation
# - K.O. One Re-act
# - K.O.3an Guo
# - KO One Return
# - The Outsiders
# - Chambers
# - Street Food
# - The Hateful Eight: Extended Version
# - KO One
# - Lunatics
# - My Dear Boy
# - Rilakkuma and Kaoru
# - Huge in France
# - Persona
# - You vs. Wild
# - Time: The Kalief Browder Story
# - Our Planet
# - Quicksand
# - Rimba Racer
# - Tijuana
# - Possessed
# - Tango
# - Kicko & Super Speedo
# - That Winter, the Wind Blows
# - Ultraman
# - Pablo
# - Osmosis
# - The Terminal
# - Traitors
# - The Eagle of El-Se'eed
# - Charlie's Colorforms City
# - Crime Diaries: The Candidate
# - Delhi Crime
# - The 10 Sins
# - Bo on the Go!
# - Stay Tuned!
# - 9-Feb
# - My Husband Won't Fit
# - Green Door
# - If I Hadn't Met You
# - My Pride
# - The Disappearance of Madeleine McCann
# - Turn Up Charlie
# - More to Say
# - The Land of Hypocrisy
# - Eugenie Nights
# - This Evening
# - Bangkok Love Stories: Hey You!
# - Disappearance
# - Immortals
# - The Confrontation
# - American Crime Story: The People v. O.J. Simpson
# - A Korean Odyssey
# - Cricket Fever: Mumbai Indians
# - Losers
# - Northern Rescue
# - Unsolved
# - Hjørdis
# - Larry Charles' Dangerous World of Comedy
# - The 43
# - The Kirlian Frequency
# - Iron Ladies
# - The Last of the Schmucks
# - Hidden Worlds
# - Live
# - Safe
# - Tayee
# - Violet Evergarden
# - Romance is a bonus book
# - Russian Doll
# - Sparta
# - Sword Art Online Alternative: Gun Gale Online
# - Paprika
# - A Taiwanese Tale of Two Cities
# - Black Earth Rising
# - Examination of Conscience
# - The Perfect Match
# - Conversations with a Killer: The Ted Bundy Tapes
# - Innocent
# - Memory Love
# - Trigger Warning with Killer Mike
# - Lavender
# - La Grande Chaumière Violette
# - Back with the Ex
# - When Heroes Fly
# - See You in Time
# - Déjà Vu
# - Tidying Up with Marie Kondo
# - Pioneers: First Women Filmmakers*
# - In Family We Trust
# - Hashoter Hatov
# - Murder Mountain
# - Selection Day
# - Stand Up and Away! with Brian Regan
# - Way Back into Love
# - Watership Down
# - Demon's Path
# - Single Ladies Senior
# - 7 Days Out
# - Jojo's World
# - Lion Pride
# - Love @ Seventeen
# - Perfume
# - Sirius the Jaeger
# - Wolf
# - Ellen DeGeneres: Relatable
# - Ashes of Love
# - DreamWorks Holiday Classics
# - Hymn of Death
# - Inside the Real Narcos
# - The Fix
# - The Innocent Man
# - Tidelands
# - Back Street Girls -GOKUDOLS-
# - Dogs of Berlin
# - Pine Gap
# - Memories of the Alhambra
# - Haunted House
# - 1983
# - Death by Magic
# - Love and Fortune
# - Bumping Mics with Jeff Ross & Dave Attell
# - Minecraft: Story Mode
# - Fugitiva
# - Kulipari: Dream Walker
# - Paap-O-Meter
# - The Final Table
# - Eternal Love
# - La Doña
# - Silvana Sin Lana
# - Vai Anitta
# - Beyblade Burst Evolution
# - Warrior
# - Age of Tanks
# - Medal of Honor
# - Super Drags
# - The Queen of Flow
# - Westside
# - Transfers
# - Damnation
# - Brainchild
# - The Great British Baking Show: The Beginnings
# - Terrorism Close Calls
# - DreamWorks Spooky Stories
# - Here to Heart
# - Accidentally in Love
# - Ask the Doctor
# - Best.Worst.Weekend.Ever.
# - Wanderlust
# - Stunt Science
# - FIGHTWORLD
# - The Curious Creations of Christine McConnell
# - The Haunting of Hill House
# - Ordinary Heroes
# - Salt Fat Acid Heat
# - Blood Pact
# - Dancing Queen
# - Empire Games
# - LOST SONG
# - YG Future Strategy Office
# - Violet Evergarden: Special
# - Monty Python Best Bits (mostly)
# - Monty Python's Almost the Truth
# - Monty Python's Fliegender Zirkus
# - Monty Python's Personal Best
# - Hot Date
# - Strong
# - Three Wives One Husband
# - Made in Mexico
# - Battlefish
# - DRAGON PILOT: Hisone & Masotan
# - Maniac
# - The Good Cop
# - Mobile Suit Gundam UC
# - Transformers: Rescue Bots
# - Al Hayba
# - Boca Juniors Confidential
# - Norm Macdonald Has a Show
# - Super Monsters Monster Party
# - The Rise of Phoenixes
# - Life
# - Daniel Sloss: Live Shows
# - If I were an Animal
# - Transformers Prime
# - Transformers: Robots in Disguise
# - First and Last
# - Monkey Twins
# - Age of Rebellion
# - Sisters
# - Cathedral of the Sea
# - Inside the Criminal Mind
# - Undercover Law
# - Chicken Soup for the Soul's Being Dad
# - GHOUL
# - Take My Brother Away
# - The Innocents
# - Stay Here
# - 72 Dangerous Animals: Asia
# - Afflicted
# - All About the Washingtons
# - Pretty Man
# - On Children
# - Cocaine Coast
# - Becoming Champions
# - Switched
# - The Could’ve-Gone-All-the-Way Committee
# - Smoking
# - Welcome to the Family
# - Amazing Interiors
# - Dark Tourist
# - Jimmy: The True Story of a True Idiot
# - Camarón Revolution
# - Meteor Garden
# - Mr. Sunshine
# - Somewhere Between
# - Churchill’s Secret Agents: The New Recruits
# - Kiss Me First
# - Hotel Transylvania
# - Borges
# - Life Sentence
# - Club de Cuervos Presents: The Ballad of Hugo Sánchez
# - True: Magical Friends
# - True: Wonderful Wishes
# - The Staircase
# - November 13: Attack on Paris
# - The Break with Michelle Wolf
# - Something in the Rain
# - Mob Psycho 100
# - Dance & Sing with True
# - Saint Seiya: The Lost Canvas
# - Evil Genius
# - The Who Was? Show
# - A Little Help with Carol Burnett
# - Simon
# - Spiritual House
# - Black Crows
# - Bobby Kennedy for President
# - Moving On
# - Trio and a Bed
# - 海的儿子
# - Charité
# - The Chalet
# - The Honeymoon Stand Up Special
# - AMO
# - Troy
# - Fallet
# - Loaded
# - Rapture
# - Trump: An American Dream
# - James Acaster: Repertoire
# - Requiem
# - Edha
# - Wild Wild Country
# - Secret of the Nile
# - Tabula Rasa
# - Children of the Whales
# - A.I.C.O.
# - Collateral
# - Bad Guys: Vile City
# - Borderliner
# - Flint Town
# - 21 Thunder
# - Best Lover
# - Seven Seconds
# - Hitler's Circle of Evil
# - Everything Sucks!
# - Re:Mind
# - Valor
# - Coach Snoop
# - Retribution
# - Prison Playbook
# - Love and Hong Kong
# - Tiempos de guerra
# - Godzilla
# - Tundukkan Playboy Itu
# - Devilman Crybaby
# - Fullmetal Alchemist
# - Pokémon: Indigo League
# - The Frozen Dead
# - Dave Chappelle: Equanimity & The Bird Revelation
# - La Mante
# - Wadi
# - Part-Time Idol
# - Myths & Monsters
# - 72 Dangerous Animals: Latin America
# - The Indian Detective
# - Cheuk Wan-Chi: Two Night Stand
# - Wormwood
# - Dawai Asmara
# - Dhia Sofea
# - Kantaro: The Sweet Tooth Salaryman
# - Oggy and the Cockroaches
# - Padamu Aku Bersujud
# - The Many Faces of Ito
# - Trailer Park Boys: Out of the Park: USA
# - Bright: The Music Videos
# - Argon
# - Godless
# - Shot in the Dark
# - The Irregular at Magic High School
# - The Method
# - Blazing Transfer Students
# - Akulah Balqis
# - Alias Grace
# - The Family Court
# - The Golden Path
# - The Little Nyonya
# - The Truth
# - Together
# - Beyond Stranger Things
# - The Mist
# - The Day I Met El Chapo
# - In Laws
# - Laws of Attraction
# - Seven and Me
# - ID-0
# - Beyblade Burst
# - Equestria Girls: Tales of Canterlot High
# - Justice in the City
# - Sudden
# - The Dream Catchers
# - What She Put on the Table
# - The Royal House of Windsor
# - Mak Cun
# - Paul Hollywood's Big Continental Road Trip
# - Satu Hari
# - Apaches
# - Fire Chasers
# - No Tomorrow
# - Frequency
# - A Boy Name Flora A
# - A House of Blocks
# - FINAL FANTASY XIV Dad of Light
# - Gurren Lagann
# - High Risk
# - LEGO Elves: Secrets of Elvendale
# - Marvel's The Defenders
# - 20 Minutes
# - Million Yen Women
# - Wet Hot American Summer: Ten Years Later
# - Bountiful Blessings
# - Close Your Eyes Before It’s Dark
# - Entangled
# - Fartsa
# - Have You Ever Fallen in Love, Miss Jiang?
# - Life Plan A and B
# - Locust
# - Love Storm
# - Surviving Escobar - Alias JJ
# - The In-Laws
# - World War II in Colour
# - Daughters of Destiny
# - Ari Shaffir: Double Negative
# - Diamond Lover
# - King’s War
# - Qin Empire: Alliance
# - The Legend of Bruce Lee
# - 46
# - Against the Tide
# - Barbie Life in the Dreamhouse
# - Breakout
# - Learning Songs by Little Baby Bum: Nursery Rhyme Friends
# - Mystic Whispers
# - Spice Up
# - The Oath
# - The Truth Seekers
# - The Ultimatum
# - World at Your Feet
# - Yes We Can!
# - Yours Fatefully
# - Gypsy
# - 28 Moons
# - Magic Phone
# - Man to Man
# - My Little Baby
# - Singles Villa
# - Under the Black Moonlight
# - My Only Love Song
# - Crashing
# - Mind Game
# - Miniforce
# - The Day Will Come
# - The Dream Job
# - Highland: Thailand's Marijuana Awakening
# - The Keepers
# - All Hail King Julien: Exiled
# - Jumping Girl
# - President
# - What in the World Happened?
# - Fangbone
# - Girlboss
# - Hot Girls Wanted: Turned On
# - The Miracle
# - Burned Cocoon
# - Five Came Back
# - Dave Chappelle
# - One-Punch Man
# - Julie's Greenroom
# - Samurai Gourmet
# - Cheer Squad
# - Buddy Thunderstruck
# - One More Time
# - Love Is in the Air
# - Tong: Memories
# - Legend Quest
# - The Sound of Your Heart
# - Love for Ten: Generation of Youth
# - Nightmare High
# - Spark
# - White Nights
# - Cyborg 009: Call of Justice
# - We're Lalaloopsy
# - My Runway
# - Chasing Cameron
# - Crazyhead
# - Color of Woman
# - Goodbye My Wife
# - Happy And
# - Heaven's Garden
# - Ice Fantasy
# - Immortal Classic
# - K-POP Extreme Survival
# - Miss Panda & Mr. Hedgehog
# - Tokyo Trial
# - Captive
# - White Rabbit Project
# - Miss in Kiss
# - The Cuba Libre Story
# - Back to 1989
# - Bromance
# - Refresh Man
# - Gilmore Girls: A Year in the Life
# - La Niña
# - Paranoid
# - Einsatzgruppen: The Nazi Death Squads
# - Case
# - Inborn Pair
# - Just You
# - Love Around
# - Love Family
# - Love Me or Leave Me
# - Love Now
# - Trailer Park Boys: Out of the Park: Europe
# - Containment
# - DEATH NOTE
# - Spotless
# - StoryBots Super Songs
# - Be with Me
# - Be with You
# - Fall in Love with Me
# - Love Cheque Charge
# - Masha's Spooky Stories
# - Murphy's Law of Love
# - Old Money
# - Someone Like You
# - When I See You Again
# - Chef's Table: France
# - Kulipari: An Army of Frogs
# - Conspiracy
# - Dead Set
# - The Fierce Wife
# - Witches: A Century of Murder
# - Behind Enemy Lines
# - Cocaine
# - Edge of the Universe
# - La Esclava Blanca
# - Justin Time GO!
# - Hibana: Spark
# - 72 Cutest Animals
# - 72 Dangerous Places to Live
# - Cyborg 009 VS Devilman
# - Netflix Presents: The Characters
# - Your lie in April
# - Cooked
# - Masha's Tales
# - Chelsea Does
# - Sammy & Co
# - Atelier
# - W/ Bob & David
# - Wakfu: The Quest for the Six Eliatrope Dofus
# - Wet Hot American Summer
# - Oscar's Oasis
# - 9-Feb
# - แผนร้ายนายเจ้าเล่ห์
# - Şubat
# - 100% Hotter
# - 12 Years Promise
# - 21 Sarfarosh: Saragarhi 1897
# - 7 (Seven)
# - 9 Months That Made You
# - A Good Wife
# - A Man Called God
# - A.D. Kingdom and Empire
# - Adam Ruins Everything
# - Africa
# - Age Gap Love
# - Agent Raghav
# - Ainsley Eats the Streets
# - America's Book of Secrets
# - American Experience: The Circus
# - American Odyssey
# - An Innocent Mistake
# - Ancient Aliens
# - Anjaan: Rural Myths
# - Anjaan: Special Crimes Unit
# - Atomic Puppet
# - Aussie Gold Hunters
# - Badalte Rishton Ki Dastaan
# - Bala Loca
# - Bangkok Bachelors
# - Bat Pat
# - Battle Creek
# - Battlefield Recovery
# - Be-Be-Bears
# - Beast Legends
# - Beating Again
# - Behind the Newsroom
# - Behzat Ç.
# - Ben 10
# - Beyblade: Metal Fusion
# - Bh Se Bhade
# - Bhaage Re Mann
# - Bitter Daisies
# - Black Heart
# - Blood & Treasures
# - Blue Planet II
# - Bob Ross: Beauty Is Everywhere
# - Bondi Rescue
# - Border Patrol
# - Botched Up Bodies
# - Brave Miss World
# - Bringing Sexy Back
# - Brown Nation
# - Buddha
# - Bure Kaam Bura Natija, Kyun Bhai Chacha Haan Bhatija
# - Cabins in the Wild with Dick Strawbridge
# - Cain and Abel
# - Calico Critters
# - Call Me Francis
# - Camelia la Texana
# - Camp X
# - Can We Get Married?
# - Cannabis
# - Care Bears: Welcome to Care-a-Lot
# - Case Closed
# - Castle of Stars
# - Cheapest Weddings
# - Chewin' the Fat
# - Chill with Bob Ross
# - Christiane Amanpour: Sex & Love Around the World
# - Chuck Chicken
# - City in the Sky
# - Civilizations
# - Classic Legends
# - Click for Murder
# - Club Friday To Be Continued - Friend & Enemy
# - Club Friday To Be Continued - My Beautiful Tomboy
# - Club Friday To Be Continued - The Promise
# - Cold Case Files
# - Cold Case Files Classic
# - Comedy High School
# - Conan Without Borders
# - Cooking on High
# - Court Justice
# - Crime Time
# - Dance Academy
# - Dandy
# - Darr Sabko Lagta Hai
# - Day and Night
# - Deep Water
# - Devlok with Devdutt Pattanaik
# - Dinner for Five
# - Dino Hunt
# - Diva Brides
# - Doomsday Preppers
# - Dramaworld
# - Drugs, Inc.
# - Dueños del paraíso
# - Earth to Luna!
# - Earth's Natural Wonders
# - Earth's Natural Wonders: Life at the Extremes
# - Easy Fortune Happy Life
# - El Cartel
# - El Cartel 2
# - El Chavo
# - El Clon
# - Emogenius
# - Encerrados
# - Encounters with Evil
# - Enemigo íntimo
# - Eurovision Song Contest
# - Everyday Miracles
# - Ex-Boyfriend
# - Exclusive Edition
# - Ezel
# - Fairy Tail
# - Fake or Fortune?
# - Fatal Destiny
# - Fear Files... Har Mod Pe Darr
# - Flowering Heart
# - Food: Delicious Science
# - Footprints in the Sand
# - For the Win
# - Forces of Nature
# - Forget Me Not
# - Four Seasons in Havana
# - Frozen Planet
# - Gabru: Hip Hop Revolution
# - Game Winning Hit
# - Gangs of Hassepur
# - Gargantia on the Verdurous Planet
# - Genius of the Ancient World
# - Genius of the Modern World
# - Gentlemen and Gangsters
# - Geronimo Stilton
# - Get Shorty
# - Ghost Town Gold
# - Glowing Embers
# - Gonul
# - Great Yellowstone Thaw
# - Happy 300 Days
# - Happyish
# - Harold Shipman - Driven to Kill
# - Harry & Bunnie
# - Hati Perempuan
# - Helix
# - Hidden Singer
# - Historia de un clan
# - History's Greatest Hoaxes
# - Hogie the Globehopper
# - Horror Homes
# - Hotel Beau Séjour
# - How to Live Mortgage Free with Sarah Beeny
# - Humsafar
# - Hunters of the South Seas
# - I Am Me!
# - Idiotest
# - In Between
# - India: Nature's Wonderland
# - Inside The Freemasons
# - Inside the Mind of a Serial Killer
# - Inside the Mossad
# - Inst@famous
# - Islands of the Future
# - 마녀사냥
# - Jack Taylor
# - Japanese Style Originator
# - Jhansi Ki Rani
# - JingleKids
# - Jonathan Strange & Mr Norrell
# - Juana Brava
# - Juana Inés
# - K
# - Kaçak
# - Ken Burns: The Civil War
# - Ken Burns: The Roosevelts: An Intimate History
# - Ken Burns: The West
# - Khaani
# - Khan: No. 1 Crime Hunter
# - Khelti Hai Zindagi Aankh Micholi
# - Khotey Sikkey
# - Kingdoms of the Sky
# - Kiss The Series
# - Kitten Rescuers
# - Kon Kon Kon
# - Krishna Balram
# - Kurt Seyit & Sura
# - La Femme
# - La Piloto
# - La Rosa de Guadalupe
# - La Viuda Negra
# - Lady, la vendedora de rosas
# - Last
# - Learning Time with Timmy
# - Legends of Strength
# - Lego Friends: Girls on a Mission
# - Leo & Tig
# - License to Drill: Louisiana
# - Life on Location
# - Life Story
# - Little Lunch
# - Lo que la verdad esconde: El caso Asunta (Operacion Nenúfar)
# - Lo que la vida me robó
# - London Spy
# - Los 10 años de Peter Capusotto
# - Los tiempos de Pablo Escobar
# - Love Cuisine
# - Love Rain
# - Love Rhythms - Accidental Daddy
# - Love Your Garden
# - Lucky Days
# - Maggie & Bianca: Fashion Friends
# - Magi: Adventure of Sinbad
# - Maharakshak Devi
# - Maharakshak: Aryan
# - Mahi Way
# - Mahmut & Meryem
# - Man vs Wild with Sunny Leone
# - Marching Orders
# - Married at First Sight
# - Mary Portas: Secret Shopper
# - Mega Food
# - MegaTruckers
# - Melodies of Life - Born This Way
# - Mere Papa Hero Hiralal
# - Merlí
# - Mexico Diseña
# - Midnight Misadventures With Mallika Dua
# - Mighty Morphin Alien Rangers
# - Minute to Win It
# - Miss Dynamite
# - Miss Rose
# - Momo Salon
# - Money for Nothing
# - Monkey Planet
# - Monty Don's French Gardens
# - Monty Don's Italian Gardens
# - My Hotter Half
# - My Life My Story
# - My Tattoo Addiction
# - Mystery Science Theater 3000
# - Nature: Animals With Cameras
# - NATURE: Natural Born Hustlers
# - Nature's Great Events (2009)
# - Nature's Great Events: Diaries
# - Nature's Great Race
# - Ninja Hattori
# - Ninja Turtles: The Next Mutation
# - Nobel
# - North & South
# - NSU German History X
# - Nuestra Lucha Libre
# - Nura: Rise of the Yokai Clan: Demon Capital
# - Nurses Who Kill
# - O-Negative, Love Can’t Be Designed
# - OCTB
# - Oliver Stone's Untold History of the United States
# - Ollie & Moon
# - One Strange Rock
# - Operation Gold Rush
# - Operation Ouch!
# - Operation Proposal
# - P. King Duckling
# - Pacific Heat
# - Pajanimals
# - Pasión de Gavilanes
# - Pawn Stars
# - Pioneers of African-American Cinema
# - Planet Earth II
# - Planet Earth: The Complete Collection
# - Powder
# - Power Battle Watch Car
# - Power Rangers Dino Charge
# - Power Rangers Dino Super Charge
# - Power Rangers Dino Thunder
# - Power Rangers in Space
# - Power Rangers Jungle Fury
# - Power Rangers Lightspeed Rescue
# - Power Rangers Lost Galaxy
# - Power Rangers Mystic Force
# - Power Rangers Ninja Storm
# - Power Rangers Operation Overdrive
# - Power Rangers RPM
# - Power Rangers S.P.D.
# - Power Rangers Samurai
# - Power Rangers Super Megaforce
# - Power Rangers Super Samurai
# - Power Rangers Time Force
# - Power Rangers Turbo
# - Power Rangers Wild Force
# - Power Rangers Zeo
# - Power Rangers: Megaforce
# - Prince Jai Aur Dumdaar Viru
# - Prohibition: A Film by Ken Burns and Lynn Novick
# - Qué pena tu serie
# - Queen of No Marriage
# - Queens of Comedy
# - Queens vs. Kings
# - Rab Se Sohna Isshq
# - Ramayan
# - Razia Sultan
# - Reality of Dream
# - Rebelde
# - Revenge
# - Revolting Rhymes
# - Rishta.com
# - Robotech
# - Rubi
# - Russell Peters vs. the World
# - Sadqay Tumhare
# - Satrangi
# - Save Our Shelter
# - Secret Affair
# - Sensitive Skin
# - Servant of the People
# - Shadow of Truth
# - Shaka Zulu
# - Sid the Science Kid
# - Sin senos no hay paraíso
# - Skin Wars: Fresh Paint
# - Slobby's World
# - Sotus The Series
# - Space Racers
# - Star-Crossed
# - Station Horizon
# - Stoked
# - Stone Age
# - Storage Wars: Northern Treasures
# - Strawberry Shortcake: Berry Bitty Adventures
# - Strong Girl Bong-soon
# - Strongland
# - Suits
# - Super Bheem
# - SuperNature: Wild Flyers
# - Surviving R. Kelly Part II: The Reckoning
# - Swami Baba Ramdev: The Untold Story
# - Sym-Bionic Titan
# - Tales of the City (1993)
# - Teresa
# - Th Eena Meena Deeka Chase Comedy Show
# - Thackeray
# - The 2000s
# - The Bachelor
# - The Beat
# - The Beginning of Life: The Series
# - The Bible's Buried Secrets
# - The Big Catch
# - The Blue Planet: A Natural History of the Oceans
# - The Bomb Squad
# - The Calling
# - The Chefs' Line
# - The Code
# - The Curse of Oak Island
# - The Devil Is a Part-Timer!
# - The Drunk and on Drugs Happy Funtime Hour
# - The Eighties
# - The Fear
# - The Five
# - The Future of Water
# - The Golden Years with Javed Akhtar
# - The Great Train Robbery
# - The Guild
# - The Homecoming
# - The Hunt
# - The Irish Mob
# - The Jaime Maussan Show
# - The Jungle Book
# - The Kindness Diaries
# - The Lady in Dignity
# - The Liar
# - The Lizzie Borden Chronicles
# - The Making of Frozen Planet
# - The Messengers
# - The Mortified Guide
# - The Most Beautiful Hands of Delhi
# - The Murder Detectives
# - The Netflix Afterparty
# - The Nineties
# - The Pyramid Code
# - The Rap Game
# - The Real Football Factories
# - The Returned
# - The Road to Calvary
# - The Seventies
# - The Story of Us with Morgan Freeman
# - The Super Mario Bros. Super Show!
# - The Traffickers
# - The Underwear
# - The Universe
# - The Vietnam War: A Film by Ken Burns and Lynn Novick
# - The War: A Film by Ken Burns and Lynn Novick
# - The Womanizer
# - The Year of Happiness and Love
# - ThirTEEN Terrors
# - This Is My Love
# - Tientsin Mystic
# - Timeless Season
# - Timeline
# - Tip the Mouse
# - Top 10 Secrets and Mysteries
# - Towies
# - Trotsky
# - Wartime Portraits
# - What Happens to My Family
# - What Is Love?
# - Who's the One
# - Wild Alaska
# - Wild Arabia
# - Winsanity
# - Winter Sun
# - World's Busiest Cities
# - Yeh Meri Family
# - Yo-Kai Watch
# - Yoko
# - YOM
# - Zindagi Gulzar Hai

# %%
from matplotlib import pyplot as plt
import numpy as np 

season_key = []
season_value = []

for show in count_seasons_tv:
    #print(show)
    for key, value in show.items():
        season_key.append(key)
        season_value.append(value)

#print(season_key)
#print(season_value)


#--------------------------------------------------------------------
#GRAPH

def my_format(x):
    return '{:.0f}%\n\n{:.0f} Shows'.format(x, total * x/100)

plt.figure(figsize=(8, 8))
total = 2676

pie_values = np.array(season_value)
colors = ['lavender', '#FDAC53']
wedge_props = {"linewidth": 1, "edgecolor": "gray"}

#autopct = lambda p: '{:.0f} Shows'.format(p * total/100) also works to get the value as well
plt.pie(pie_values, labels = season_key, autopct = my_format, 
        colors = colors, wedgeprops = wedge_props, textprops={'fontsize': 15})
plt.title("TV Show Seasons", fontsize = 20)

plt.show()

# %% [markdown]
# ### Summary
#
# From the data and graph, we can see that there are 1,793 TV shows (67%) listed, which is the majority, that have a duration of at least one season compared to the 883 TV shows (33%) that have two or more seasons.
#
# So from this data, we could assume that most of the TV shows that are released on Netflix will mostly likely have only one season, with a small chance of having another season.

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ## 8. Find the Most Popular Genre of Movies and TV Shows
#
# We want to find what was the most popular genre in both movies and TV shows. We'll be using `netflix_listed_in` to find the different genres; and because there are multiple genres listed to each TV show and movie, we will only be taking the first genre listed and using that to create the data.
#
# Also, since we're finding both movies and TV shows, we'll need to use `netflix_type` as well.

# %%
updated_netflix_genre = []

genre_tv_list = []
genre_list_length = []

def popular_genre_tv():
    
    tv_show_list = []
    tv_dict = {}
    
    int_tv_show_list = []
    crime_tv_show_list = []
    docu_tv_show_list = []
    tv_dram_show_list = []
    british_tv_show_list = []
    tv_com_list = []
    kid_tv_list = []
    real_tv_list = []
    anime_ser_list = []
    action_adventure_list = []
    comedy_talkshow_list = []
    classic_cult_list = []
    romantic_tv_list = []
    horror_tv_list = []
    spanish_tv_list = []
    scifi_fantasy_list = []
    
    for genre in netflix_listed_in:
        genre = genre.split(",")
        #print(genre[0])
        updated_netflix_genre.append(genre[0])
    #print(updated_netflix_genre)  
    
    for index in range(0, len(netflix_show_id)):
        tv_dict.update({
            "Title" : netflix_title[index],
            "Type" : netflix_type[index],
            "Genre" : updated_netflix_genre[index]
        })
        #print(tv_dict)
        tv_show_list.append(tv_dict.copy())
    #print(tv_show_list)
    
    tv_show_list = [tv for tv in tv_show_list if tv["Type"] == "TV Show"]
    #print(tv_show_list)
    
    updated_tv_show_list = [tv for tv in tv_show_list if tv["Genre"] != '']
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if key == "Genre":
                #print(value)
                genre_tv_list.append(value)
        #print(show)
    #print(genre_tv_list)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "International TV Shows":
                int_tv_show_list.append(value)
    international_tv_shows = len(int_tv_show_list)
    #print(international_tv_shows)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Crime TV Shows":
                crime_tv_show_list.append(value)
    crime_tv_shows = len(crime_tv_show_list)
    #print(crime_tv_shows)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Docuseries":
                docu_tv_show_list.append(value)
    docuseries = len(docu_tv_show_list)
    #print(docuseries)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "TV Dramas":
                tv_dram_show_list.append(value)
    tv_dramas = len(tv_dram_show_list)
    #print(tv_dramas)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "British TV Shows":
                british_tv_show_list.append(value)
    british_tv_shows = len(british_tv_show_list)
    #print(british_tv_shows)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "TV Comedies":
                tv_com_list.append(value)
    tv_comedies = len(tv_com_list)
    #print(tv_comedies)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Kids' TV":
                kid_tv_list.append(value)
    kids_tv = len(kid_tv_list)
    #print(kids_tv)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Reality TV":
                real_tv_list.append(value)
    reality_tv = len(real_tv_list)
    #print(reality_tv)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Anime Series":
                anime_ser_list.append(value)
    anime_series = len(anime_ser_list)
    #print(anime_series)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "TV Action & Adventure":
                action_adventure_list.append(value)
    tv_action_adventure = len(action_adventure_list)
    #print(tv_action_adventure)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Stand-Up Comedy & Talk Shows":
                comedy_talkshow_list.append(value)
    standup_comedy_talkshows = len(comedy_talkshow_list)
    #print(standup_comedy_talkshows)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Classic & Cult TV":
                classic_cult_list.append(value)
    classic_cult_tv = len(classic_cult_list)
    #print(classic_cult_tv)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Romantic TV Shows":
                romantic_tv_list.append(value)
    romantic_tv_shows = len(romantic_tv_list)
    #print(romantic_tv_shows)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "TV Horror":
                horror_tv_list.append(value)
    tv_horror = len(horror_tv_list)
    #print(tv_horror)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "Spanish-Language TV Shows":
                spanish_tv_list.append(value)
    spanish_language_tv_shows = len(spanish_tv_list)
    #print(spanish_language_tv_shows)
    
    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "TV Sci-Fi & Fantasy":
                scifi_fantasy_list.append(value)
    tv_scifi_fantasy = len(scifi_fantasy_list)
    #print(tv_scifi_fantasy)
    
    
    genre_list_length.append(international_tv_shows)
    genre_list_length.append(crime_tv_shows)
    genre_list_length.append(docuseries)
    genre_list_length.append(tv_dramas)
    genre_list_length.append(british_tv_shows)
    genre_list_length.append(tv_comedies)
    genre_list_length.append(kids_tv)
    genre_list_length.append(reality_tv)
    genre_list_length.append(anime_series)
    genre_list_length.append(tv_action_adventure)
    genre_list_length.append(standup_comedy_talkshows)
    genre_list_length.append(classic_cult_tv)
    genre_list_length.append(romantic_tv_shows)
    genre_list_length.append(tv_horror)
    genre_list_length.append(spanish_language_tv_shows)
    genre_list_length.append(tv_scifi_fantasy)
    
    
popular_genre_tv()

# %%
genre_movie_list = []
genre_movie_length = []

def popular_genre_movie():
    
    movie_list = []
    movie_dict = {}
    
    doc_movie_list = []
    child_fam_movie_list = []
    drama_movie_list = []
    comedy_movie_list = []
    thriller_movie_list = []
    horror_movie_list = []
    action_adv_movie_list = []
    int_movie_list = []
    scifi_fantasy_movie_list = []
    classic_movie_list = []
    standup_comedy_movie_list = []
    anime_movie_list = []
    cult_movie_list = []
    independ_movie_list = []
    music_movie_list = []
    romantic_movie_list = []
    lgbtq_movie_list = []
    sport_movie_list = []
    
    for index in range(0, len(netflix_show_id)):
        movie_dict.update({
            "Title" : netflix_title[index],
            "Type" : netflix_type[index],
            "Genre" : updated_netflix_genre[index]
        })
        movie_list.append(movie_dict.copy())
    #print(movie_list)
    
    movie_list = [m for m in movie_list if m["Type"] == "Movie"]
    #print(movie_list)
    
    updated_movie_list = [m for m in movie_list if m["Genre"] != '']
    for movie in updated_movie_list:
        for key, value in movie.items():
            if key == "Genre":
                #print(value)
                genre_movie_list.append(value)
        #print(movie)
    #print(genre_movie_list)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Documentaries":
                doc_movie_list.append(value)
    documentaries = len(doc_movie_list)
    #print(documentaries)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Children & Family Movies":
                child_fam_movie_list.append(value)
    children_family_movies = len(child_fam_movie_list)
    #print(children_family_movies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Dramas":
                drama_movie_list.append(value)
    dramas = len(drama_movie_list)
    #print(dramas)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Comedies":
                comedy_movie_list.append(value)
    comedies = len(comedy_movie_list)
    #print(comedies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Thrillers":
                thriller_movie_list.append(value)
    thrillers = len(thriller_movie_list)
    #print(thrillers)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Horror Movies":
                horror_movie_list.append(value)
    horror_movies = len(horror_movie_list)
    #print(horror_movies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Action & Adventure":
                action_adv_movie_list.append(value)
    action_adventure = len(action_adv_movie_list)
    #print(action_adventure)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "International Movies":
                int_movie_list.append(value)
    international_movies = len(int_movie_list)
    #print(international_movies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Sci-Fi & Fantasy":
                scifi_fantasy_movie_list.append(value)
    scifi_fantasy = len(scifi_fantasy_movie_list)
    #print(scifi_fantasy)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Classic Movies":
                classic_movie_list.append(value)
    classic_movies = len(classic_movie_list)
    #print(classic_movies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Stand-Up Comedy":
                standup_comedy_movie_list.append(value)
    standup_comedy = len(standup_comedy_movie_list)
    #print(standup_comedy)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Anime Features":
                anime_movie_list.append(value)
    anime_features = len(anime_movie_list)
    #print(anime_features)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Cult Movies":
                cult_movie_list.append(value)
    cult_movies = len(cult_movie_list)
    #print(cult_movies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Independent Movies":
                independ_movie_list.append(value)
    independent_movies = len(independ_movie_list)
    #print(independent_movies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Music & Musicals":
                music_movie_list.append(value)
    music_musicals = len(music_movie_list)
    #print(music_musicals)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Romantic Movies":
                romantic_movie_list.append(value)
    romantic_movies = len(romantic_movie_list)
    #print(romantic_movies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "LGBTQ Movies":
                lgbtq_movie_list.append(value)
    lgbtq_movies = len(lgbtq_movie_list)
    #print(lgbtq_movies)
    
    for movie in updated_movie_list:
        for key, value in movie.items():
            if value == "Sports Movies":
                sport_movie_list.append(value)
    sports_movies = len(sport_movie_list)
    #print(sports_movies)
    
    
    genre_movie_length.append(documentaries)
    genre_movie_length.append(children_family_movies)
    genre_movie_length.append(dramas)
    genre_movie_length.append(comedies)
    genre_movie_length.append(thrillers)
    genre_movie_length.append(horror_movies)
    genre_movie_length.append(action_adventure)
    genre_movie_length.append(international_movies)
    genre_movie_length.append(scifi_fantasy)
    genre_movie_length.append(classic_movies)
    genre_movie_length.append(standup_comedy)
    genre_movie_length.append(anime_features)
    genre_movie_length.append(cult_movies)
    genre_movie_length.append(independent_movies)
    genre_movie_length.append(music_musicals)
    genre_movie_length.append(romantic_movies)
    genre_movie_length.append(lgbtq_movies)
    genre_movie_length.append(sports_movies)
    
    
popular_genre_movie()

# %%
from matplotlib import pyplot as plt
import numpy as np 

#labels for tv
tv_genre_list = list(dict.fromkeys(genre_tv_list))
tv_genre_list.remove("TV Shows")
#print(tv_genre_list)

#x-axis for tv
#print(genre_list_length)


#labels for movie
movie_genre_list = list(dict.fromkeys(genre_movie_list))
movie_genre_list.remove("Movies")
#print(movie_genre_list)

#x-axis for movie
#print(genre_movie_length)

#--------------------------------------------------------#
#GRAPH

mycolors_one = ['#F29BCB', '#2A2359', '#0634BF', '#0460D9', '#F2BFBB', '#0AA6A6', '#D95829', '#D92A1A', '#0D0D0D', '#C04BF2', '#52B5F2', '#1B3940', '#F2A341', '#F26B6B', '#8C4552', '#D9D7D8']
mycolors_two = ['#F29BCB', '#2A2359', '#0634BF', '#0460D9', '#F2BFBB', '#0AA6A6', '#D95829', '#D92A1A', '#0D0D0D', '#C04BF2', '#52B5F2', '#1B3940', '#F2A341', '#F26B6B', '#8C4552', '#D9D7D8', '#73655D', '#F2845C']

                                    #rows, columns
fig, (chart1, chart2) = plt.subplots(2, 1, figsize=(15, 15))
                                    
chart1.barh(tv_genre_list, genre_list_length, color = mycolors_one)
chart2.barh(movie_genre_list, genre_movie_length, color = mycolors_two)

chart1.set_title("TV Show Genres", fontsize = 15)
chart2.set_title("Movie Genres", fontsize = 15)

for index, value in enumerate(genre_list_length):
    chart1.text(value + 3.0, index - 0.1, str(value))

for index, value in enumerate(genre_movie_length):
    chart2.text(value + 4.0, index - 0.15, str(value))

plt.show()


#---------------------------------------------------
#If I wanted to make the chart a pie graph, I could use this code below


#first_pie = np.array(genre_list_length)
#first_labels = [f'{tv_genre_list} - {genre_list_length:.0f}' for tv_genre_list, genre_list_length in zip(tv_genre_list, genre_list_length)]
#myexplode_one = [0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03]
#mycolors_one = ['#F29BCB', '#2A2359', '#0634BF', '#0460D9', '#F2BFBB', '#0AA6A6', '#D95829', '#D92A1A', '#0D0D0D', '#C04BF2', '#52B5F2', '#1B3940', '#F2A341', '#F26B6B', '#8C4552', '#D9D7D8']

#second_pie = np.array(genre_movie_length)
#second_labels = [f'{movie_genre_list} - {genre_movie_length:.0f}' for movie_genre_list, genre_movie_length in zip(movie_genre_list, genre_movie_length)]
#myexplode_two = [0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03]
#mycolors_two = ['#F29BCB', '#2A2359', '#0634BF', '#0460D9', '#F2BFBB', '#0AA6A6', '#D95829', '#D92A1A', '#0D0D0D', '#C04BF2', '#52B5F2', '#1B3940', '#F2A341', '#F26B6B', '#8C4552', '#D9D7D8', '#73655D', '#F2845C']

#fig, (pie1, pie2) = plt.subplots(2, 1, figsize=(32, 32))
#pie1.pie(first_pie, explode = myexplode_one, colors = mycolors_one)
#pie2.pie(second_pie, explode = myexplode_two, colors = mycolors_two)

#pie1.set_title("TV Show Genres", fontsize=20)
#pie2.set_title("Movie Genres", fontsize=20)

#pie1.legend(first_labels)
#pie2.legend(second_labels)

#plt.show()

# %% [markdown]
# ### Summary
#
# In the *TV Show Genres* graph, it is shown that a majority of TV shows are part of the **International TV Shows** genre; while in the *Movie Genres* graph, the majority of movies are in the **Dramas** genre with **Comedies** coming in close to Dramas. Therefore, we could safely assume that a TV show released onto Netflix will most likely be an international TV show; while a movie released onto Netflix will most likely be a drama or a comedy*.
#
# \*It must be noted that in the TV Show category, there was a *TV Show* genre which was deleted because "TV Show" is not a genre; however, it may be that many TV shows were put into that category. In the Movie category, there was also a genre called "Movie" which was deleted as well.

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ## 9. Find TV Shows That Were Created Outside the United States.
#
# We want to know what TV shows were created and filmed from other countries other than the United States; as well as finding out how many TV shows each country has released on Netflix. We will need to use `netflix_country` to find the different countries*. Also, since we are only finding TV shows, we will need to use `netflix_type` to remove all the movies as well.
#
# *Because there are some Netflix titles that have more than one country where it was filmed, we will only use the first country listed as the first country is where the majority of the movie was filmed.

# %%
country_list = []
number_of_countries = []

def international_tv_shows():
    
    tv_show_list = []
    tv_show_dict = {}
    
    updated_netflix_country = []
    
    countries = []
    s_africa_list = []
    india_list = []
    uk_list = []
    mex_list = []
    turk_list = []
    aus_list = []
    s_korea_list = []
    fin_list = []
    nigeria_list = []
    jap_list = []
    bel_list = []
    fra_list = []
    spa_list = []
    rus_list = []
    ire_list = []
    ita_list = []
    argen_list = []
    jor_list = []
    colombia_list = []
    israel_list = []
    taiwan_list = []
    ger_list = []
    can_list = []
    pol_list = []
    thai_list = []
    swe_list = []
    chi_list = []
    ice_list = []
    den_list = []
    phil_list = []
    uae_list = []
    nor_list = []
    leb_list = []
    uru_list = []
    egypt_list = []
    lux_list = []
    braz_list = []
    senegal_list = []
    neth_list = []
    sa_list = []
    kuwait_list = []
    indo_list = []
    belar_list = []
    chile_list = []
    pr_list = []
    austria_list = []
    cyp_list = []
    maur_list = []
    sing_list = []
    malay_list = []
    hk_list = []
    nz_list = []
    cro_list = []
    cr_list = []
    paki_list = []
    ukr_list = []
    swiss_list = []
    
    for country in netflix_country:
        country = country.split(",")
        #print(country[0])
        updated_netflix_country.append(country[0])
    #print(updated_netflix_country)
    
    for index in range(0, len(netflix_show_id)):
        tv_show_dict.update({
             "ID" : netflix_show_id[index],
             "Title": netflix_title[index],
             "Country" : updated_netflix_country[index],
             "Type" : netflix_type[index]
         })
        #print(tv_show_dict)
        tv_show_list.append(tv_show_dict.copy())
    #print(tv_show_list)
    
    
    tv_show_list = [tv for tv in tv_show_list if tv["Type"] == "TV Show"]
    #print(tv_show_list)
    
    updated_tv_show_list = [tv for tv in tv_show_list if tv["Country"] != '' and tv["Country"] != "United States"]
    #print(updated_tv_show_list)
    
    for show in updated_tv_show_list:
        #print(show)
        for key, value in show.items():
            if key == "Country":
                #print(value)
                countries.append(value)
    #print(countries)
    
    list_of_countries = list(dict.fromkeys(countries))
    #print(list_of_countries)
    for country in list_of_countries:
        #print(country)
        country_list.append(country)

    for show in updated_tv_show_list:
        for key, value in show.items():
            if value == "South Africa":
                s_africa_list.append(value)
            if value == "India":
                india_list.append(value)
            if value == "United Kingdom":
                uk_list.append(value)
            if value == "Mexico":
                mex_list.append(value)
            if value == "Turkey":
                turk_list.append(value)
            if value == "Australia":
                aus_list.append(value)
            if value == "South Korea":
                s_korea_list.append(value)
            if value == "Finland":
                fin_list.append(value)
            if value == "Nigeria":
                nigeria_list.append(value)
            if value == "Japan":
                jap_list.append(value)
            if value == "Belgium":
                bel_list.append(value)
            if value == "France":
                fra_list.append(value)
            if value == "Spain":
                spa_list.append(value)
            if value == "Russia":
                rus_list.append(value)
            if value == "Ireland":
                ire_list.append(value)
            if value == "Italy":
                ita_list.append(value)
            if value == "Argentina":
                argen_list.append(value)
            if value == "Jordan":
                jor_list.append(value)
            if value == "Colombia":
                colombia_list.append(value)
            if value == "Israel":
                israel_list.append(value)
            if value == "Taiwan":
                taiwan_list.append(value)
            if value == "Germany":
                ger_list.append(value)
            if value == "Canada":
                can_list.append(value)
            if value == "Poland":
                pol_list.append(value)
            if value == "Thailand":
                thai_list.append(value)
            if value == "Sweden":
                swe_list.append(value)
            if value == "China":
                chi_list.append(value)
            if value == "Iceland":
                ice_list.append(value)
            if value == "Denmark":
                den_list.append(value)
            if value == "Philippines":
                phil_list.append(value)
            if value == "United Arab Emirates":
                uae_list.append(value)
            if value == "Norway":
                nor_list.append(value)
            if value == "Lebanon":
                leb_list.append(value)
            if value == "Uruguay":
                uru_list.append(value)
            if value == "Egypt":
                egypt_list.append(value)
            if value == "Luxembourg":
                lux_list.append(value)
            if value == "Brazil":
                braz_list.append(value)
            if value == "Senegal":
                senegal_list.append(value)
            if value == "Netherlands":
                neth_list.append(value)
            if value == "Saudi Arabia":
                sa_list.append(value)
            if value == "Kuwait":
                kuwait_list.append(value)
            if value == "Indonesia":
                indo_list.append(value)
            if value == "Belarus":
                belar_list.append(value)
            if value == "Chile":
                chile_list.append(value)
            if value == "Puerto Rico":
                pr_list.append(value)
            if value == "Austria":
                austria_list.append(value)
            if value == "Cyprus":
                cyp_list.append(value)
            if value == "Mauritius":
                maur_list.append(value)
            if value == "Singapore":
                sing_list.append(value)
            if value == "Malaysia":
                malay_list.append(value)
            if value == "Hong Kong":
                hk_list.append(value)
            if value == "New Zealand":
                nz_list.append(value)
            if value == "Croatia":
                cro_list.append(value)
            if value == "Czech Republic":
                cr_list.append(value)
            if value == "Pakistan":
                paki_list.append(value)
            if value == "Ukraine":
                ukr_list.append(value)
            if value == "Switzerland":
                swiss_list.append(value)
    
    south_africa = len(s_africa_list)
    #print(south_africa)
    india = len(india_list)
    #print(india)
    united_kingdom = len(uk_list)
    #print(united_kingdom)
    mexico = len(mex_list)
    #print(mexico)
    turkey = len(turk_list)
    #print(turkey)
    australia = len(aus_list)
    #print(australia)
    south_korea = len(s_korea_list)
    #print(south_korea)
    finland = len(fin_list)
    #print(finland)
    nigeria = len(nigeria_list)
    #print(nigeria)
    japan = len(jap_list)
    #print(japan)
    belgium = len(bel_list)
    #print(belgium)
    france = len(fra_list)
    #print(france)
    spain = len(spa_list)
    #print(spain)
    russia = len(rus_list)
    #print(russia)
    ireland = len(ire_list)
    #print(ireland)
    italy = len(ita_list)
    #print(italy)
    argentina = len(argen_list)
    #print(argentina)
    jordan = len(jor_list)
    #print(jordan)
    colombia = len(colombia_list)
    #print(colombia)
    israel = len(israel_list)
    #print(israel)
    taiwan = len(taiwan_list)
    #print(taiwan)
    germany = len(ger_list)
    #print(germany)
    canada = len(can_list)
    #print(canada)
    poland = len(pol_list)
    #print(poland)
    thailand = len(thai_list)
    #print(thailand)
    sweden = len(swe_list)
    #print(sweden)
    china = len(chi_list)
    #print(china)
    iceland = len(ice_list)
    #print(iceland)
    denmark = len(den_list)
    #print(denmark)
    philippines = len(phil_list)
    #print(philippines)
    uae = len(uae_list)
    #print(uae)
    norway = len(nor_list)
    #print(norway)
    lebanon = len(leb_list)
    #print(lebanon)
    uruguay = len(uru_list)
    #print(uruguay)
    egypt = len(egypt_list)
    #print(egypt)
    luxembourg = len(lux_list)
    #print(luxembourg)
    brazil = len(braz_list)
    #print(brazil)
    senegal = len(senegal_list)
    #print(senegal)
    netherlands = len(neth_list)
    #print(netherlands)
    saudi_arabia = len(sa_list)
    #print(saudi_arabia)
    kuwait = len(kuwait_list)
    #print(kuwait)
    indonesia = len(indo_list)
    #print(indonesia)
    belarus = len(belar_list)
    #print(belarus)
    chile = len(chile_list)
    #print(chile)
    puerto_rico = len(pr_list)
    #print(puerto_rico)
    austria = len(austria_list)
    #print(austria)
    cyprus = len(cyp_list)
    #print(cyprus)
    mauritius = len(maur_list)
    #print(mauritius)
    singapore = len(sing_list)
    #print(singapore)
    malaysia = len(malay_list)
    #print(malaysia)
    hong_kong = len(hk_list)
    #print(hong_kong)
    new_zealand = len(nz_list)
    #print(new_zealand)
    croatia = len(cro_list)
    #print(croatia)
    czech_republic = len(cr_list)
    #print(czech_republic)
    pakistan = len(paki_list)
    #print(pakistan)
    ukraine = len(ukr_list)
    #print(ukraine)
    switzerland = len(swiss_list)
    #print(switzerland)
    
    
    number_of_countries.append(south_africa)
    number_of_countries.append(india)
    number_of_countries.append(united_kingdom)
    number_of_countries.append(mexico)
    number_of_countries.append(turkey)
    number_of_countries.append(australia)
    number_of_countries.append(south_korea)
    number_of_countries.append(finland)
    number_of_countries.append(nigeria)
    number_of_countries.append(japan)
    number_of_countries.append(belgium)
    number_of_countries.append(france)
    number_of_countries.append(spain)
    number_of_countries.append(russia)
    number_of_countries.append(ireland)
    number_of_countries.append(italy)
    number_of_countries.append(argentina)
    number_of_countries.append(jordan)
    number_of_countries.append(colombia)
    number_of_countries.append(israel)
    number_of_countries.append(taiwan)
    number_of_countries.append(germany)
    number_of_countries.append(canada)
    number_of_countries.append(poland)
    number_of_countries.append(thailand)
    number_of_countries.append(sweden)
    number_of_countries.append(china)
    number_of_countries.append(iceland)
    number_of_countries.append(denmark)
    number_of_countries.append(philippines)
    number_of_countries.append(uae)
    number_of_countries.append(norway)
    number_of_countries.append(lebanon)
    number_of_countries.append(uruguay)
    number_of_countries.append(egypt)
    number_of_countries.append(luxembourg)
    number_of_countries.append(brazil)
    number_of_countries.append(senegal)
    number_of_countries.append(netherlands)
    number_of_countries.append(saudi_arabia)
    number_of_countries.append(kuwait)
    number_of_countries.append(indonesia)
    number_of_countries.append(belarus)
    number_of_countries.append(chile)
    number_of_countries.append(puerto_rico)
    number_of_countries.append(austria)
    number_of_countries.append(cyprus)
    number_of_countries.append(mauritius)
    number_of_countries.append(singapore)
    number_of_countries.append(malaysia)
    number_of_countries.append(hong_kong)
    number_of_countries.append(new_zealand)
    number_of_countries.append(croatia)
    number_of_countries.append(czech_republic)
    number_of_countries.append(pakistan)
    number_of_countries.append(ukraine)
    number_of_countries.append(switzerland)
    
    
international_tv_shows()

# %%
from matplotlib import pyplot as plt
import numpy as np 

#print(country_list)
#print(number_of_countries)

list_of_countries = {key:value for key, value in zip(country_list, number_of_countries)}
#print(list_of_countries)

new_list_of_countries = dict(sorted(list_of_countries.items(), key=lambda item: item[1]))
#print(new_list_of_countries)

countries = []
number_of_shows = []

for key, value in new_list_of_countries.items():
    #print(key + ' ' + str(value))
    countries.append(key)
    number_of_shows.append(value)
    
#print(countries)
#print(number_of_shows)

#------------------------------------------------------#
#GRAPH
fig, ax = plt.subplots(figsize=(15, 30))
mycolors = ['#F27999', '#D9296A', '#D5EFF2', '#F2B705', '#D98E04', '#CCCCFF', '#7D7DB3', '#FFCCB3', '#DAFFDE', '#91B386']

#the barh graph will print in reverse whatever is in the lists
plt.barh(countries, number_of_shows, align = 'center', height = 0.8, color = mycolors)

for index, value in enumerate(number_of_shows):
    plt.text(value + 1.0, index - 0.15, str(value))
    
plt.title("TV Shows on Netflix Outside the U.S.", fontsize = 15)

plt.show()

# %% [markdown]
# ### Summary
#
# Based on the graph, the United Kingdom has the most TV shows on Netflix, with Japan coming in second, and South Korea coming in third. However, I will note that if you add all the East Asian countries together (Japan, South Korea, Taiwan, China), you'll have at least 450 TV shows in the *East Asian* category.
#
# So therefore, we could safely assume that there will be a high chance a TV show released on Netflix will be from the United Kingdom; or an East Asian country, most likely Japan or South Korea.

# %% [markdown]
# <hr>
#
# [<sup id="fn1">1</sup>](#fn1-back) Data and description are written by Shivam Bansal; which is provided by *[Kaggle](https://www.kaggle.com/shivamb/netflix-shows)*.
